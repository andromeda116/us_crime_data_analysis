# %%
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# ### Weighting by ref pop; YEAR as control var; lagged values of dep var
# #### **** all regressions with dm ref pop lag vars counts files ****

# %% [markdown]
# #### create a func to automate weighted lagged regression - univariate for now

# %%
def wols_lagged_control_uni(req_dfs, dep_var, ind_vars, weights_var, control_var=False, dataset_names=False):
    df_count=0
    for df in req_dfs:
        for var in ind_vars:
            if control_var:
                model = sm.WLS.from_formula(f'{dep_var} ~ {var} + lag1_{dep_var} + lag2_{dep_var} + {control_var}', 
                                            data=df, 
                                            weights=df[f'{weights_var}'])
            else:
                model = sm.WLS.from_formula(f'{dep_var} ~ {var} + lag1_{dep_var} + lag2_{dep_var}', 
                                            data=df, 
                                            weights=df[f'{weights_var}'])
                
            results = model.fit()
            if dataset_names:
                print(dataset_names[df_count])
            print(results.summary(), '\n', '\n')
        df_count += 1

# %%
dm_dep_var_rates = 'dm_violent_crime_rate'
dm_ind_vars_rates = ['dm_total_officers_rate', 'dm_prison_occupancy_count_rate', 'dm_jail_occupancy_count_rate',
               'dm_drug_tot_arrests_rate', 'dm_disorder_arrests_tot_index_rate']

# %% [markdown]
# ### All Agencies - 90-15, 90-02, 03-15

# %%
all_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_gte_10k_core_rates_dm_ref_pop_lag.csv')
all_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_gte_10k_core_rates_dm_1990_2002_ref_pop_lag.csv')
all_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_gte_10k_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %% [markdown]
# #### With control var

# %%
wols_lagged_control_uni(req_dfs=[all_90_15, all_90_02, all_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['all_90_15', 'all_90_02', 'all_03_15'])
# Out:
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.779
# Model:                               WLS   Adj. R-squared:                  0.779
# Method:                    Least Squares   F-statistic:                 8.845e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -6.4494e+05
# No. Observations:                 100612   AIC:                         1.290e+06
# Df Residuals:                     100607   BIC:                         1.290e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3218.7629    114.692     28.065      0.000    2993.969    3443.557
# dm_total_officers_rate        -3.4449      0.492     -6.996      0.000      -4.410      -2.480
# lag1_dm_violent_crime_rate     0.8393      0.003    281.487      0.000       0.833       0.845
# lag2_dm_violent_crime_rate    -0.0206      0.003     -7.171      0.000      -0.026      -0.015
# YEAR                          -1.6154      0.057    -28.223      0.000      -1.728      -1.503
# ==============================================================================
# Omnibus:                    58164.290   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         20143666.583
# Skew:                          -1.561   Prob(JB):                         0.00
# Kurtosis:                      72.248   Cond. No.                     6.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.796
# Model:                               WLS   Adj. R-squared:                  0.796
# Method:                    Least Squares   F-statistic:                 8.549e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -5.6020e+05
# No. Observations:                  87831   AIC:                         1.120e+06
# Df Residuals:                      87826   BIC:                         1.120e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2932.7879    123.437     23.759      0.000    2690.852    3174.724
# dm_prison_occupancy_count_rate    -0.2585      0.035     -7.352      0.000      -0.327      -0.190
# lag1_dm_violent_crime_rate         0.8542      0.003    268.445      0.000       0.848       0.860
# lag2_dm_violent_crime_rate        -0.0271      0.003     -8.839      0.000      -0.033      -0.021
# YEAR                              -1.4727      0.062    -23.905      0.000      -1.593      -1.352
# ==============================================================================
# Omnibus:                    52651.180   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18442779.881
# Skew:                          -1.671   Prob(JB):                         0.00
# Kurtosis:                      73.911   Cond. No.                     6.89e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.89e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.781
# Model:                               WLS   Adj. R-squared:                  0.781
# Method:                    Least Squares   F-statistic:                 8.688e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -6.2471e+05
# No. Observations:                  97469   AIC:                         1.249e+06
# Df Residuals:                      97464   BIC:                         1.249e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3299.0108    119.279     27.658      0.000    3065.225    3532.796
# dm_jail_occupancy_count_rate     0.0181      0.047      0.381      0.703      -0.075       0.111
# lag1_dm_violent_crime_rate       0.8377      0.003    277.158      0.000       0.832       0.844
# lag2_dm_violent_crime_rate      -0.0187      0.003     -6.427      0.000      -0.024      -0.013
# YEAR                            -1.6554      0.060    -27.809      0.000      -1.772      -1.539
# ==============================================================================
# Omnibus:                    53731.858   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18337481.025
# Skew:                          -1.426   Prob(JB):                         0.00
# Kurtosis:                      70.135   Cond. No.                     6.75e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.75e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.779
# Model:                               WLS   Adj. R-squared:                  0.779
# Method:                    Least Squares   F-statistic:                 8.847e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -6.4493e+05
# No. Observations:                 100612   AIC:                         1.290e+06
# Df Residuals:                     100607   BIC:                         1.290e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3288.4763    114.622     28.690      0.000    3063.819    3513.133
# dm_drug_tot_arrests_rate       0.1176      0.014      8.366      0.000       0.090       0.145
# lag1_dm_violent_crime_rate     0.8384      0.003    281.084      0.000       0.833       0.844
# lag2_dm_violent_crime_rate    -0.0223      0.003     -7.731      0.000      -0.028      -0.017
# YEAR                          -1.6502      0.057    -28.850      0.000      -1.762      -1.538
# ==============================================================================
# Omnibus:                    58115.145   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         19850965.999
# Skew:                          -1.562   Prob(JB):                         0.00
# Kurtosis:                      71.742   Cond. No.                     6.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.781
# Model:                               WLS   Adj. R-squared:                  0.781
# Method:                    Least Squares   F-statistic:                 8.320e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -5.9550e+05
# No. Observations:                  93297   AIC:                         1.191e+06
# Df Residuals:                      93292   BIC:                         1.191e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2842.3174    122.159     23.267      0.000    2602.888    3081.747
# dm_disorder_arrests_tot_index_rate     0.0563      0.011      5.253      0.000       0.035       0.077
# lag1_dm_violent_crime_rate             0.8325      0.003    270.573      0.000       0.826       0.838
# lag2_dm_violent_crime_rate            -0.0179      0.003     -6.077      0.000      -0.024      -0.012
# YEAR                                  -1.4266      0.061    -23.398      0.000      -1.546      -1.307
# ==============================================================================
# Omnibus:                    43421.293   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14710314.470
# Skew:                          -0.990   Prob(JB):                         0.00
# Kurtosis:                      64.483   Cond. No.                     6.91e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.91e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.744
# Model:                               WLS   Adj. R-squared:                  0.744
# Method:                    Least Squares   F-statistic:                 3.096e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.8022e+05
# No. Observations:                  42659   AIC:                         5.605e+05
# Df Residuals:                      42654   BIC:                         5.605e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1.298e+04    427.415     30.375      0.000    1.21e+04    1.38e+04
# dm_total_officers_rate        -9.5057      1.091     -8.713      0.000     -11.644      -7.368
# lag1_dm_violent_crime_rate     0.7888      0.004    176.440      0.000       0.780       0.798
# lag2_dm_violent_crime_rate    -0.0389      0.004     -9.576      0.000      -0.047      -0.031
# YEAR                          -6.5028      0.214    -30.391      0.000      -6.922      -6.083
# ==============================================================================
# Omnibus:                    14750.916   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4205644.456
# Skew:                          -0.332   Prob(JB):                         0.00
# Kurtosis:                      51.638   Cond. No.                     1.39e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.766
# Model:                               WLS   Adj. R-squared:                  0.766
# Method:                    Least Squares   F-statistic:                 3.009e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.4074e+05
# No. Observations:                  36844   AIC:                         4.815e+05
# Df Residuals:                      36839   BIC:                         4.815e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       9963.0337    470.154     21.191      0.000    9041.518    1.09e+04
# dm_prison_occupancy_count_rate    -0.9817      0.066    -14.786      0.000      -1.112      -0.852
# lag1_dm_violent_crime_rate         0.8003      0.005    167.496      0.000       0.791       0.810
# lag2_dm_violent_crime_rate        -0.0378      0.004     -8.652      0.000      -0.046      -0.029
# YEAR                              -4.9921      0.235    -21.212      0.000      -5.453      -4.531
# ==============================================================================
# Omnibus:                    13308.772   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3308481.400
# Skew:                          -0.498   Prob(JB):                         0.00
# Kurtosis:                      49.413   Cond. No.                     1.48e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.746
# Model:                               WLS   Adj. R-squared:                  0.746
# Method:                    Least Squares   F-statistic:                 3.036e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.7112e+05
# No. Observations:                  41277   AIC:                         5.423e+05
# Df Residuals:                      41272   BIC:                         5.423e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.255e+04    443.487     28.296      0.000    1.17e+04    1.34e+04
# dm_jail_occupancy_count_rate    -0.7366      0.090     -8.185      0.000      -0.913      -0.560
# lag1_dm_violent_crime_rate       0.7858      0.005    173.770      0.000       0.777       0.795
# lag2_dm_violent_crime_rate      -0.0332      0.004     -8.033      0.000      -0.041      -0.025
# YEAR                            -6.2858      0.222    -28.314      0.000      -6.721      -5.851
# ==============================================================================
# Omnibus:                    13912.548   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3920945.296
# Skew:                          -0.253   Prob(JB):                         0.00
# Kurtosis:                      50.744   Cond. No.                     1.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.744
# Model:                               WLS   Adj. R-squared:                  0.744
# Method:                    Least Squares   F-statistic:                 3.102e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.8019e+05
# No. Observations:                  42659   AIC:                         5.604e+05
# Df Residuals:                      42654   BIC:                         5.604e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    1.29e+04    426.479     30.244      0.000    1.21e+04    1.37e+04
# dm_drug_tot_arrests_rate      -0.2876      0.024    -11.807      0.000      -0.335      -0.240
# lag1_dm_violent_crime_rate     0.7878      0.004    176.292      0.000       0.779       0.797
# lag2_dm_violent_crime_rate    -0.0336      0.004     -8.222      0.000      -0.042      -0.026
# YEAR                          -6.4604      0.214    -30.259      0.000      -6.879      -6.042
# ==============================================================================
# Omnibus:                    14634.912   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4110239.274
# Skew:                          -0.315   Prob(JB):                         0.00
# Kurtosis:                      51.084   Cond. No.                     1.39e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.752
# Model:                               WLS   Adj. R-squared:                  0.752
# Method:                    Least Squares   F-statistic:                 3.032e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.6218e+05
# No. Observations:                  40028   AIC:                         5.244e+05
# Df Residuals:                      40023   BIC:                         5.244e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.307e+04    434.753     30.072      0.000    1.22e+04    1.39e+04
# dm_disorder_arrests_tot_index_rate     0.0254      0.017      1.472      0.141      -0.008       0.059
# lag1_dm_violent_crime_rate             0.7882      0.005    173.170      0.000       0.779       0.797
# lag2_dm_violent_crime_rate            -0.0357      0.004     -8.612      0.000      -0.044      -0.028
# YEAR                                  -6.5480      0.218    -30.086      0.000      -6.975      -6.121
# ==============================================================================
# Omnibus:                    13457.222   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4332509.274
# Skew:                          -0.147   Prob(JB):                         0.00
# Kurtosis:                      53.967   Cond. No.                     1.39e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.803
# Model:                               WLS   Adj. R-squared:                  0.803
# Method:                    Least Squares   F-statistic:                 4.924e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.9810e+05
# No. Observations:                  48372   AIC:                         5.962e+05
# Df Residuals:                      48367   BIC:                         5.963e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   2140.2443    260.208      8.225      0.000    1630.234    2650.255
# dm_total_officers_rate        -6.8622      0.605    -11.343      0.000      -8.048      -5.676
# lag1_dm_violent_crime_rate     0.8683      0.004    195.421      0.000       0.860       0.877
# lag2_dm_violent_crime_rate     0.0688      0.005     14.808      0.000       0.060       0.078
# YEAR                          -1.0718      0.129     -8.278      0.000      -1.326      -0.818
# ==============================================================================
# Omnibus:                    18302.923   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8893177.895
# Skew:                          -0.380   Prob(JB):                         0.00
# Kurtosis:                      69.421   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.811
# Model:                               WLS   Adj. R-squared:                  0.811
# Method:                    Least Squares   F-statistic:                 4.575e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.6207e+05
# No. Observations:                  42654   AIC:                         5.242e+05
# Df Residuals:                      42649   BIC:                         5.242e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2775.0484    277.982      9.983      0.000    2230.198    3319.899
# dm_prison_occupancy_count_rate    -0.3451      0.042     -8.166      0.000      -0.428      -0.262
# lag1_dm_violent_crime_rate         0.8772      0.005    183.341      0.000       0.868       0.887
# lag2_dm_violent_crime_rate         0.0658      0.005     13.168      0.000       0.056       0.076
# YEAR                              -1.3872      0.138    -10.030      0.000      -1.658      -1.116
# ==============================================================================
# Omnibus:                    17969.306   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10590711.870
# Skew:                          -0.607   Prob(JB):                         0.00
# Kurtosis:                      80.185   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.802
# Model:                               WLS   Adj. R-squared:                  0.802
# Method:                    Least Squares   F-statistic:                 4.741e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.8932e+05
# No. Observations:                  46897   AIC:                         5.787e+05
# Df Residuals:                      46892   BIC:                         5.787e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1946.5448    265.676      7.327      0.000    1425.816    2467.274
# dm_jail_occupancy_count_rate     0.2164      0.052      4.160      0.000       0.114       0.318
# lag1_dm_violent_crime_rate       0.8645      0.005    190.192      0.000       0.856       0.873
# lag2_dm_violent_crime_rate       0.0696      0.005     14.664      0.000       0.060       0.079
# YEAR                            -0.9759      0.132     -7.383      0.000      -1.235      -0.717
# ==============================================================================
# Omnibus:                    19940.213   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10492042.117
# Skew:                          -0.661   Prob(JB):                         0.00
# Kurtosis:                      76.264   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.803
# Model:                               WLS   Adj. R-squared:                  0.803
# Method:                    Least Squares   F-statistic:                 4.918e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.9813e+05
# No. Observations:                  48372   AIC:                         5.963e+05
# Df Residuals:                      48367   BIC:                         5.963e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1713.4351    262.926      6.517      0.000    1198.098    2228.773
# dm_drug_tot_arrests_rate       0.1574      0.018      8.954      0.000       0.123       0.192
# lag1_dm_violent_crime_rate     0.8633      0.004    193.858      0.000       0.855       0.872
# lag2_dm_violent_crime_rate     0.0668      0.005     14.336      0.000       0.058       0.076
# YEAR                          -0.8599      0.131     -6.573      0.000      -1.116      -0.603
# ==============================================================================
# Omnibus:                    20388.014   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10817119.840
# Skew:                          -0.638   Prob(JB):                         0.00
# Kurtosis:                      76.248   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.799
# Model:                               WLS   Adj. R-squared:                  0.799
# Method:                    Least Squares   F-statistic:                 4.447e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:06   Log-Likelihood:            -2.7460e+05
# No. Observations:                  44638   AIC:                         5.492e+05
# Df Residuals:                      44633   BIC:                         5.492e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1296.8177    278.208      4.661      0.000     751.526    1842.110
# dm_disorder_arrests_tot_index_rate     0.0244      0.013      1.810      0.070      -0.002       0.051
# lag1_dm_violent_crime_rate             0.8714      0.005    185.305      0.000       0.862       0.881
# lag2_dm_violent_crime_rate             0.0658      0.005     13.306      0.000       0.056       0.075
# YEAR                                  -0.6518      0.138     -4.708      0.000      -0.923      -0.380
# ==============================================================================
# Omnibus:                    19094.616   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12296161.460
# Skew:                          -0.622   Prob(JB):                         0.00
# Kurtosis:                      84.299   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Without control var

# %%
wols_lagged_control_uni(req_dfs=[all_90_15, all_90_02, all_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       weights_var='fnl_population_wt',
                       dataset_names=['all_90_15', 'all_90_02', 'all_03_15'])
# Out:
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.777
# Model:                               WLS   Adj. R-squared:                  0.777
# Method:                    Least Squares   F-statistic:                 1.167e+05
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -6.4534e+05
# No. Observations:                 100612   AIC:                         1.291e+06
# Df Residuals:                     100608   BIC:                         1.291e+06
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -18.1923      0.354    -51.402      0.000     -18.886     -17.499
# dm_total_officers_rate        -4.0910      0.494     -8.284      0.000      -5.059      -3.123
# lag1_dm_violent_crime_rate     0.8511      0.003    287.160      0.000       0.845       0.857
# lag2_dm_violent_crime_rate    -0.0108      0.003     -3.785      0.000      -0.016      -0.005
# ==============================================================================
# Omnibus:                    57129.392   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         20172401.262
# Skew:                          -1.503   Prob(JB):                         0.00
# Kurtosis:                      72.303   Cond. No.                         485.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.794
# Model:                               WLS   Adj. R-squared:                  0.794
# Method:                    Least Squares   F-statistic:                 1.131e+05
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -5.6049e+05
# No. Observations:                  87831   AIC:                         1.121e+06
# Df Residuals:                      87827   BIC:                         1.121e+06
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -17.9684      0.366    -49.125      0.000     -18.685     -17.251
# dm_prison_occupancy_count_rate    -0.4776      0.034    -14.020      0.000      -0.544      -0.411
# lag1_dm_violent_crime_rate         0.8641      0.003    273.025      0.000       0.858       0.870
# lag2_dm_violent_crime_rate        -0.0177      0.003     -5.781      0.000      -0.024      -0.012
# ==============================================================================
# Omnibus:                    52009.747   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18893704.993
# Skew:                          -1.623   Prob(JB):                         0.00
# Kurtosis:                      74.779   Cond. No.                         351.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.779
# Model:                               WLS   Adj. R-squared:                  0.779
# Method:                    Least Squares   F-statistic:                 1.147e+05
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -6.2509e+05
# No. Observations:                  97469   AIC:                         1.250e+06
# Df Residuals:                      97465   BIC:                         1.250e+06
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -17.9853      0.360    -50.008      0.000     -18.690     -17.280
# dm_jail_occupancy_count_rate    -0.2726      0.046     -5.871      0.000      -0.364      -0.182
# lag1_dm_violent_crime_rate       0.8494      0.003    282.646      0.000       0.843       0.855
# lag2_dm_violent_crime_rate      -0.0086      0.003     -2.960      0.003      -0.014      -0.003
# ==============================================================================
# Omnibus:                    53016.538   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18506206.523
# Skew:                          -1.382   Prob(JB):                         0.00
# Kurtosis:                      70.448   Cond. No.                         350.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.777
# Model:                               WLS   Adj. R-squared:                  0.777
# Method:                    Least Squares   F-statistic:                 1.167e+05
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -6.4534e+05
# No. Observations:                 100612   AIC:                         1.291e+06
# Df Residuals:                     100608   BIC:                         1.291e+06
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -18.2916      0.354    -51.681      0.000     -18.985     -17.598
# dm_drug_tot_arrests_rate       0.1038      0.014      7.362      0.000       0.076       0.131
# lag1_dm_violent_crime_rate     0.8505      0.003    286.855      0.000       0.845       0.856
# lag2_dm_violent_crime_rate    -0.0121      0.003     -4.203      0.000      -0.018      -0.006
# ==============================================================================
# Omnibus:                    57135.991   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         19870473.751
# Skew:                          -1.507   Prob(JB):                         0.00
# Kurtosis:                      71.781   Cond. No.                         347.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.780
# Model:                               WLS   Adj. R-squared:                  0.780
# Method:                    Least Squares   F-statistic:                 1.101e+05
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -5.9577e+05
# No. Observations:                  93297   AIC:                         1.192e+06
# Df Residuals:                      93293   BIC:                         1.192e+06
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -15.9263      0.359    -44.315      0.000     -16.631     -15.222
# dm_disorder_arrests_tot_index_rate     0.1406      0.010     13.876      0.000       0.121       0.160
# lag1_dm_violent_crime_rate             0.8410      0.003    274.519      0.000       0.835       0.847
# lag2_dm_violent_crime_rate            -0.0110      0.003     -3.725      0.000      -0.017      -0.005
# ==============================================================================
# Omnibus:                    41936.402   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14382356.771
# Skew:                          -0.905   Prob(JB):                         0.00
# Kurtosis:                      63.799   Cond. No.                         346.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.738
# Model:                               WLS   Adj. R-squared:                  0.738
# Method:                    Least Squares   F-statistic:                 4.011e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -2.8068e+05
# No. Observations:                  42659   AIC:                         5.614e+05
# Df Residuals:                      42655   BIC:                         5.614e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -6.6521      0.677     -9.822      0.000      -7.980      -5.325
# dm_total_officers_rate       -13.3255      1.095    -12.166      0.000     -15.472     -11.179
# lag1_dm_violent_crime_rate     0.8158      0.004    184.245      0.000       0.807       0.825
# lag2_dm_violent_crime_rate    -0.0384      0.004     -9.346      0.000      -0.046      -0.030
# ==============================================================================
# Omnibus:                    15357.157   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4361821.059
# Skew:                          -0.443   Prob(JB):                         0.00
# Kurtosis:                      52.530   Cond. No.                         743.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.763
# Model:                               WLS   Adj. R-squared:                  0.763
# Method:                    Least Squares   F-statistic:                 3.949e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -2.4096e+05
# No. Observations:                  36844   AIC:                         4.819e+05
# Df Residuals:                      36840   BIC:                         4.820e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -9.7210      0.706    -13.776      0.000     -11.104      -8.338
# dm_prison_occupancy_count_rate    -1.4920      0.062    -23.964      0.000      -1.614      -1.370
# lag1_dm_violent_crime_rate         0.8167      0.005    172.191      0.000       0.807       0.826
# lag2_dm_violent_crime_rate        -0.0335      0.004     -7.622      0.000      -0.042      -0.025
# ==============================================================================
# Omnibus:                    13554.069   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3330033.422
# Skew:                          -0.544   Prob(JB):                         0.00
# Kurtosis:                      49.562   Cond. No.                         472.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.741
# Model:                               WLS   Adj. R-squared:                  0.741
# Method:                    Least Squares   F-statistic:                 3.945e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -2.7152e+05
# No. Observations:                  41277   AIC:                         5.430e+05
# Df Residuals:                      41273   BIC:                         5.431e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -7.9754      0.698    -11.422      0.000      -9.344      -6.607
# dm_jail_occupancy_count_rate    -1.3310      0.088    -15.063      0.000      -1.504      -1.158
# lag1_dm_violent_crime_rate       0.8103      0.004    180.815      0.000       0.802       0.819
# lag2_dm_violent_crime_rate      -0.0306      0.004     -7.343      0.000      -0.039      -0.022
# ==============================================================================
# Omnibus:                    14452.185   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4044388.765
# Skew:                          -0.376   Prob(JB):                         0.00
# Kurtosis:                      51.487   Cond. No.                         470.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.739
# Model:                               WLS   Adj. R-squared:                  0.739
# Method:                    Least Squares   F-statistic:                 4.020e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -2.8065e+05
# No. Observations:                  42659   AIC:                         5.613e+05
# Df Residuals:                      42655   BIC:                         5.613e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -6.5338      0.677     -9.658      0.000      -7.860      -5.208
# dm_drug_tot_arrests_rate      -0.3628      0.024    -14.814      0.000      -0.411      -0.315
# lag1_dm_violent_crime_rate     0.8147      0.004    184.078      0.000       0.806       0.823
# lag2_dm_violent_crime_rate    -0.0318      0.004     -7.699      0.000      -0.040      -0.024
# ==============================================================================
# Omnibus:                    15214.490   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4285740.063
# Skew:                          -0.423   Prob(JB):                         0.00
# Kurtosis:                      52.096   Cond. No.                         459.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.746
# Model:                               WLS   Adj. R-squared:                  0.746
# Method:                    Least Squares   F-statistic:                 3.923e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:17:59   Log-Likelihood:            -2.6263e+05
# No. Observations:                  40028   AIC:                         5.253e+05
# Df Residuals:                      40024   BIC:                         5.253e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -5.9786      0.707     -8.456      0.000      -7.364      -4.593
# dm_disorder_arrests_tot_index_rate     0.1158      0.017      6.749      0.000       0.082       0.149
# lag1_dm_violent_crime_rate             0.8157      0.005    180.908      0.000       0.807       0.825
# lag2_dm_violent_crime_rate            -0.0367      0.004     -8.754      0.000      -0.045      -0.028
# ==============================================================================
# Omnibus:                    13756.178   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4507491.372
# Skew:                          -0.239   Prob(JB):                         0.00
# Kurtosis:                      54.984   Cond. No.                         475.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.803
# Model:                               WLS   Adj. R-squared:                  0.803
# Method:                    Least Squares   F-statistic:                 6.554e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:18:00   Log-Likelihood:            -2.9814e+05
# No. Observations:                  48372   AIC:                         5.963e+05
# Df Residuals:                      48368   BIC:                         5.963e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -13.7974      0.439    -31.428      0.000     -14.658     -12.937
# dm_total_officers_rate        -6.7104      0.605    -11.090      0.000      -7.896      -5.524
# lag1_dm_violent_crime_rate     0.8712      0.004    196.532      0.000       0.862       0.880
# lag2_dm_violent_crime_rate     0.0702      0.005     15.101      0.000       0.061       0.079
# ==============================================================================
# Omnibus:                    17934.822   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8790692.120
# Skew:                          -0.311   Prob(JB):                         0.00
# Kurtosis:                      69.039   Cond. No.                         427.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.811
# Model:                               WLS   Adj. R-squared:                  0.811
# Method:                    Least Squares   F-statistic:                 6.082e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:18:00   Log-Likelihood:            -2.6212e+05
# No. Observations:                  42654   AIC:                         5.243e+05
# Df Residuals:                      42650   BIC:                         5.243e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -13.1144      0.492    -26.647      0.000     -14.079     -12.150
# dm_prison_occupancy_count_rate    -0.2818      0.042     -6.735      0.000      -0.364      -0.200
# lag1_dm_violent_crime_rate         0.8808      0.005    184.373      0.000       0.871       0.890
# lag2_dm_violent_crime_rate         0.0672      0.005     13.422      0.000       0.057       0.077
# ==============================================================================
# Omnibus:                    17527.812   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10608825.176
# Skew:                          -0.535   Prob(JB):                         0.00
# Kurtosis:                      80.253   Cond. No.                         334.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.802
# Model:                               WLS   Adj. R-squared:                  0.802
# Method:                    Least Squares   F-statistic:                 6.312e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:18:00   Log-Likelihood:            -2.8935e+05
# No. Observations:                  46897   AIC:                         5.787e+05
# Df Residuals:                      46893   BIC:                         5.787e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -14.8550      0.464    -32.023      0.000     -15.764     -13.946
# dm_jail_occupancy_count_rate     0.2297      0.052      4.416      0.000       0.128       0.332
# lag1_dm_violent_crime_rate       0.8670      0.005    191.170      0.000       0.858       0.876
# lag2_dm_violent_crime_rate       0.0708      0.005     14.936      0.000       0.062       0.080
# ==============================================================================
# Omnibus:                    19484.753   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10439785.484
# Skew:                          -0.599   Prob(JB):                         0.00
# Kurtosis:                      76.084   Cond. No.                         322.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.802
# Model:                               WLS   Adj. R-squared:                  0.802
# Method:                    Least Squares   F-statistic:                 6.550e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:18:00   Log-Likelihood:            -2.9815e+05
# No. Observations:                  48372   AIC:                         5.963e+05
# Df Residuals:                      48368   BIC:                         5.963e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -14.7812      0.443    -33.351      0.000     -15.650     -13.912
# dm_drug_tot_arrests_rate       0.1740      0.017      9.991      0.000       0.140       0.208
# lag1_dm_violent_crime_rate     0.8653      0.004    194.674      0.000       0.857       0.874
# lag2_dm_violent_crime_rate     0.0676      0.005     14.494      0.000       0.058       0.077
# ==============================================================================
# Omnibus:                    19967.847   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10766948.515
# Skew:                          -0.581   Prob(JB):                         0.00
# Kurtosis:                      76.080   Cond. No.                         312.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.799
# Model:                               WLS   Adj. R-squared:                  0.799
# Method:                    Least Squares   F-statistic:                 5.925e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:18:00   Log-Likelihood:            -2.7461e+05
# No. Observations:                  44638   AIC:                         5.492e+05
# Df Residuals:                      44634   BIC:                         5.493e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -12.8775      0.478    -26.949      0.000     -13.814     -11.941
# dm_disorder_arrests_tot_index_rate     0.0415      0.013      3.194      0.001       0.016       0.067
# lag1_dm_violent_crime_rate             0.8727      0.005    185.839      0.000       0.863       0.882
# lag2_dm_violent_crime_rate             0.0663      0.005     13.406      0.000       0.057       0.076
# ==============================================================================
# Omnibus:                    18800.838   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12276291.757
# Skew:                          -0.578   Prob(JB):                         0.00
# Kurtosis:                      84.235   Cond. No.                         319.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Large Agencies - 90-15, 90-02, 03-15

# %%
#### read in the required files
large_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_large_cities_core_rates_dm_ref_pop_lag.csv')
large_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_large_cities_core_rates_dm_1990_2002_ref_pop_lag.csv')
large_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_large_cities_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %% [markdown]
# #### With control var

# %%
wols_lagged_control_uni(req_dfs=[large_90_15, large_90_02, large_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['large_90_15', 'large_90_02', 'large_03_15'])
# Out:
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.883
# Model:                               WLS   Adj. R-squared:                  0.883
# Method:                    Least Squares   F-statistic:                 1.581e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -51647.
# No. Observations:                   8360   AIC:                         1.033e+05
# Df Residuals:                       8355   BIC:                         1.033e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   2966.5793    387.401      7.658      0.000    2207.177    3725.982
# dm_total_officers_rate       -18.4280      2.050     -8.991      0.000     -22.446     -14.410
# lag1_dm_violent_crime_rate     1.0230      0.010    103.648      0.000       1.004       1.042
# lag2_dm_violent_crime_rate    -0.1638      0.009    -17.250      0.000      -0.182      -0.145
# YEAR                          -1.4934      0.193     -7.723      0.000      -1.872      -1.114
# ==============================================================================
# Omnibus:                     3547.696   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           186759.103
# Skew:                          -1.261   Prob(JB):                         0.00
# Kurtosis:                      26.017   Cond. No.                     7.20e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.892
# Model:                               WLS   Adj. R-squared:                  0.892
# Method:                    Least Squares   F-statistic:                 1.574e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -46871.
# No. Observations:                   7632   AIC:                         9.375e+04
# Df Residuals:                       7627   BIC:                         9.379e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2644.6761    399.496      6.620      0.000    1861.553    3427.799
# dm_prison_occupancy_count_rate    -0.3878      0.118     -3.296      0.001      -0.619      -0.157
# lag1_dm_violent_crime_rate         1.0423      0.010    101.589      0.000       1.022       1.062
# lag2_dm_violent_crime_rate        -0.1752      0.010    -17.673      0.000      -0.195      -0.156
# YEAR                              -1.3324      0.199     -6.682      0.000      -1.723      -0.941
# ==============================================================================
# Omnibus:                     3310.974   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           191488.900
# Skew:                          -1.279   Prob(JB):                         0.00
# Kurtosis:                      27.405   Cond. No.                     7.40e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.886
# Model:                               WLS   Adj. R-squared:                  0.886
# Method:                    Least Squares   F-statistic:                 1.567e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -49948.
# No. Observations:                   8094   AIC:                         9.991e+04
# Df Residuals:                       8089   BIC:                         9.994e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2955.7011    394.725      7.488      0.000    2181.938    3729.464
# dm_jail_occupancy_count_rate    -0.5410      0.208     -2.596      0.009      -0.950      -0.132
# lag1_dm_violent_crime_rate       1.0223      0.010    102.056      0.000       1.003       1.042
# lag2_dm_violent_crime_rate      -0.1598      0.010    -16.551      0.000      -0.179      -0.141
# YEAR                            -1.4879      0.197     -7.552      0.000      -1.874      -1.102
# ==============================================================================
# Omnibus:                     3384.768   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           184705.685
# Skew:                          -1.220   Prob(JB):                         0.00
# Kurtosis:                      26.275   Cond. No.                     7.27e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.882
# Model:                               WLS   Adj. R-squared:                  0.882
# Method:                    Least Squares   F-statistic:                 1.564e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -51687.
# No. Observations:                   8360   AIC:                         1.034e+05
# Df Residuals:                       8355   BIC:                         1.034e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3064.9365    389.810      7.863      0.000    2300.813    3829.060
# dm_drug_tot_arrests_rate       0.0014      0.040      0.036      0.972      -0.078       0.080
# lag1_dm_violent_crime_rate     1.0236      0.010    103.216      0.000       1.004       1.043
# lag2_dm_violent_crime_rate    -0.1628      0.010    -17.001      0.000      -0.182      -0.144
# YEAR                          -1.5426      0.195     -7.929      0.000      -1.924      -1.161
# ==============================================================================
# Omnibus:                     3757.865   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           198862.277
# Skew:                          -1.383   Prob(JB):                         0.00
# Kurtosis:                      26.733   Cond. No.                     7.21e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.886
# Model:                               WLS   Adj. R-squared:                  0.886
# Method:                    Least Squares   F-statistic:                 1.432e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -45430.
# No. Observations:                   7375   AIC:                         9.087e+04
# Df Residuals:                       7370   BIC:                         9.090e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2938.3246    424.328      6.925      0.000    2106.520    3770.130
# dm_disorder_arrests_tot_index_rate    -0.0380      0.036     -1.044      0.296      -0.109       0.033
# lag1_dm_violent_crime_rate             1.0129      0.010     97.058      0.000       0.992       1.033
# lag2_dm_violent_crime_rate            -0.1544      0.010    -15.423      0.000      -0.174      -0.135
# YEAR                                  -1.4786      0.212     -6.981      0.000      -1.894      -1.063
# ==============================================================================
# Omnibus:                     2632.389   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           134812.872
# Skew:                          -0.938   Prob(JB):                         0.00
# Kurtosis:                      23.861   Cond. No.                     7.57e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.57e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.856
# Model:                               WLS   Adj. R-squared:                  0.856
# Method:                    Least Squares   F-statistic:                     5696.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -24246.
# No. Observations:                   3836   AIC:                         4.850e+04
# Df Residuals:                       3831   BIC:                         4.853e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1.264e+04   1355.188      9.328      0.000    9983.655    1.53e+04
# dm_total_officers_rate       -25.1094      4.197     -5.982      0.000     -33.338     -16.880
# lag1_dm_violent_crime_rate     0.9575      0.014     68.479      0.000       0.930       0.985
# lag2_dm_violent_crime_rate    -0.1635      0.013    -13.038      0.000      -0.188      -0.139
# YEAR                          -6.3346      0.678     -9.338      0.000      -7.665      -5.005
# ==============================================================================
# Omnibus:                     1104.827   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32587.456
# Skew:                          -0.751   Prob(JB):                         0.00
# Kurtosis:                      17.200   Cond. No.                     1.52e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.870
# Model:                               WLS   Adj. R-squared:                  0.870
# Method:                    Least Squares   F-statistic:                     5797.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -21718.
# No. Observations:                   3462   AIC:                         4.345e+04
# Df Residuals:                       3457   BIC:                         4.348e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       8710.7312   1457.492      5.977      0.000    5853.099    1.16e+04
# dm_prison_occupancy_count_rate    -1.2234      0.216     -5.664      0.000      -1.647      -0.800
# lag1_dm_violent_crime_rate         0.9747      0.015     67.096      0.000       0.946       1.003
# lag2_dm_violent_crime_rate        -0.1630      0.013    -12.283      0.000      -0.189      -0.137
# YEAR                              -4.3680      0.730     -5.987      0.000      -5.798      -2.938
# ==============================================================================
# Omnibus:                     1048.351   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27349.029
# Skew:                          -0.859   Prob(JB):                         0.00
# Kurtosis:                      16.662   Cond. No.                     1.63e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.860
# Model:                               WLS   Adj. R-squared:                  0.859
# Method:                    Least Squares   F-statistic:                     5666.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -23384.
# No. Observations:                   3706   AIC:                         4.678e+04
# Df Residuals:                       3701   BIC:                         4.681e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.181e+04   1391.771      8.489      0.000    9085.768    1.45e+04
# dm_jail_occupancy_count_rate    -1.8811      0.374     -5.028      0.000      -2.615      -1.148
# lag1_dm_violent_crime_rate       0.9590      0.014     68.119      0.000       0.931       0.987
# lag2_dm_violent_crime_rate      -0.1558      0.013    -12.210      0.000      -0.181      -0.131
# YEAR                            -5.9214      0.697     -8.500      0.000      -7.287      -4.556
# ==============================================================================
# Omnibus:                     1078.866   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33466.999
# Skew:                          -0.750   Prob(JB):                         0.00
# Kurtosis:                      17.645   Cond. No.                     1.55e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.857
# Model:                               WLS   Adj. R-squared:                  0.857
# Method:                    Least Squares   F-statistic:                     5727.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -24237.
# No. Observations:                   3836   AIC:                         4.848e+04
# Df Residuals:                       3831   BIC:                         4.851e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1.333e+04   1338.753      9.956      0.000    1.07e+04     1.6e+04
# dm_drug_tot_arrests_rate      -0.4895      0.067     -7.356      0.000      -0.620      -0.359
# lag1_dm_violent_crime_rate     0.9536      0.014     68.208      0.000       0.926       0.981
# lag2_dm_violent_crime_rate    -0.1523      0.013    -12.030      0.000      -0.177      -0.128
# YEAR                          -6.6784      0.670     -9.966      0.000      -7.992      -5.365
# ==============================================================================
# Omnibus:                     1146.000   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34485.375
# Skew:                          -0.798   Prob(JB):                         0.00
# Kurtosis:                      17.602   Cond. No.                     1.50e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.862
# Model:                               WLS   Adj. R-squared:                  0.862
# Method:                    Least Squares   F-statistic:                     5332.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -21578.
# No. Observations:                   3420   AIC:                         4.317e+04
# Df Residuals:                       3415   BIC:                         4.320e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            1.42e+04   1395.818     10.176      0.000    1.15e+04    1.69e+04
# dm_disorder_arrests_tot_index_rate    -0.0867      0.055     -1.579      0.114      -0.194       0.021
# lag1_dm_violent_crime_rate             0.9535      0.015     65.560      0.000       0.925       0.982
# lag2_dm_violent_crime_rate            -0.1545      0.013    -11.768      0.000      -0.180      -0.129
# YEAR                                  -7.1165      0.699    -10.185      0.000      -8.486      -5.747
# ==============================================================================
# Omnibus:                      981.971   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32649.034
# Skew:                          -0.705   Prob(JB):                         0.00
# Kurtosis:                      18.071   Cond. No.                     1.50e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.891
# Method:                    Least Squares   F-statistic:                     7776.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -22316.
# No. Observations:                   3793   AIC:                         4.464e+04
# Df Residuals:                       3788   BIC:                         4.467e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1383.1619    807.478      1.713      0.087    -199.972    2966.295
# dm_total_officers_rate       -21.2060      1.912    -11.094      0.000     -24.954     -17.458
# lag1_dm_violent_crime_rate     1.0298      0.016     65.322      0.000       0.999       1.061
# lag2_dm_violent_crime_rate    -0.0602      0.017     -3.635      0.000      -0.093      -0.028
# YEAR                          -0.6955      0.402     -1.731      0.084      -1.483       0.092
# ==============================================================================
# Omnibus:                     1173.236   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           158786.135
# Skew:                           0.315   Prob(JB):                         0.00
# Kurtosis:                      34.691   Cond. No.                     1.35e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.891
# Method:                    Least Squares   F-statistic:                     7160.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -20592.
# No. Observations:                   3499   AIC:                         4.119e+04
# Df Residuals:                       3494   BIC:                         4.122e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3348.2505    874.393      3.829      0.000    1633.877    5062.624
# dm_prison_occupancy_count_rate    -1.1640      0.150     -7.751      0.000      -1.458      -0.870
# lag1_dm_violent_crime_rate         1.0444      0.017     62.262      0.000       1.011       1.077
# lag2_dm_violent_crime_rate        -0.0659      0.018     -3.748      0.000      -0.100      -0.031
# YEAR                              -1.6718      0.435     -3.842      0.000      -2.525      -0.819
# ==============================================================================
# Omnibus:                     1092.749   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           212773.437
# Skew:                           0.029   Prob(JB):                         0.00
# Kurtosis:                      41.203   Cond. No.                     1.40e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.887
# Model:                               WLS   Adj. R-squared:                  0.887
# Method:                    Least Squares   F-statistic:                     7214.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -21732.
# No. Observations:                   3681   AIC:                         4.347e+04
# Df Residuals:                       3676   BIC:                         4.350e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1286.9753    844.082      1.525      0.127    -367.939    2941.890
# dm_jail_occupancy_count_rate    -0.5248      0.236     -2.225      0.026      -0.987      -0.062
# lag1_dm_violent_crime_rate       1.0210      0.016     61.986      0.000       0.989       1.053
# lag2_dm_violent_crime_rate      -0.0536      0.017     -3.107      0.002      -0.087      -0.020
# YEAR                            -0.6482      0.420     -1.543      0.123      -1.472       0.175
# ==============================================================================
# Omnibus:                     1229.058   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           220822.606
# Skew:                          -0.381   Prob(JB):                         0.00
# Kurtosis:                      40.936   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.888
# Model:                               WLS   Adj. R-squared:                  0.888
# Method:                    Least Squares   F-statistic:                     7502.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -22376.
# No. Observations:                   3793   AIC:                         4.476e+04
# Df Residuals:                       3788   BIC:                         4.479e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1149.7546    837.088      1.374      0.170    -491.433    2790.942
# dm_drug_tot_arrests_rate      -0.0240      0.053     -0.452      0.652      -0.128       0.080
# lag1_dm_violent_crime_rate     1.0146      0.016     63.534      0.000       0.983       1.046
# lag2_dm_violent_crime_rate    -0.0468      0.017     -2.779      0.005      -0.080      -0.014
# YEAR                          -0.5801      0.417     -1.392      0.164      -1.397       0.237
# ==============================================================================
# Omnibus:                     1318.190   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           241605.279
# Skew:                          -0.472   Prob(JB):                         0.00
# Kurtosis:                      42.088   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.883
# Model:                               WLS   Adj. R-squared:                  0.883
# Method:                    Least Squares   F-statistic:                     6322.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:50   Log-Likelihood:                -19813.
# No. Observations:                   3347   AIC:                         3.964e+04
# Df Residuals:                       3342   BIC:                         3.967e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            679.0826    932.100      0.729      0.466   -1148.461    2506.626
# dm_disorder_arrests_tot_index_rate    -0.0584      0.047     -1.238      0.216      -0.151       0.034
# lag1_dm_violent_crime_rate             1.0293      0.018     58.552      0.000       0.995       1.064
# lag2_dm_violent_crime_rate            -0.0598      0.019     -3.215      0.001      -0.096      -0.023
# YEAR                                  -0.3460      0.464     -0.746      0.456      -1.256       0.564
# ==============================================================================
# Omnibus:                     1160.736   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           228260.744
# Skew:                          -0.433   Prob(JB):                         0.00
# Kurtosis:                      43.448   Cond. No.                     1.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Without control var

# %%
wols_lagged_control_uni(req_dfs=[large_90_15, large_90_02, large_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       weights_var='fnl_population_wt',
                       dataset_names=['large_90_15', 'large_90_02', 'large_03_15'])
# Out:
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.882
# Model:                               WLS   Adj. R-squared:                  0.882
# Method:                    Least Squares   F-statistic:                 2.092e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -51677.
# No. Observations:                   8360   AIC:                         1.034e+05
# Df Residuals:                       8356   BIC:                         1.034e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -25.4764      1.114    -22.869      0.000     -27.660     -23.293
# dm_total_officers_rate       -18.8803      2.056     -9.183      0.000     -22.910     -14.850
# lag1_dm_violent_crime_rate     1.0341      0.010    105.542      0.000       1.015       1.053
# lag2_dm_violent_crime_rate    -0.1546      0.009    -16.347      0.000      -0.173      -0.136
# ==============================================================================
# Omnibus:                     3527.822   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           191594.013
# Skew:                          -1.240   Prob(JB):                         0.00
# Kurtosis:                      26.321   Cond. No.                         820.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.891
# Method:                    Least Squares   F-statistic:                 2.085e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -46893.
# No. Observations:                   7632   AIC:                         9.379e+04
# Df Residuals:                       7628   BIC:                         9.382e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -24.6847      1.123    -21.978      0.000     -26.886     -22.483
# dm_prison_occupancy_count_rate    -0.5467      0.116     -4.730      0.000      -0.773      -0.320
# lag1_dm_violent_crime_rate         1.0514      0.010    103.116      0.000       1.031       1.071
# lag2_dm_violent_crime_rate        -0.1662      0.010    -16.874      0.000      -0.186      -0.147
# ==============================================================================
# Omnibus:                     3301.320   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           199270.498
# Skew:                          -1.261   Prob(JB):                         0.00
# Kurtosis:                      27.905   Cond. No.                         446.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.885
# Model:                               WLS   Adj. R-squared:                  0.885
# Method:                    Least Squares   F-statistic:                 2.073e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -49976.
# No. Observations:                   8094   AIC:                         9.996e+04
# Df Residuals:                       8090   BIC:                         9.999e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -25.3302      1.124    -22.526      0.000     -27.534     -23.126
# dm_jail_occupancy_count_rate    -0.7444      0.207     -3.589      0.000      -1.151      -0.338
# lag1_dm_violent_crime_rate       1.0333      0.010    103.880      0.000       1.014       1.053
# lag2_dm_violent_crime_rate      -0.1503      0.010    -15.643      0.000      -0.169      -0.131
# ==============================================================================
# Omnibus:                     3370.225   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           190013.336
# Skew:                          -1.202   Prob(JB):                         0.00
# Kurtosis:                      26.614   Cond. No.                         447.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.881
# Model:                               WLS   Adj. R-squared:                  0.881
# Method:                    Least Squares   F-statistic:                 2.068e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -51719.
# No. Observations:                   8360   AIC:                         1.034e+05
# Df Residuals:                       8356   BIC:                         1.035e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -25.8120      1.119    -23.066      0.000     -28.006     -23.618
# dm_drug_tot_arrests_rate       0.0205      0.040      0.509      0.611      -0.059       0.100
# lag1_dm_violent_crime_rate     1.0351      0.010    105.122      0.000       1.016       1.054
# lag2_dm_violent_crime_rate    -0.1536      0.010    -16.099      0.000      -0.172      -0.135
# ==============================================================================
# Omnibus:                     3730.243   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           203603.264
# Skew:                          -1.358   Prob(JB):                         0.00
# Kurtosis:                      27.024   Cond. No.                         444.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.885
# Model:                               WLS   Adj. R-squared:                  0.885
# Method:                    Least Squares   F-statistic:                 1.895e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -45454.
# No. Observations:                   7375   AIC:                         9.092e+04
# Df Residuals:                       7371   BIC:                         9.094e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -23.8420      1.162    -20.524      0.000     -26.119     -21.565
# dm_disorder_arrests_tot_index_rate     0.0494      0.034      1.441      0.150      -0.018       0.117
# lag1_dm_violent_crime_rate             1.0227      0.010     98.566      0.000       1.002       1.043
# lag2_dm_violent_crime_rate            -0.1478      0.010    -14.784      0.000      -0.167      -0.128
# ==============================================================================
# Omnibus:                     2560.342   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           133915.319
# Skew:                          -0.884   Prob(JB):                         0.00
# Kurtosis:                      23.801   Cond. No.                         447.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.853
# Model:                               WLS   Adj. R-squared:                  0.853
# Method:                    Least Squares   F-statistic:                     7399.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -24289.
# No. Observations:                   3836   AIC:                         4.859e+04
# Df Residuals:                       3832   BIC:                         4.861e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -14.1425      2.089     -6.768      0.000     -18.239     -10.046
# dm_total_officers_rate       -30.9553      4.197     -7.376      0.000     -39.183     -22.727
# lag1_dm_violent_crime_rate     0.9905      0.014     72.412      0.000       0.964       1.017
# lag2_dm_violent_crime_rate    -0.1668      0.013    -13.154      0.000      -0.192      -0.142
# ==============================================================================
# Omnibus:                     1146.173   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34352.389
# Skew:                          -0.799   Prob(JB):                         0.00
# Kurtosis:                      17.573   Cond. No.                     1.20e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.2e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.869
# Model:                               WLS   Adj. R-squared:                  0.869
# Method:                    Least Squares   F-statistic:                     7641.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -21736.
# No. Observations:                   3462   AIC:                         4.348e+04
# Df Residuals:                       3458   BIC:                         4.350e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -15.8261      2.076     -7.624      0.000     -19.896     -11.756
# dm_prison_occupancy_count_rate    -1.7374      0.199     -8.722      0.000      -2.128      -1.347
# lag1_dm_violent_crime_rate         0.9912      0.014     69.146      0.000       0.963       1.019
# lag2_dm_violent_crime_rate        -0.1592      0.013    -11.949      0.000      -0.185      -0.133
# ==============================================================================
# Omnibus:                     1061.079   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27601.823
# Skew:                          -0.877   Prob(JB):                         0.00
# Kurtosis:                      16.721   Cond. No.                         603.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.857
# Model:                               WLS   Adj. R-squared:                  0.857
# Method:                    Least Squares   F-statistic:                     7389.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -23419.
# No. Observations:                   3706   AIC:                         4.685e+04
# Df Residuals:                       3702   BIC:                         4.687e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -15.3433      2.103     -7.296      0.000     -19.466     -11.220
# dm_jail_occupancy_count_rate    -2.6656      0.366     -7.282      0.000      -3.383      -1.948
# lag1_dm_violent_crime_rate       0.9886      0.014     71.782      0.000       0.962       1.016
# lag2_dm_violent_crime_rate      -0.1563      0.013    -12.133      0.000      -0.182      -0.131
# ==============================================================================
# Omnibus:                     1125.278   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35083.022
# Skew:                          -0.810   Prob(JB):                         0.00
# Kurtosis:                      17.986   Cond. No.                         603.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.853
# Model:                               WLS   Adj. R-squared:                  0.853
# Method:                    Least Squares   F-statistic:                     7413.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -24286.
# No. Observations:                   3836   AIC:                         4.858e+04
# Df Residuals:                       3832   BIC:                         4.860e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -13.2717      2.095     -6.336      0.000     -17.379      -9.165
# dm_drug_tot_arrests_rate      -0.5247      0.067     -7.796      0.000      -0.657      -0.393
# lag1_dm_violent_crime_rate     0.9902      0.014     72.495      0.000       0.963       1.017
# lag2_dm_violent_crime_rate    -0.1557      0.013    -12.146      0.000      -0.181      -0.131
# ==============================================================================
# Omnibus:                     1201.440   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37251.117
# Skew:                          -0.860   Prob(JB):                         0.00
# Kurtosis:                      18.169   Cond. No.                         600.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.858
# Model:                               WLS   Adj. R-squared:                  0.858
# Method:                    Least Squares   F-statistic:                     6868.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -21629.
# No. Observations:                   3420   AIC:                         4.327e+04
# Df Residuals:                       3416   BIC:                         4.329e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -13.2343      2.239     -5.911      0.000     -17.624      -8.845
# dm_disorder_arrests_tot_index_rate    -0.0004      0.055     -0.007      0.994      -0.108       0.108
# lag1_dm_violent_crime_rate             0.9945      0.014     70.097      0.000       0.967       1.022
# lag2_dm_violent_crime_rate            -0.1622      0.013    -12.192      0.000      -0.188      -0.136
# ==============================================================================
# Omnibus:                     1004.880   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33062.733
# Skew:                          -0.742   Prob(JB):                         0.00
# Kurtosis:                      18.160   Cond. No.                         624.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.891
# Method:                    Least Squares   F-statistic:                 1.036e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -22317.
# No. Observations:                   3793   AIC:                         4.464e+04
# Df Residuals:                       3789   BIC:                         4.467e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -14.4586      1.456     -9.928      0.000     -17.314     -11.603
# dm_total_officers_rate       -21.0922      1.911    -11.038      0.000     -24.839     -17.346
# lag1_dm_violent_crime_rate     1.0316      0.016     65.576      0.000       1.001       1.062
# lag2_dm_violent_crime_rate    -0.0587      0.017     -3.550      0.000      -0.091      -0.026
# ==============================================================================
# Omnibus:                     1194.184   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           158576.542
# Skew:                           0.369   Prob(JB):                         0.00
# Kurtosis:                      34.668   Cond. No.                         561.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.891
# Method:                    Least Squares   F-statistic:                     9504.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:51   Log-Likelihood:                -20599.
# No. Observations:                   3499   AIC:                         4.121e+04
# Df Residuals:                       3495   BIC:                         4.123e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -11.4574      1.649     -6.949      0.000     -14.690      -8.225
# dm_prison_occupancy_count_rate    -1.0287      0.146     -7.032      0.000      -1.315      -0.742
# lag1_dm_violent_crime_rate         1.0479      0.017     62.446      0.000       1.015       1.081
# lag2_dm_violent_crime_rate        -0.0636      0.018     -3.610      0.000      -0.098      -0.029
# ==============================================================================
# Omnibus:                     1102.830   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           220428.966
# Skew:                           0.089   Prob(JB):                         0.00
# Kurtosis:                      41.883   Cond. No.                         460.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.887
# Model:                               WLS   Adj. R-squared:                  0.887
# Method:                    Least Squares   F-statistic:                     9614.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:52   Log-Likelihood:                -21733.
# No. Observations:                   3681   AIC:                         4.347e+04
# Df Residuals:                       3677   BIC:                         4.350e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -15.5929      1.550    -10.063      0.000     -18.631     -12.555
# dm_jail_occupancy_count_rate    -0.4742      0.234     -2.030      0.042      -0.932      -0.016
# lag1_dm_violent_crime_rate       1.0224      0.016     62.157      0.000       0.990       1.055
# lag2_dm_violent_crime_rate      -0.0522      0.017     -3.029      0.002      -0.086      -0.018
# ==============================================================================
# Omnibus:                     1217.791   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           224126.249
# Skew:                          -0.346   Prob(JB):                         0.00
# Kurtosis:                      41.221   Cond. No.                         439.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.888
# Model:                               WLS   Adj. R-squared:                  0.888
# Method:                    Least Squares   F-statistic:                 1.000e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:52   Log-Likelihood:                -22377.
# No. Observations:                   3793   AIC:                         4.476e+04
# Df Residuals:                       3789   BIC:                         4.479e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -15.8849      1.488    -10.674      0.000     -18.803     -12.967
# dm_drug_tot_arrests_rate      -0.0091      0.052     -0.175      0.861      -0.111       0.093
# lag1_dm_violent_crime_rate     1.0160      0.016     63.732      0.000       0.985       1.047
# lag2_dm_violent_crime_rate    -0.0461      0.017     -2.739      0.006      -0.079      -0.013
# ==============================================================================
# Omnibus:                     1303.033   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           244106.241
# Skew:                          -0.436   Prob(JB):                         0.00
# Kurtosis:                      42.291   Cond. No.                         428.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.883
# Model:                               WLS   Adj. R-squared:                  0.883
# Method:                    Least Squares   F-statistic:                     8430.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           16:58:52   Log-Likelihood:                -19813.
# No. Observations:                   3347   AIC:                         3.963e+04
# Df Residuals:                       3343   BIC:                         3.966e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -16.0970      1.684     -9.560      0.000     -19.398     -12.796
# dm_disorder_arrests_tot_index_rate    -0.0472      0.045     -1.056      0.291      -0.135       0.040
# lag1_dm_violent_crime_rate             1.0299      0.018     58.667      0.000       0.996       1.064
# lag2_dm_violent_crime_rate            -0.0594      0.019     -3.195      0.001      -0.096      -0.023
# ==============================================================================
# Omnibus:                     1153.830   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           229719.444
# Skew:                          -0.414   Prob(JB):                         0.00
# Kurtosis:                      43.578   Cond. No.                         444.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Medium Agencies - 90-15, 90-02, 03-15

# %%
#### read in the required files
medium_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_medium_cities_core_rates_dm_ref_pop_lag.csv')
medium_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_medium_cities_core_rates_dm_1990_2002_ref_pop_lag.csv')
medium_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_medium_cities_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %% [markdown]
# #### With control var

# %%
wols_lagged_control_uni(req_dfs=[medium_90_15, medium_90_02, medium_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['medium_90_15', 'medium_90_02', 'medium_03_15'])
# Out:
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.676
# Model:                               WLS   Adj. R-squared:                  0.676
# Method:                    Least Squares   F-statistic:                     7265.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -84009.
# No. Observations:                  13907   AIC:                         1.680e+05
# Df Residuals:                      13902   BIC:                         1.681e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3559.9267    271.612     13.107      0.000    3027.530    4092.323
# dm_total_officers_rate         2.4540      0.648      3.786      0.000       1.183       3.725
# lag1_dm_violent_crime_rate     0.7502      0.008     93.114      0.000       0.734       0.766
# lag2_dm_violent_crime_rate     0.0247      0.008      3.178      0.001       0.009       0.040
# YEAR                          -1.7821      0.136    -13.148      0.000      -2.048      -1.516
# ==============================================================================
# Omnibus:                     3640.108   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           253580.701
# Skew:                           0.290   Prob(JB):                         0.00
# Kurtosis:                      23.911   Cond. No.                     6.38e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.38e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.697
# Model:                               WLS   Adj. R-squared:                  0.697
# Method:                    Least Squares   F-statistic:                     6966.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -72516.
# No. Observations:                  12111   AIC:                         1.450e+05
# Df Residuals:                      12106   BIC:                         1.451e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3562.5945    288.164     12.363      0.000    2997.747    4127.442
# dm_prison_occupancy_count_rate     0.0160      0.077      0.209      0.835      -0.134       0.166
# lag1_dm_violent_crime_rate         0.7534      0.009     86.967      0.000       0.736       0.770
# lag2_dm_violent_crime_rate         0.0316      0.008      3.800      0.000       0.015       0.048
# YEAR                              -1.7837      0.144    -12.403      0.000      -2.066      -1.502
# ==============================================================================
# Omnibus:                     2473.115   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            90928.843
# Skew:                           0.046   Prob(JB):                         0.00
# Kurtosis:                      16.423   Cond. No.                     6.66e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.678
# Model:                               WLS   Adj. R-squared:                  0.678
# Method:                    Least Squares   F-statistic:                     7065.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -81192.
# No. Observations:                  13431   AIC:                         1.624e+05
# Df Residuals:                      13426   BIC:                         1.624e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3697.6443    284.919     12.978      0.000    3139.163    4256.126
# dm_jail_occupancy_count_rate     0.2893      0.113      2.564      0.010       0.068       0.511
# lag1_dm_violent_crime_rate       0.7540      0.008     91.985      0.000       0.738       0.770
# lag2_dm_violent_crime_rate       0.0223      0.008      2.828      0.005       0.007       0.038
# YEAR                            -1.8509      0.142    -13.017      0.000      -2.130      -1.572
# ==============================================================================
# Omnibus:                     3463.052   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           242329.382
# Skew:                           0.249   Prob(JB):                         0.00
# Kurtosis:                      23.803   Cond. No.                     6.54e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.54e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.677
# Model:                               WLS   Adj. R-squared:                  0.676
# Method:                    Least Squares   F-statistic:                     7271.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -84005.
# No. Observations:                  13907   AIC:                         1.680e+05
# Df Residuals:                      13902   BIC:                         1.681e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3624.9311    272.380     13.308      0.000    3091.030    4158.832
# dm_drug_tot_arrests_rate       0.1876      0.040      4.714      0.000       0.110       0.266
# lag1_dm_violent_crime_rate     0.7495      0.008     93.020      0.000       0.734       0.765
# lag2_dm_violent_crime_rate     0.0227      0.008      2.927      0.003       0.008       0.038
# YEAR                          -1.8146      0.136    -13.350      0.000      -2.081      -1.548
# ==============================================================================
# Omnibus:                     3681.472   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           254901.792
# Skew:                           0.319   Prob(JB):                         0.00
# Kurtosis:                      23.964   Cond. No.                     6.40e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.675
# Model:                               WLS   Adj. R-squared:                  0.675
# Method:                    Least Squares   F-statistic:                     6686.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -77459.
# No. Observations:                  12856   AIC:                         1.549e+05
# Df Residuals:                      12851   BIC:                         1.550e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3260.3505    292.644     11.141      0.000    2686.725    3833.976
# dm_disorder_arrests_tot_index_rate     0.0311      0.027      1.156      0.248      -0.022       0.084
# lag1_dm_violent_crime_rate             0.7466      0.008     89.540      0.000       0.730       0.763
# lag2_dm_violent_crime_rate             0.0266      0.008      3.320      0.001       0.011       0.042
# YEAR                                  -1.6319      0.146    -11.174      0.000      -1.918      -1.346
# ==============================================================================
# Omnibus:                     3594.033   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           280557.442
# Skew:                           0.377   Prob(JB):                         0.00
# Kurtosis:                      25.873   Cond. No.                     6.71e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.632
# Model:                               WLS   Adj. R-squared:                  0.632
# Method:                    Least Squares   F-statistic:                     2593.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -37447.
# No. Observations:                   6039   AIC:                         7.490e+04
# Df Residuals:                       6034   BIC:                         7.494e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1.077e+04   1005.613     10.707      0.000    8795.651    1.27e+04
# dm_total_officers_rate         0.6302      1.488      0.423      0.672      -2.288       3.548
# lag1_dm_violent_crime_rate     0.7079      0.012     59.105      0.000       0.684       0.731
# lag2_dm_violent_crime_rate     0.0133      0.011      1.204      0.229      -0.008       0.035
# YEAR                          -5.3905      0.503    -10.707      0.000      -6.377      -4.404
# ==============================================================================
# Omnibus:                     2132.954   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           138162.290
# Skew:                           0.848   Prob(JB):                         0.00
# Kurtosis:                      26.371   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.647
# Model:                               WLS   Adj. R-squared:                  0.647
# Method:                    Least Squares   F-statistic:                     2387.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -32053.
# No. Observations:                   5216   AIC:                         6.412e+04
# Df Residuals:                       5211   BIC:                         6.415e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       8724.5776   1087.651      8.021      0.000    6592.326    1.09e+04
# dm_prison_occupancy_count_rate    -0.4807      0.146     -3.288      0.001      -0.767      -0.194
# lag1_dm_violent_crime_rate         0.7009      0.013     54.159      0.000       0.675       0.726
# lag2_dm_violent_crime_rate         0.0257      0.012      2.166      0.030       0.002       0.049
# YEAR                              -4.3684      0.544     -8.023      0.000      -5.436      -3.301
# ==============================================================================
# Omnibus:                     1334.946   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33250.217
# Skew:                           0.649   Prob(JB):                         0.00
# Kurtosis:                      15.301   Cond. No.                     1.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.633
# Model:                               WLS   Adj. R-squared:                  0.632
# Method:                    Least Squares   F-statistic:                     2506.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -36190.
# No. Observations:                   5827   AIC:                         7.239e+04
# Df Residuals:                       5822   BIC:                         7.242e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.057e+04   1065.091      9.922      0.000    8479.444    1.27e+04
# dm_jail_occupancy_count_rate    -0.3149      0.217     -1.449      0.147      -0.741       0.111
# lag1_dm_violent_crime_rate       0.7098      0.012     58.174      0.000       0.686       0.734
# lag2_dm_violent_crime_rate       0.0108      0.011      0.956      0.339      -0.011       0.033
# YEAR                            -5.2907      0.533     -9.923      0.000      -6.336      -4.245
# ==============================================================================
# Omnibus:                     2037.179   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131473.305
# Skew:                           0.830   Prob(JB):                         0.00
# Kurtosis:                      26.211   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.633
# Model:                               WLS   Adj. R-squared:                  0.632
# Method:                    Least Squares   F-statistic:                     2598.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -37444.
# No. Observations:                   6039   AIC:                         7.490e+04
# Df Residuals:                       6034   BIC:                         7.493e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     1.1e+04   1008.405     10.911      0.000    9025.850     1.3e+04
# dm_drug_tot_arrests_rate       0.1753      0.068      2.581      0.010       0.042       0.308
# lag1_dm_violent_crime_rate     0.7069      0.012     59.026      0.000       0.683       0.730
# lag2_dm_violent_crime_rate     0.0110      0.011      0.995      0.320      -0.011       0.033
# YEAR                          -5.5082      0.505    -10.911      0.000      -6.498      -4.519
# ==============================================================================
# Omnibus:                     2146.039   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           137650.747
# Skew:                           0.862   Prob(JB):                         0.00
# Kurtosis:                      26.325   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.636
# Model:                               WLS   Adj. R-squared:                  0.636
# Method:                    Least Squares   F-statistic:                     2469.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -35086.
# No. Observations:                   5662   AIC:                         7.018e+04
# Df Residuals:                       5657   BIC:                         7.022e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.024e+04   1050.247      9.750      0.000    8180.711    1.23e+04
# dm_disorder_arrests_tot_index_rate     0.0039      0.043      0.090      0.928      -0.081       0.089
# lag1_dm_violent_crime_rate             0.7055      0.012     57.373      0.000       0.681       0.730
# lag2_dm_violent_crime_rate             0.0169      0.011      1.492      0.136      -0.005       0.039
# YEAR                                  -5.1261      0.526     -9.749      0.000      -6.157      -4.095
# ==============================================================================
# Omnibus:                     2109.720   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           145445.490
# Skew:                           0.925   Prob(JB):                         0.00
# Kurtosis:                      27.761   Cond. No.                     1.35e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.710
# Model:                               WLS   Adj. R-squared:                  0.710
# Method:                    Least Squares   F-statistic:                     4029.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -38446.
# No. Observations:                   6591   AIC:                         7.690e+04
# Df Residuals:                       6586   BIC:                         7.694e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3508.9291    659.660      5.319      0.000    2215.781    4802.077
# dm_total_officers_rate         2.3596      1.007      2.344      0.019       0.386       4.333
# lag1_dm_violent_crime_rate     0.8310      0.012     69.134      0.000       0.807       0.855
# lag2_dm_violent_crime_rate     0.0412      0.012      3.343      0.001       0.017       0.065
# YEAR                          -1.7528      0.328     -5.340      0.000      -2.396      -1.109
# ==============================================================================
# Omnibus:                     1673.278   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           128758.953
# Skew:                          -0.058   Prob(JB):                         0.00
# Kurtosis:                      24.653   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.733
# Model:                               WLS   Adj. R-squared:                  0.733
# Method:                    Least Squares   F-statistic:                     3961.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -33382.
# No. Observations:                   5782   AIC:                         6.677e+04
# Df Residuals:                       5777   BIC:                         6.681e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3706.6734    684.164      5.418      0.000    2365.456    5047.891
# dm_prison_occupancy_count_rate     0.0977      0.101      0.965      0.335      -0.101       0.296
# lag1_dm_violent_crime_rate         0.8474      0.013     65.134      0.000       0.822       0.873
# lag2_dm_violent_crime_rate         0.0398      0.013      2.974      0.003       0.014       0.066
# YEAR                              -1.8514      0.340     -5.439      0.000      -2.519      -1.184
# ==============================================================================
# Omnibus:                     1674.259   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            62933.890
# Skew:                          -0.691   Prob(JB):                         0.00
# Kurtosis:                      19.103   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.712
# Model:                               WLS   Adj. R-squared:                  0.712
# Method:                    Least Squares   F-statistic:                     3937.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -37148.
# No. Observations:                   6369   AIC:                         7.431e+04
# Df Residuals:                       6364   BIC:                         7.434e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3273.3462    671.401      4.875      0.000    1957.174    4589.519
# dm_jail_occupancy_count_rate     0.6353      0.137      4.625      0.000       0.366       0.905
# lag1_dm_violent_crime_rate       0.8285      0.012     67.686      0.000       0.804       0.852
# lag2_dm_violent_crime_rate       0.0463      0.013      3.677      0.000       0.022       0.071
# YEAR                            -1.6361      0.334     -4.898      0.000      -2.291      -0.981
# ==============================================================================
# Omnibus:                     1643.213   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           108012.699
# Skew:                          -0.270   Prob(JB):                         0.00
# Kurtosis:                      23.167   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.711
# Model:                               WLS   Adj. R-squared:                  0.711
# Method:                    Least Squares   F-statistic:                     4046.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -38436.
# No. Observations:                   6591   AIC:                         7.688e+04
# Df Residuals:                       6586   BIC:                         7.692e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3092.3463    664.138      4.656      0.000    1790.421    4394.271
# dm_drug_tot_arrests_rate       0.2464      0.049      5.015      0.000       0.150       0.343
# lag1_dm_violent_crime_rate     0.8287      0.012     68.982      0.000       0.805       0.852
# lag2_dm_violent_crime_rate     0.0396      0.012      3.212      0.001       0.015       0.064
# YEAR                          -1.5458      0.330     -4.678      0.000      -2.194      -0.898
# ==============================================================================
# Omnibus:                     1667.095   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           126887.612
# Skew:                          -0.047   Prob(JB):                         0.00
# Kurtosis:                      24.495   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.701
# Model:                               WLS   Adj. R-squared:                  0.701
# Method:                    Least Squares   F-statistic:                     3541.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:47   Log-Likelihood:                -35114.
# No. Observations:                   6044   AIC:                         7.024e+04
# Df Residuals:                       6039   BIC:                         7.027e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3182.9499    695.022      4.580      0.000    1820.459    4545.441
# dm_disorder_arrests_tot_index_rate     0.0308      0.035      0.884      0.377      -0.038       0.099
# lag1_dm_violent_crime_rate             0.8254      0.013     65.697      0.000       0.801       0.850
# lag2_dm_violent_crime_rate             0.0453      0.013      3.488      0.000       0.020       0.071
# YEAR                                  -1.5898      0.346     -4.597      0.000      -2.268      -0.912
# ==============================================================================
# Omnibus:                     1600.522   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           147737.188
# Skew:                          -0.005   Prob(JB):                         0.00
# Kurtosis:                      27.221   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Without control var

# %%
wols_lagged_control_uni(req_dfs=[medium_90_15, medium_90_02, medium_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       weights_var='fnl_population_wt',
                       dataset_names=['medium_90_15', 'medium_90_02', 'medium_03_15'])
# Out:
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.672
# Model:                               WLS   Adj. R-squared:                  0.672
# Method:                    Least Squares   F-statistic:                     9511.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:50   Log-Likelihood:                -84095.
# No. Observations:                  13907   AIC:                         1.682e+05
# Df Residuals:                      13903   BIC:                         1.682e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -11.2030      0.863    -12.988      0.000     -12.894      -9.512
# dm_total_officers_rate         1.9351      0.651      2.972      0.003       0.659       3.211
# lag1_dm_violent_crime_rate     0.7662      0.008     95.623      0.000       0.751       0.782
# lag2_dm_violent_crime_rate     0.0363      0.008      4.686      0.000       0.021       0.052
# ==============================================================================
# Omnibus:                     3606.846   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           256831.441
# Skew:                           0.254   Prob(JB):                         0.00
# Kurtosis:                      24.047   Cond. No.                         250.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.693
# Model:                               WLS   Adj. R-squared:                  0.693
# Method:                    Least Squares   F-statistic:                     9122.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -72592.
# No. Observations:                  12111   AIC:                         1.452e+05
# Df Residuals:                      12107   BIC:                         1.452e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -11.5762      0.881    -13.143      0.000     -13.303      -9.850
# dm_prison_occupancy_count_rate    -0.2197      0.075     -2.946      0.003      -0.366      -0.073
# lag1_dm_violent_crime_rate         0.7694      0.009     89.235      0.000       0.752       0.786
# lag2_dm_violent_crime_rate         0.0430      0.008      5.170      0.000       0.027       0.059
# ==============================================================================
# Omnibus:                     2501.809   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94913.086
# Skew:                           0.058   Prob(JB):                         0.00
# Kurtosis:                      16.714   Cond. No.                         248.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.674
# Model:                               WLS   Adj. R-squared:                  0.674
# Method:                    Least Squares   F-statistic:                     9248.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -81276.
# No. Observations:                  13431   AIC:                         1.626e+05
# Df Residuals:                      13427   BIC:                         1.626e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -11.1188      0.884    -12.578      0.000     -12.851      -9.386
# dm_jail_occupancy_count_rate    -0.0490      0.110     -0.443      0.658      -0.266       0.168
# lag1_dm_violent_crime_rate       0.7698      0.008     94.361      0.000       0.754       0.786
# lag2_dm_violent_crime_rate       0.0335      0.008      4.238      0.000       0.018       0.049
# ==============================================================================
# Omnibus:                     3482.378   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           252442.465
# Skew:                           0.241   Prob(JB):                         0.00
# Kurtosis:                      24.233   Cond. No.                         252.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.672
# Model:                               WLS   Adj. R-squared:                  0.672
# Method:                    Least Squares   F-statistic:                     9514.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -84093.
# No. Observations:                  13907   AIC:                         1.682e+05
# Df Residuals:                      13903   BIC:                         1.682e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -11.2796      0.863    -13.070      0.000     -12.971      -9.588
# dm_drug_tot_arrests_rate       0.1348      0.040      3.382      0.001       0.057       0.213
# lag1_dm_violent_crime_rate     0.7660      0.008     95.590      0.000       0.750       0.782
# lag2_dm_violent_crime_rate     0.0351      0.008      4.522      0.000       0.020       0.050
# ==============================================================================
# Omnibus:                     3636.522   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           257937.025
# Skew:                           0.277   Prob(JB):                         0.00
# Kurtosis:                      24.091   Cond. No.                         250.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.672
# Model:                               WLS   Adj. R-squared:                  0.672
# Method:                    Least Squares   F-statistic:                     8788.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -77521.
# No. Observations:                  12856   AIC:                         1.550e+05
# Df Residuals:                      12852   BIC:                         1.551e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -9.5262      0.884    -10.776      0.000     -11.259      -7.793
# dm_disorder_arrests_tot_index_rate     0.1320      0.025      5.183      0.000       0.082       0.182
# lag1_dm_violent_crime_rate             0.7598      0.008     91.635      0.000       0.744       0.776
# lag2_dm_violent_crime_rate             0.0357      0.008      4.461      0.000       0.020       0.051
# ==============================================================================
# Omnibus:                     3561.429   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           283811.762
# Skew:                           0.348   Prob(JB):                         0.00
# Kurtosis:                      26.008   Cond. No.                         248.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.625
# Model:                               WLS   Adj. R-squared:                  0.625
# Method:                    Least Squares   F-statistic:                     3357.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -37504.
# No. Observations:                   6039   AIC:                         7.502e+04
# Df Residuals:                       6035   BIC:                         7.504e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.0356      1.632     -0.022      0.983      -3.236       3.165
# dm_total_officers_rate        -0.3062      1.500     -0.204      0.838      -3.246       2.634
# lag1_dm_violent_crime_rate     0.7293      0.012     61.194      0.000       0.706       0.753
# lag2_dm_violent_crime_rate     0.0168      0.011      1.501      0.133      -0.005       0.039
# ==============================================================================
# Omnibus:                     1979.455   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           135893.078
# Skew:                           0.700   Prob(JB):                         0.00
# Kurtosis:                      26.197   Cond. No.                         327.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.643
# Model:                               WLS   Adj. R-squared:                  0.642
# Method:                    Least Squares   F-statistic:                     3123.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -32085.
# No. Observations:                   5216   AIC:                         6.418e+04
# Df Residuals:                       5212   BIC:                         6.420e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -1.9722      1.689     -1.168      0.243      -5.283       1.339
# dm_prison_occupancy_count_rate    -0.8756      0.138     -6.323      0.000      -1.147      -0.604
# lag1_dm_violent_crime_rate         0.7154      0.013     55.500      0.000       0.690       0.741
# lag2_dm_violent_crime_rate         0.0294      0.012      2.464      0.014       0.006       0.053
# ==============================================================================
# Omnibus:                     1279.782   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33386.902
# Skew:                           0.578   Prob(JB):                         0.00
# Kurtosis:                      15.340   Cond. No.                         324.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.626
# Model:                               WLS   Adj. R-squared:                  0.626
# Method:                    Least Squares   F-statistic:                     3253.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -36238.
# No. Observations:                   5827   AIC:                         7.248e+04
# Df Residuals:                       5823   BIC:                         7.251e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -1.1236      1.707     -0.658      0.510      -4.469       2.222
# dm_jail_occupancy_count_rate    -0.8527      0.212     -4.018      0.000      -1.269      -0.437
# lag1_dm_violent_crime_rate       0.7283      0.012     59.902      0.000       0.705       0.752
# lag2_dm_violent_crime_rate       0.0146      0.011      1.289      0.197      -0.008       0.037
# ==============================================================================
# Omnibus:                     1885.420   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           129682.721
# Skew:                           0.676   Prob(JB):                         0.00
# Kurtosis:                      26.072   Cond. No.                         333.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.625
# Model:                               WLS   Adj. R-squared:                  0.625
# Method:                    Least Squares   F-statistic:                     3358.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -37503.
# No. Observations:                   6039   AIC:                         7.501e+04
# Df Residuals:                       6035   BIC:                         7.504e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.2512      1.638      0.153      0.878      -2.961       3.463
# dm_drug_tot_arrests_rate       0.1012      0.068      1.483      0.138      -0.033       0.235
# lag1_dm_violent_crime_rate     0.7290      0.012     61.174      0.000       0.706       0.752
# lag2_dm_violent_crime_rate     0.0155      0.011      1.387      0.166      -0.006       0.037
# ==============================================================================
# Omnibus:                     1985.509   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           135530.396
# Skew:                           0.707   Prob(JB):                         0.00
# Kurtosis:                      26.165   Cond. No.                         325.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.630
# Model:                               WLS   Adj. R-squared:                  0.630
# Method:                    Least Squares   F-statistic:                     3208.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -35133.
# No. Observations:                   5662   AIC:                         7.027e+04
# Df Residuals:                       5658   BIC:                         7.030e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.3364      1.718      0.196      0.845      -3.031       3.704
# dm_disorder_arrests_tot_index_rate     0.0903      0.043      2.115      0.035       0.007       0.174
# lag1_dm_violent_crime_rate             0.7254      0.012     59.326      0.000       0.701       0.749
# lag2_dm_violent_crime_rate             0.0195      0.011      1.708      0.088      -0.003       0.042
# ==============================================================================
# Omnibus:                     1979.374   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           143559.346
# Skew:                           0.795   Prob(JB):                         0.00
# Kurtosis:                      27.617   Cond. No.                         334.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.709
# Model:                               WLS   Adj. R-squared:                  0.709
# Method:                    Least Squares   F-statistic:                     5341.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -38460.
# No. Observations:                   6591   AIC:                         7.693e+04
# Df Residuals:                       6587   BIC:                         7.696e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -13.8140      1.080    -12.794      0.000     -15.931     -11.697
# dm_total_officers_rate         2.3944      1.009      2.374      0.018       0.417       4.372
# lag1_dm_violent_crime_rate     0.8378      0.012     69.956      0.000       0.814       0.861
# lag2_dm_violent_crime_rate     0.0424      0.012      3.428      0.001       0.018       0.067
# ==============================================================================
# Omnibus:                     1670.291   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           128162.915
# Skew:                          -0.045   Prob(JB):                         0.00
# Kurtosis:                      24.603   Cond. No.                         224.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.731
# Model:                               WLS   Adj. R-squared:                  0.731
# Method:                    Least Squares   F-statistic:                     5245.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -33397.
# No. Observations:                   5782   AIC:                         6.680e+04
# Df Residuals:                       5778   BIC:                         6.683e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -14.5105      1.164    -12.471      0.000     -16.791     -12.230
# dm_prison_occupancy_count_rate     0.1859      0.100      1.857      0.063      -0.010       0.382
# lag1_dm_violent_crime_rate         0.8549      0.013     65.913      0.000       0.829       0.880
# lag2_dm_violent_crime_rate         0.0404      0.013      3.009      0.003       0.014       0.067
# ==============================================================================
# Omnibus:                     1668.783   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            62797.372
# Skew:                          -0.686   Prob(JB):                         0.00
# Kurtosis:                      19.087   Cond. No.                         236.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.711
# Model:                               WLS   Adj. R-squared:                  0.711
# Method:                    Least Squares   F-statistic:                     5222.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -37160.
# No. Observations:                   6369   AIC:                         7.433e+04
# Df Residuals:                       6365   BIC:                         7.435e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -15.0892      1.137    -13.270      0.000     -17.318     -12.860
# dm_jail_occupancy_count_rate     0.6696      0.137      4.872      0.000       0.400       0.939
# lag1_dm_violent_crime_rate       0.8347      0.012     68.434      0.000       0.811       0.859
# lag2_dm_violent_crime_rate       0.0475      0.013      3.770      0.000       0.023       0.072
# ==============================================================================
# Omnibus:                     1638.500   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           106862.747
# Skew:                          -0.268   Prob(JB):                         0.00
# Kurtosis:                      23.060   Cond. No.                         231.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.710
# Model:                               WLS   Adj. R-squared:                  0.710
# Method:                    Least Squares   F-statistic:                     5371.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -38447.
# No. Observations:                   6591   AIC:                         7.690e+04
# Df Residuals:                       6587   BIC:                         7.693e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -14.6317      1.089    -13.434      0.000     -16.767     -12.497
# dm_drug_tot_arrests_rate       0.2758      0.049      5.651      0.000       0.180       0.371
# lag1_dm_violent_crime_rate     0.8342      0.012     69.679      0.000       0.811       0.858
# lag2_dm_violent_crime_rate     0.0404      0.012      3.270      0.001       0.016       0.065
# ==============================================================================
# Omnibus:                     1664.152   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           126127.818
# Skew:                          -0.036   Prob(JB):                         0.00
# Kurtosis:                      24.431   Cond. No.                         224.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.700
# Model:                               WLS   Adj. R-squared:                  0.700
# Method:                    Least Squares   F-statistic:                     4699.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:03:51   Log-Likelihood:                -35125.
# No. Observations:                   6044   AIC:                         7.026e+04
# Df Residuals:                       6040   BIC:                         7.028e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -11.7458      1.164    -10.087      0.000     -14.029      -9.463
# dm_disorder_arrests_tot_index_rate     0.0719      0.034      2.131      0.033       0.006       0.138
# lag1_dm_violent_crime_rate             0.8311      0.013     66.375      0.000       0.807       0.856
# lag2_dm_violent_crime_rate             0.0464      0.013      3.563      0.000       0.021       0.072
# ==============================================================================
# Omnibus:                     1600.976   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           147875.371
# Skew:                           0.014   Prob(JB):                         0.00
# Kurtosis:                      27.232   Cond. No.                         224.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Small Agencies - 90-15, 90-02, 03-15

# %%
#### read in the required files
small_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_small_cities_core_rates_dm_ref_pop_lag.csv')
small_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_small_cities_core_rates_dm_1990_2002_ref_pop_lag.csv')
small_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_small_cities_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %% [markdown]
# #### With control var

# %%
wols_lagged_control_uni(req_dfs=[small_90_15, small_90_02, small_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['small_90_15', 'small_90_02', 'small_03_15'])
# Out:
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.497
# Model:                               WLS   Adj. R-squared:                  0.497
# Method:                    Least Squares   F-statistic:                 1.936e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -4.9145e+05
# No. Observations:                  78345   AIC:                         9.829e+05
# Df Residuals:                      78340   BIC:                         9.829e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3317.4938    132.031     25.127      0.000    3058.713    3576.274
# dm_total_officers_rate         6.3086      1.178      5.356      0.000       4.000       8.617
# lag1_dm_violent_crime_rate     0.6250      0.003    181.334      0.000       0.618       0.632
# lag2_dm_violent_crime_rate     0.0528      0.003     15.803      0.000       0.046       0.059
# YEAR                          -1.6587      0.066    -25.177      0.000      -1.788      -1.530
# ==============================================================================
# Omnibus:                    32045.859   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6758813.005
# Skew:                           0.821   Prob(JB):                         0.00
# Kurtosis:                      48.473   Cond. No.                     6.08e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.516
# Model:                               WLS   Adj. R-squared:                  0.516
# Method:                    Least Squares   F-statistic:                 1.816e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -4.2524e+05
# No. Observations:                  68088   AIC:                         8.505e+05
# Df Residuals:                      68083   BIC:                         8.505e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2644.2524    147.272     17.955      0.000    2355.600    2932.904
# dm_prison_occupancy_count_rate    -0.5782      0.042    -13.635      0.000      -0.661      -0.495
# lag1_dm_violent_crime_rate         0.6310      0.004    170.587      0.000       0.624       0.638
# lag2_dm_violent_crime_rate         0.0572      0.004     15.970      0.000       0.050       0.064
# YEAR                              -1.3226      0.073    -17.997      0.000      -1.467      -1.179
# ==============================================================================
# Omnibus:                    25748.352   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6655565.466
# Skew:                           0.593   Prob(JB):                         0.00
# Kurtosis:                      51.421   Cond. No.                     6.49e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.497
# Model:                               WLS   Adj. R-squared:                  0.497
# Method:                    Least Squares   F-statistic:                 1.878e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -4.7679e+05
# No. Observations:                  75944   AIC:                         9.536e+05
# Df Residuals:                      75939   BIC:                         9.536e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3106.5229    140.418     22.123      0.000    2831.305    3381.741
# dm_jail_occupancy_count_rate    -0.1903      0.047     -4.057      0.000      -0.282      -0.098
# lag1_dm_violent_crime_rate       0.6254      0.003    178.716      0.000       0.619       0.632
# lag2_dm_violent_crime_rate       0.0531      0.003     15.683      0.000       0.046       0.060
# YEAR                            -1.5533      0.070    -22.168      0.000      -1.691      -1.416
# ==============================================================================
# Omnibus:                    30245.224   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6241646.347
# Skew:                           0.770   Prob(JB):                         0.00
# Kurtosis:                      47.386   Cond. No.                     6.33e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.33e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.498
# Model:                               WLS   Adj. R-squared:                  0.498
# Method:                    Least Squares   F-statistic:                 1.941e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -4.9140e+05
# No. Observations:                  78345   AIC:                         9.828e+05
# Df Residuals:                      78340   BIC:                         9.829e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3458.2997    132.751     26.051      0.000    3198.109    3718.490
# dm_drug_tot_arrests_rate       0.2071      0.019     11.018      0.000       0.170       0.244
# lag1_dm_violent_crime_rate     0.6241      0.003    181.116      0.000       0.617       0.631
# lag2_dm_violent_crime_rate     0.0521      0.003     15.625      0.000       0.046       0.059
# YEAR                          -1.7290      0.066    -26.102      0.000      -1.859      -1.599
# ==============================================================================
# Omnibus:                    32312.862   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6776734.985
# Skew:                           0.840   Prob(JB):                         0.00
# Kurtosis:                      48.532   Cond. No.                     6.11e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.506
# Model:                               WLS   Adj. R-squared:                  0.506
# Method:                    Least Squares   F-statistic:                 1.870e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -4.5665e+05
# No. Observations:                  73066   AIC:                         9.133e+05
# Df Residuals:                      73061   BIC:                         9.134e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2481.5012    140.409     17.673      0.000    2206.301    2756.702
# dm_disorder_arrests_tot_index_rate     0.1734      0.012     14.121      0.000       0.149       0.197
# lag1_dm_violent_crime_rate             0.6320      0.004    177.129      0.000       0.625       0.639
# lag2_dm_violent_crime_rate             0.0492      0.003     14.281      0.000       0.042       0.056
# YEAR                                  -1.2408      0.070    -17.708      0.000      -1.378      -1.103
# ==============================================================================
# Omnibus:                    31421.937   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6968101.179
# Skew:                           0.916   Prob(JB):                         0.00
# Kurtosis:                      50.806   Cond. No.                     6.38e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.38e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.452
# Model:                               WLS   Adj. R-squared:                  0.452
# Method:                    Least Squares   F-statistic:                     6772.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.1151e+05
# No. Observations:                  32784   AIC:                         4.230e+05
# Df Residuals:                      32779   BIC:                         4.231e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   9578.4711    523.264     18.305      0.000    8552.855    1.06e+04
# dm_total_officers_rate         3.6334      2.306      1.576      0.115      -0.886       8.153
# lag1_dm_violent_crime_rate     0.5851      0.005    110.001      0.000       0.575       0.595
# lag2_dm_violent_crime_rate     0.0396      0.005      7.923      0.000       0.030       0.049
# YEAR                          -4.7934      0.262    -18.297      0.000      -5.307      -4.280
# ==============================================================================
# Omnibus:                    16741.110   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2932606.036
# Skew:                           1.380   Prob(JB):                         0.00
# Kurtosis:                      49.252   Cond. No.                     1.30e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.474
# Model:                               WLS   Adj. R-squared:                  0.474
# Method:                    Least Squares   F-statistic:                     6343.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -1.8100e+05
# No. Observations:                  28166   AIC:                         3.620e+05
# Df Residuals:                      28161   BIC:                         3.621e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       7594.0888    575.020     13.207      0.000    6467.021    8721.157
# dm_prison_occupancy_count_rate    -0.9059      0.081    -11.175      0.000      -1.065      -0.747
# lag1_dm_violent_crime_rate         0.5909      0.006    103.224      0.000       0.580       0.602
# lag2_dm_violent_crime_rate         0.0391      0.005      7.269      0.000       0.029       0.050
# YEAR                              -3.8017      0.288    -13.207      0.000      -4.366      -3.238
# ==============================================================================
# Omnibus:                    12571.137   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2851417.452
# Skew:                           0.990   Prob(JB):                         0.00
# Kurtosis:                      52.252   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.454
# Model:                               WLS   Adj. R-squared:                  0.454
# Method:                    Least Squares   F-statistic:                     6609.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.0497e+05
# No. Observations:                  31744   AIC:                         4.099e+05
# Df Residuals:                      31739   BIC:                         4.100e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     8966.3636    541.045     16.572      0.000    7905.894       1e+04
# dm_jail_occupancy_count_rate    -0.5421      0.091     -5.977      0.000      -0.720      -0.364
# lag1_dm_violent_crime_rate       0.5828      0.005    108.197      0.000       0.572       0.593
# lag2_dm_violent_crime_rate       0.0407      0.005      8.035      0.000       0.031       0.051
# YEAR                            -4.4877      0.271    -16.568      0.000      -5.019      -3.957
# ==============================================================================
# Omnibus:                    15222.832   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2628046.930
# Skew:                           1.227   Prob(JB):                         0.00
# Kurtosis:                      47.507   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.453
# Model:                               WLS   Adj. R-squared:                  0.453
# Method:                    Least Squares   F-statistic:                     6783.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.1150e+05
# No. Observations:                  32784   AIC:                         4.230e+05
# Df Residuals:                      32779   BIC:                         4.231e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   9854.6725    522.224     18.871      0.000    8831.095    1.09e+04
# dm_drug_tot_arrests_rate       0.1763      0.034      5.151      0.000       0.109       0.243
# lag1_dm_violent_crime_rate     0.5846      0.005    109.937      0.000       0.574       0.595
# lag2_dm_violent_crime_rate     0.0384      0.005      7.672      0.000       0.029       0.048
# YEAR                          -4.9315      0.261    -18.861      0.000      -5.444      -4.419
# ==============================================================================
# Omnibus:                    16882.836   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2939779.384
# Skew:                           1.403   Prob(JB):                         0.00
# Kurtosis:                      49.306   Cond. No.                     1.30e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.470
# Model:                               WLS   Adj. R-squared:                  0.470
# Method:                    Least Squares   F-statistic:                     6856.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -1.9910e+05
# No. Observations:                  30946   AIC:                         3.982e+05
# Df Residuals:                      30941   BIC:                         3.982e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           8490.1376    529.537     16.033      0.000    7452.224    9528.051
# dm_disorder_arrests_tot_index_rate     0.2095      0.020     10.230      0.000       0.169       0.250
# lag1_dm_violent_crime_rate             0.5989      0.005    110.398      0.000       0.588       0.610
# lag2_dm_violent_crime_rate             0.0331      0.005      6.518      0.000       0.023       0.043
# YEAR                                  -4.2495      0.265    -16.028      0.000      -4.769      -3.730
# ==============================================================================
# Omnibus:                    15649.786   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2896043.271
# Skew:                           1.341   Prob(JB):                         0.00
# Kurtosis:                      50.316   Cond. No.                     1.30e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.570
# Model:                               WLS   Adj. R-squared:                  0.570
# Method:                    Least Squares   F-statistic:                 1.259e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.3037e+05
# No. Observations:                  37988   AIC:                         4.607e+05
# Df Residuals:                      37983   BIC:                         4.608e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   2602.6873    329.089      7.909      0.000    1957.664    3247.711
# dm_total_officers_rate         8.1776      1.285      6.365      0.000       5.659      10.696
# lag1_dm_violent_crime_rate     0.7019      0.005    138.733      0.000       0.692       0.712
# lag2_dm_violent_crime_rate     0.0982      0.005     18.889      0.000       0.088       0.108
# YEAR                          -1.3003      0.164     -7.942      0.000      -1.621      -0.979
# ==============================================================================
# Omnibus:                    12199.024   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1723372.803
# Skew:                           0.435   Prob(JB):                         0.00
# Kurtosis:                      35.985   Cond. No.                     1.31e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.581
# Model:                               WLS   Adj. R-squared:                  0.581
# Method:                    Least Squares   F-statistic:                 1.155e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.0166e+05
# No. Observations:                  33373   AIC:                         4.033e+05
# Df Residuals:                      33368   BIC:                         4.034e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3205.2625    351.037      9.131      0.000    2517.218    3893.307
# dm_prison_occupancy_count_rate    -0.2955      0.048     -6.139      0.000      -0.390      -0.201
# lag1_dm_violent_crime_rate         0.6991      0.005    129.346      0.000       0.688       0.710
# lag2_dm_violent_crime_rate         0.1125      0.006     20.297      0.000       0.102       0.123
# YEAR                              -1.5996      0.175     -9.159      0.000      -1.942      -1.257
# ==============================================================================
# Omnibus:                    11010.016   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1496449.725
# Skew:                           0.507   Prob(JB):                         0.00
# Kurtosis:                      35.789   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.569
# Model:                               WLS   Adj. R-squared:                  0.569
# Method:                    Least Squares   F-statistic:                 1.215e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.2367e+05
# No. Observations:                  36847   AIC:                         4.474e+05
# Df Residuals:                      36842   BIC:                         4.474e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2761.6076    335.473      8.232      0.000    2104.072    3419.143
# dm_jail_occupancy_count_rate     0.0464      0.051      0.906      0.365      -0.054       0.147
# lag1_dm_violent_crime_rate       0.7017      0.005    136.640      0.000       0.692       0.712
# lag2_dm_violent_crime_rate       0.0994      0.005     18.844      0.000       0.089       0.110
# YEAR                            -1.3793      0.167     -8.264      0.000      -1.706      -1.052
# ==============================================================================
# Omnibus:                    12085.848   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1619987.063
# Skew:                           0.500   Prob(JB):                         0.00
# Kurtosis:                      35.468   Cond. No.                     1.31e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.570
# Model:                               WLS   Adj. R-squared:                  0.570
# Method:                    Least Squares   F-statistic:                 1.261e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.3035e+05
# No. Observations:                  37988   AIC:                         4.607e+05
# Df Residuals:                      37983   BIC:                         4.607e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   2495.5143    329.393      7.576      0.000    1849.896    3141.133
# dm_drug_tot_arrests_rate       0.1992      0.023      8.833      0.000       0.155       0.243
# lag1_dm_violent_crime_rate     0.7007      0.005    138.463      0.000       0.691       0.711
# lag2_dm_violent_crime_rate     0.0983      0.005     18.932      0.000       0.088       0.109
# YEAR                          -1.2473      0.164     -7.611      0.000      -1.568      -0.926
# ==============================================================================
# Omnibus:                    12211.727   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1718482.088
# Skew:                           0.439   Prob(JB):                         0.00
# Kurtosis:                      35.938   Cond. No.                     1.31e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.564
# Model:                               WLS   Adj. R-squared:                  0.564
# Method:                    Least Squares   F-statistic:                 1.140e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -2.1269e+05
# No. Observations:                  35247   AIC:                         4.254e+05
# Df Residuals:                      35242   BIC:                         4.254e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1824.0441    339.107      5.379      0.000    1159.384    2488.704
# dm_disorder_arrests_tot_index_rate     0.0974      0.015      6.342      0.000       0.067       0.127
# lag1_dm_violent_crime_rate             0.7003      0.005    132.181      0.000       0.690       0.711
# lag2_dm_violent_crime_rate             0.0953      0.005     17.530      0.000       0.085       0.106
# YEAR                                  -0.9118      0.169     -5.404      0.000      -1.243      -0.581
# ==============================================================================
# Omnibus:                    12466.449   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1852054.060
# Skew:                           0.620   Prob(JB):                         0.00
# Kurtosis:                      38.490   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Without control var

# %%
wols_lagged_control_uni(req_dfs=[small_90_15, small_90_02, small_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars=dm_ind_vars_rates,
                       weights_var='fnl_population_wt',
                       dataset_names=['small_90_15', 'small_90_02', 'small_03_15'])
# Out:
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.493
# Model:                               WLS   Adj. R-squared:                  0.493
# Method:                    Least Squares   F-statistic:                 2.540e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:14   Log-Likelihood:            -4.9176e+05
# No. Observations:                  78345   AIC:                         9.835e+05
# Df Residuals:                      78341   BIC:                         9.836e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -6.6397      0.438    -15.168      0.000      -7.498      -5.782
# dm_total_officers_rate         4.0427      1.179      3.428      0.001       1.732       6.354
# lag1_dm_violent_crime_rate     0.6351      0.003    184.776      0.000       0.628       0.642
# lag2_dm_violent_crime_rate     0.0602      0.003     18.025      0.000       0.054       0.067
# ==============================================================================
# Omnibus:                    32304.234   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6964350.473
# Skew:                           0.832   Prob(JB):                         0.00
# Kurtosis:                      49.159   Cond. No.                         633.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.514
# Model:                               WLS   Adj. R-squared:                  0.514
# Method:                    Least Squares   F-statistic:                 2.399e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -4.2540e+05
# No. Observations:                  68088   AIC:                         8.508e+05
# Df Residuals:                      68084   BIC:                         8.508e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -6.1995      0.458    -13.534      0.000      -7.097      -5.302
# dm_prison_occupancy_count_rate    -0.8352      0.040    -20.866      0.000      -0.914      -0.757
# lag1_dm_violent_crime_rate         0.6373      0.004    172.687      0.000       0.630       0.645
# lag2_dm_violent_crime_rate         0.0627      0.004     17.538      0.000       0.056       0.070
# ==============================================================================
# Omnibus:                    25903.504   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6787193.925
# Skew:                           0.602   Prob(JB):                         0.00
# Kurtosis:                      51.897   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.494
# Model:                               WLS   Adj. R-squared:                  0.494
# Method:                    Least Squares   F-statistic:                 2.471e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -4.7704e+05
# No. Observations:                  75944   AIC:                         9.541e+05
# Df Residuals:                      75940   BIC:                         9.541e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -6.2595      0.448    -13.984      0.000      -7.137      -5.382
# dm_jail_occupancy_count_rate    -0.4896      0.045    -10.861      0.000      -0.578      -0.401
# lag1_dm_violent_crime_rate       0.6334      0.003    181.416      0.000       0.627       0.640
# lag2_dm_violent_crime_rate       0.0594      0.003     17.546      0.000       0.053       0.066
# ==============================================================================
# Omnibus:                    30321.940   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6358457.118
# Skew:                           0.771   Prob(JB):                         0.00
# Kurtosis:                      47.800   Cond. No.                         237.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.493
# Model:                               WLS   Adj. R-squared:                  0.493
# Method:                    Least Squares   F-statistic:                 2.543e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -4.9174e+05
# No. Observations:                  78345   AIC:                         9.835e+05
# Df Residuals:                      78341   BIC:                         9.835e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -6.7604      0.438    -15.435      0.000      -7.619      -5.902
# dm_drug_tot_arrests_rate       0.1417      0.019      7.573      0.000       0.105       0.178
# lag1_dm_violent_crime_rate     0.6347      0.003    184.714      0.000       0.628       0.641
# lag2_dm_violent_crime_rate     0.0599      0.003     17.960      0.000       0.053       0.066
# ==============================================================================
# Omnibus:                    32501.661   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6983230.117
# Skew:                           0.846   Prob(JB):                         0.00
# Kurtosis:                      49.221   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.504
# Model:                               WLS   Adj. R-squared:                  0.504
# Method:                    Least Squares   F-statistic:                 2.472e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -4.5681e+05
# No. Observations:                  73066   AIC:                         9.136e+05
# Df Residuals:                      73062   BIC:                         9.137e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -4.9066      0.443    -11.076      0.000      -5.775      -4.038
# dm_disorder_arrests_tot_index_rate     0.2454      0.012     21.128      0.000       0.223       0.268
# lag1_dm_violent_crime_rate             0.6374      0.004    178.937      0.000       0.630       0.644
# lag2_dm_violent_crime_rate             0.0540      0.003     15.700      0.000       0.047       0.061
# ==============================================================================
# Omnibus:                    31786.694   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7133364.688
# Skew:                           0.938   Prob(JB):                         0.00
# Kurtosis:                      51.369   Cond. No.                         232.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.447
# Model:                               WLS   Adj. R-squared:                  0.447
# Method:                    Least Squares   F-statistic:                     8828.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.1168e+05
# No. Observations:                  32784   AIC:                         4.234e+05
# Df Residuals:                      32780   BIC:                         4.234e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.5409      0.830      5.472      0.000       2.914       6.168
# dm_total_officers_rate        -3.2187      2.287     -1.408      0.159      -7.701       1.263
# lag1_dm_violent_crime_rate     0.5960      0.005    112.209      0.000       0.586       0.606
# lag2_dm_violent_crime_rate     0.0414      0.005      8.231      0.000       0.032       0.051
# ==============================================================================
# Omnibus:                    16542.389   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2995379.235
# Skew:                           1.341   Prob(JB):                         0.00
# Kurtosis:                      49.751   Cond. No.                         814.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.471
# Model:                               WLS   Adj. R-squared:                  0.471
# Method:                    Least Squares   F-statistic:                     8348.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -1.8109e+05
# No. Observations:                  28166   AIC:                         3.622e+05
# Df Residuals:                      28162   BIC:                         3.622e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -0.1580      0.909     -0.174      0.862      -1.940       1.624
# dm_prison_occupancy_count_rate    -1.2582      0.077    -16.387      0.000      -1.409      -1.108
# lag1_dm_violent_crime_rate         0.5976      0.006    104.493      0.000       0.586       0.609
# lag2_dm_violent_crime_rate         0.0406      0.005      7.523      0.000       0.030       0.051
# ==============================================================================
# Omnibus:                    12402.612   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2910314.054
# Skew:                           0.951   Prob(JB):                         0.00
# Kurtosis:                      52.762   Cond. No.                         309.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.450
# Model:                               WLS   Adj. R-squared:                  0.450
# Method:                    Least Squares   F-statistic:                     8646.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.0510e+05
# No. Observations:                  31744   AIC:                         4.102e+05
# Df Residuals:                      31740   BIC:                         4.103e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.2834      0.875      2.608      0.009       0.567       3.999
# dm_jail_occupancy_count_rate    -0.8795      0.089     -9.909      0.000      -1.054      -0.706
# lag1_dm_violent_crime_rate       0.5917      0.005    109.931      0.000       0.581       0.602
# lag2_dm_violent_crime_rate       0.0420      0.005      8.274      0.000       0.032       0.052
# ==============================================================================
# Omnibus:                    14911.883   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2652674.365
# Skew:                           1.170   Prob(JB):                         0.00
# Kurtosis:                      47.722   Cond. No.                         308.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.447
# Model:                               WLS   Adj. R-squared:                  0.447
# Method:                    Least Squares   F-statistic:                     8830.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.1168e+05
# No. Observations:                  32784   AIC:                         4.234e+05
# Df Residuals:                      32780   BIC:                         4.234e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.8607      0.834      5.827      0.000       3.226       6.496
# dm_drug_tot_arrests_rate       0.0780      0.034      2.293      0.022       0.011       0.145
# lag1_dm_violent_crime_rate     0.5960      0.005    112.201      0.000       0.586       0.606
# lag2_dm_violent_crime_rate     0.0404      0.005      8.032      0.000       0.031       0.050
# ==============================================================================
# Omnibus:                    16635.796   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3000880.526
# Skew:                           1.356   Prob(JB):                         0.00
# Kurtosis:                      49.792   Cond. No.                         297.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.465
# Model:                               WLS   Adj. R-squared:                  0.465
# Method:                    Least Squares   F-statistic:                     8982.
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -1.9922e+05
# No. Observations:                  30946   AIC:                         3.985e+05
# Df Residuals:                      30942   BIC:                         3.985e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              2.5312      0.861      2.941      0.003       0.844       4.218
# dm_disorder_arrests_tot_index_rate     0.2706      0.020     13.389      0.000       0.231       0.310
# lag1_dm_violent_crime_rate             0.6077      0.005    112.122      0.000       0.597       0.618
# lag2_dm_violent_crime_rate             0.0342      0.005      6.715      0.000       0.024       0.044
# ==============================================================================
# Omnibus:                    15588.572   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2974827.817
# Skew:                           1.323   Prob(JB):                         0.00
# Kurtosis:                      50.959   Cond. No.                         303.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.569
# Model:                               WLS   Adj. R-squared:                  0.569
# Method:                    Least Squares   F-statistic:                 1.673e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.3040e+05
# No. Observations:                  37988   AIC:                         4.608e+05
# Df Residuals:                      37984   BIC:                         4.608e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -10.9624      0.522    -20.992      0.000     -11.986      -9.939
# dm_total_officers_rate         8.7440      1.284      6.811      0.000       6.228      11.260
# lag1_dm_violent_crime_rate     0.7047      0.005    139.496      0.000       0.695       0.715
# lag2_dm_violent_crime_rate     0.0990      0.005     19.026      0.000       0.089       0.109
# ==============================================================================
# Omnibus:                    12220.840   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1725106.685
# Skew:                           0.440   Prob(JB):                         0.00
# Kurtosis:                      36.002   Cond. No.                         491.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.580
# Model:                               WLS   Adj. R-squared:                  0.580
# Method:                    Least Squares   F-statistic:                 1.533e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.0171e+05
# No. Observations:                  33373   AIC:                         4.034e+05
# Df Residuals:                      33369   BIC:                         4.035e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -9.8660      0.587    -16.815      0.000     -11.016      -8.716
# dm_prison_occupancy_count_rate    -0.2698      0.048     -5.609      0.000      -0.364      -0.176
# lag1_dm_violent_crime_rate         0.7029      0.005    130.300      0.000       0.692       0.714
# lag2_dm_violent_crime_rate         0.1136      0.006     20.468      0.000       0.103       0.124
# ==============================================================================
# Omnibus:                    11003.016   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1496900.464
# Skew:                           0.505   Prob(JB):                         0.00
# Kurtosis:                      35.794   Cond. No.                         214.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.568
# Model:                               WLS   Adj. R-squared:                  0.568
# Method:                    Least Squares   F-statistic:                 1.614e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.2371e+05
# No. Observations:                  36847   AIC:                         4.474e+05
# Df Residuals:                      36843   BIC:                         4.475e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -10.8549      0.557    -19.504      0.000     -11.946      -9.764
# dm_jail_occupancy_count_rate     0.0363      0.051      0.709      0.479      -0.064       0.137
# lag1_dm_violent_crime_rate       0.7047      0.005    137.453      0.000       0.695       0.715
# lag2_dm_violent_crime_rate       0.1003      0.005     18.998      0.000       0.090       0.111
# ==============================================================================
# Omnibus:                    12110.550   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1622692.193
# Skew:                           0.505   Prob(JB):                         0.00
# Kurtosis:                      35.495   Cond. No.                         210.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.570
# Model:                               WLS   Adj. R-squared:                  0.570
# Method:                    Least Squares   F-statistic:                 1.677e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.3038e+05
# No. Observations:                  37988   AIC:                         4.608e+05
# Df Residuals:                      37984   BIC:                         4.608e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -11.5794      0.528    -21.911      0.000     -12.615     -10.544
# dm_drug_tot_arrests_rate       0.2124      0.023      9.437      0.000       0.168       0.256
# lag1_dm_violent_crime_rate     0.7033      0.005    139.175      0.000       0.693       0.713
# lag2_dm_violent_crime_rate     0.0991      0.005     19.067      0.000       0.089       0.109
# ==============================================================================
# Omnibus:                    12233.830   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1719688.346
# Skew:                           0.444   Prob(JB):                         0.00
# Kurtosis:                      35.950   Cond. No.                         202.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.564
# Model:                               WLS   Adj. R-squared:                  0.564
# Method:                    Least Squares   F-statistic:                 1.518e+04
# Date:                   Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                           17:06:15   Log-Likelihood:            -2.1271e+05
# No. Observations:                  35247   AIC:                         4.254e+05
# Df Residuals:                      35243   BIC:                         4.255e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -8.5309      0.557    -15.327      0.000      -9.622      -7.440
# dm_disorder_arrests_tot_index_rate     0.1163      0.015      7.781      0.000       0.087       0.146
# lag1_dm_violent_crime_rate             0.7018      0.005    132.595      0.000       0.691       0.712
# lag2_dm_violent_crime_rate             0.0957      0.005     17.592      0.000       0.085       0.106
# ==============================================================================
# Omnibus:                    12503.410   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1857667.600
# Skew:                           0.626   Prob(JB):                         0.00
# Kurtosis:                      38.543   Cond. No.                         204.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
