# %%
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# ### Weighting by ref pop; YEAR as control var; lagged values of dep var
# #### **** all regressions with dm ref pop lag vars counts files ****

# %% [markdown]
# #### create a func to automate weighted lagged regression - univariate for now

# %%
def wols_lagged_control_uni(req_dfs, dep_var, ind_vars_lists, weights_var, control_var=False, dataset_names=False):
    df_count=0
    for df in req_dfs:
        for var_list in ind_vars_lists:
            if control_var:
                model = sm.WLS.from_formula(f'{dep_var} ~ {var_list[0]} + {var_list[1]} + lag1_{dep_var} + lag2_{dep_var} + {control_var}', 
                                            data=df, 
                                            weights=df[f'{weights_var}'])
            else:
                model = sm.WLS.from_formula(f'{dep_var} ~ {var_list[0]} + {var_list[1]} + lag1_{dep_var} + lag2_{dep_var}', 
                                            data=df, 
                                            weights=df[f'{weights_var}'])
                
            results = model.fit()
            if dataset_names:
                print(dataset_names[df_count])
            print(results.summary(), '\n', '\n')
        df_count += 1

# %% [markdown]
# ## 'dm_total_officers_rate' and others one at a time

# %%
dm_dep_var_rates = 'dm_violent_crime_rate'
dm_ind_var_lists = [['dm_total_officers_rate', 'dm_jail_occupancy_count_rate'], 
                    ['dm_total_officers_rate', 'dm_prison_occupancy_count_rate'],
                   ['dm_total_officers_rate', 'dm_drug_tot_arrests_rate'], 
                    ['dm_total_officers_rate', 'dm_disorder_arrests_tot_index_rate']]

# %% [markdown]
# ''### All Agencies - 90-15, 90-02, 03-15

# %%
all_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_gte_10k_core_rates_dm_ref_pop_lag.csv')
all_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_gte_10k_core_rates_dm_1990_2002_ref_pop_lag.csv')
all_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_gte_10k_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %% [markdown]
# #### With control var

# %%
wols_lagged_control_uni(req_dfs=[all_90_15, all_90_02, all_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['all_90_15', 'all_90_02', 'all_03_15'])
# Out:
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.781
# Model:                               WLS   Adj. R-squared:                  0.781
# Method:                    Least Squares   F-statistic:                 6.955e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:06   Log-Likelihood:            -6.2468e+05
# No. Observations:                  97469   AIC:                         1.249e+06
# Df Residuals:                      97463   BIC:                         1.249e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3308.1057    119.254     27.740      0.000    3074.370    3541.841
# dm_total_officers_rate          -3.7145      0.509     -7.296      0.000      -4.712      -2.717
# dm_jail_occupancy_count_rate     0.1102      0.049      2.246      0.025       0.014       0.206
# lag1_dm_violent_crime_rate       0.8377      0.003    277.249      0.000       0.832       0.844
# lag2_dm_violent_crime_rate      -0.0190      0.003     -6.526      0.000      -0.025      -0.013
# YEAR                            -1.6599      0.060    -27.891      0.000      -1.777      -1.543
# ==============================================================================
# Omnibus:                    52874.631   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17995978.823
# Skew:                          -1.381   Prob(JB):                         0.00
# Kurtosis:                      69.510   Cond. No.                     6.75e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.75e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.796
# Model:                               WLS   Adj. R-squared:                  0.796
# Method:                    Least Squares   F-statistic:                 6.842e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:06   Log-Likelihood:            -5.6019e+05
# No. Observations:                  87831   AIC:                         1.120e+06
# Df Residuals:                      87825   BIC:                         1.120e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2959.4533    123.539     23.956      0.000    2717.319    3201.588
# dm_total_officers_rate            -2.5520      0.516     -4.946      0.000      -3.563      -1.541
# dm_prison_occupancy_count_rate    -0.1974      0.037     -5.295      0.000      -0.270      -0.124
# lag1_dm_violent_crime_rate         0.8544      0.003    268.519      0.000       0.848       0.861
# lag2_dm_violent_crime_rate        -0.0276      0.003     -8.977      0.000      -0.034      -0.022
# YEAR                              -1.4860      0.062    -24.101      0.000      -1.607      -1.365
# ==============================================================================
# Omnibus:                    52057.694   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18131234.772
# Skew:                          -1.636   Prob(JB):                         0.00
# Kurtosis:                      73.311   Cond. No.                     6.89e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.89e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.779
# Model:                               WLS   Adj. R-squared:                  0.779
# Method:                    Least Squares   F-statistic:                 7.083e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -6.4490e+05
# No. Observations:                 100612   AIC:                         1.290e+06
# Df Residuals:                     100606   BIC:                         1.290e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3250.0393    114.702     28.335      0.000    3025.225    3474.853
# dm_total_officers_rate        -3.7358      0.493     -7.572      0.000      -4.703      -2.769
# dm_drug_tot_arrests_rate       0.1247      0.014      8.854      0.000       0.097       0.152
# lag1_dm_violent_crime_rate     0.8384      0.003    281.178      0.000       0.833       0.844
# lag2_dm_violent_crime_rate    -0.0224      0.003     -7.796      0.000      -0.028      -0.017
# YEAR                          -1.6310      0.057    -28.494      0.000      -1.743      -1.519
# ==============================================================================
# Omnibus:                    57249.315   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         19486504.525
# Skew:                          -1.518   Prob(JB):                         0.00
# Kurtosis:                      71.111   Cond. No.                     6.59e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.782
# Model:                               WLS   Adj. R-squared:                  0.782
# Method:                    Least Squares   F-statistic:                 6.690e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -5.9531e+05
# No. Observations:                  93297   AIC:                         1.191e+06
# Df Residuals:                      93291   BIC:                         1.191e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2679.7356    122.205     21.928      0.000    2440.216    2919.255
# dm_total_officers_rate               -14.3892      0.744    -19.339      0.000     -15.848     -12.931
# dm_disorder_arrests_tot_index_rate     0.0686      0.011      6.402      0.000       0.048       0.090
# lag1_dm_violent_crime_rate             0.8316      0.003    270.790      0.000       0.826       0.838
# lag2_dm_violent_crime_rate            -0.0180      0.003     -6.120      0.000      -0.024      -0.012
# YEAR                                  -1.3453      0.061    -22.057      0.000      -1.465      -1.226
# ==============================================================================
# Omnibus:                    40853.218   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13541806.492
# Skew:                          -0.853   Prob(JB):                         0.00
# Kurtosis:                      61.997   Cond. No.                     6.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.747
# Model:                               WLS   Adj. R-squared:                  0.747
# Method:                    Least Squares   F-statistic:                 2.432e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.7110e+05
# No. Observations:                  41277   AIC:                         5.422e+05
# Df Residuals:                      41271   BIC:                         5.423e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.235e+04    444.143     27.804      0.000    1.15e+04    1.32e+04
# dm_total_officers_rate          -7.8300      1.116     -7.017      0.000     -10.017      -5.643
# dm_jail_occupancy_count_rate    -0.5975      0.092     -6.487      0.000      -0.778      -0.417
# lag1_dm_violent_crime_rate       0.7848      0.005    173.560      0.000       0.776       0.794
# lag2_dm_violent_crime_rate      -0.0331      0.004     -8.025      0.000      -0.041      -0.025
# YEAR                            -6.1857      0.222    -27.822      0.000      -6.621      -5.750
# ==============================================================================
# Omnibus:                    13721.640   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3795507.630
# Skew:                          -0.210   Prob(JB):                         0.00
# Kurtosis:                      49.975   Cond. No.                     1.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.766
# Model:                               WLS   Adj. R-squared:                  0.766
# Method:                    Least Squares   F-statistic:                 2.410e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.4072e+05
# No. Observations:                  36844   AIC:                         4.815e+05
# Df Residuals:                      36838   BIC:                         4.815e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       9925.6090    470.013     21.118      0.000    9004.371    1.08e+04
# dm_total_officers_rate            -6.1540      1.110     -5.545      0.000      -8.329      -3.979
# dm_prison_occupancy_count_rate    -0.8882      0.068    -12.972      0.000      -1.022      -0.754
# lag1_dm_violent_crime_rate         0.7997      0.005    167.396      0.000       0.790       0.809
# lag2_dm_violent_crime_rate        -0.0381      0.004     -8.723      0.000      -0.047      -0.030
# YEAR                              -4.9733      0.235    -21.138      0.000      -5.434      -4.512
# ==============================================================================
# Omnibus:                    13147.097   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3217394.307
# Skew:                          -0.474   Prob(JB):                         0.00
# Kurtosis:                      48.770   Cond. No.                     1.48e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.745
# Model:                               WLS   Adj. R-squared:                  0.745
# Method:                    Least Squares   F-statistic:                 2.487e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.8016e+05
# No. Observations:                  42659   AIC:                         5.603e+05
# Df Residuals:                      42653   BIC:                         5.604e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1.254e+04    428.646     29.252      0.000    1.17e+04    1.34e+04
# dm_total_officers_rate        -8.5542      1.093     -7.829      0.000     -10.696      -6.413
# dm_drug_tot_arrests_rate      -0.2727      0.024    -11.169      0.000      -0.321      -0.225
# lag1_dm_violent_crime_rate     0.7866      0.004    176.039      0.000       0.778       0.795
# lag2_dm_violent_crime_rate    -0.0333      0.004     -8.150      0.000      -0.041      -0.025
# YEAR                          -6.2804      0.215    -29.267      0.000      -6.701      -5.860
# ==============================================================================
# Omnibus:                    14454.998   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4008848.153
# Skew:                          -0.281   Prob(JB):                         0.00
# Kurtosis:                      50.488   Cond. No.                     1.39e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.753
# Model:                               WLS   Adj. R-squared:                  0.753
# Method:                    Least Squares   F-statistic:                 2.436e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.6212e+05
# No. Observations:                  40028   AIC:                         5.242e+05
# Df Residuals:                      40022   BIC:                         5.243e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.234e+04    438.740     28.129      0.000    1.15e+04    1.32e+04
# dm_total_officers_rate               -14.4153      1.259    -11.447      0.000     -16.884     -11.947
# dm_disorder_arrests_tot_index_rate     0.0366      0.017      2.122      0.034       0.003       0.070
# lag1_dm_violent_crime_rate             0.7855      0.005    172.647      0.000       0.777       0.794
# lag2_dm_violent_crime_rate            -0.0346      0.004     -8.357      0.000      -0.043      -0.026
# YEAR                                  -6.1814      0.220    -28.143      0.000      -6.612      -5.751
# ==============================================================================
# Omnibus:                    13220.547   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4065337.750
# Skew:                          -0.056   Prob(JB):                         0.00
# Kurtosis:                      52.371   Cond. No.                     1.40e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.802
# Model:                               WLS   Adj. R-squared:                  0.802
# Method:                    Least Squares   F-statistic:                 3.809e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.8924e+05
# No. Observations:                  46897   AIC:                         5.785e+05
# Df Residuals:                      46891   BIC:                         5.786e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2021.7188    265.305      7.620      0.000    1501.718    2541.720
# dm_total_officers_rate          -7.7854      0.622    -12.513      0.000      -9.005      -6.566
# dm_jail_occupancy_count_rate     0.3553      0.053      6.691      0.000       0.251       0.459
# lag1_dm_violent_crime_rate       0.8664      0.005    190.816      0.000       0.857       0.875
# lag2_dm_violent_crime_rate       0.0684      0.005     14.437      0.000       0.059       0.078
# YEAR                            -1.0133      0.132     -7.676      0.000      -1.272      -0.755
# ==============================================================================
# Omnibus:                    17756.040   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8528840.578
# Skew:                          -0.386   Prob(JB):                         0.00
# Kurtosis:                      69.061   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.811
# Model:                               WLS   Adj. R-squared:                  0.811
# Method:                    Least Squares   F-statistic:                 3.670e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.6202e+05
# No. Observations:                  42654   AIC:                         5.241e+05
# Df Residuals:                      42648   BIC:                         5.241e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2724.0218    277.716      9.809      0.000    2179.692    3268.351
# dm_total_officers_rate            -6.3406      0.642     -9.873      0.000      -7.599      -5.082
# dm_prison_occupancy_count_rate    -0.2081      0.044     -4.684      0.000      -0.295      -0.121
# lag1_dm_violent_crime_rate         0.8789      0.005    183.785      0.000       0.870       0.888
# lag2_dm_violent_crime_rate         0.0640      0.005     12.809      0.000       0.054       0.074
# YEAR                              -1.3620      0.138     -9.857      0.000      -1.633      -1.091
# ==============================================================================
# Omnibus:                    16520.642   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9222802.535
# Skew:                          -0.397   Prob(JB):                         0.00
# Kurtosis:                      75.033   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.803
# Model:                               WLS   Adj. R-squared:                  0.803
# Method:                    Least Squares   F-statistic:                 3.948e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.9806e+05
# No. Observations:                  48372   AIC:                         5.961e+05
# Df Residuals:                      48366   BIC:                         5.962e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1781.9252    262.608      6.785      0.000    1267.210    2296.641
# dm_total_officers_rate        -7.1971      0.605    -11.889      0.000      -8.384      -6.011
# dm_drug_tot_arrests_rate       0.1695      0.018      9.634      0.000       0.135       0.204
# lag1_dm_violent_crime_rate     0.8653      0.004    194.454      0.000       0.857       0.874
# lag2_dm_violent_crime_rate     0.0656      0.005     14.087      0.000       0.056       0.075
# YEAR                          -0.8938      0.131     -6.841      0.000      -1.150      -0.638
# ==============================================================================
# Omnibus:                    18274.280   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8992834.087
# Skew:                          -0.370   Prob(JB):                         0.00
# Kurtosis:                      69.793   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.801
# Model:                               WLS   Adj. R-squared:                  0.801
# Method:                    Least Squares   F-statistic:                 3.592e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:25:07   Log-Likelihood:            -2.7442e+05
# No. Observations:                  44638   AIC:                         5.489e+05
# Df Residuals:                      44632   BIC:                         5.489e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1416.3925    277.197      5.110      0.000     873.081    1959.704
# dm_total_officers_rate               -14.8992      0.795    -18.730      0.000     -16.458     -13.340
# dm_disorder_arrests_tot_index_rate     0.0387      0.013      2.876      0.004       0.012       0.065
# lag1_dm_violent_crime_rate             0.8756      0.005    186.709      0.000       0.866       0.885
# lag2_dm_violent_crime_rate             0.0632      0.005     12.824      0.000       0.054       0.073
# YEAR                                  -0.7109      0.138     -5.153      0.000      -0.981      -0.440
# ==============================================================================
# Omnibus:                    16315.576   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9356661.126
# Skew:                          -0.156   Prob(JB):                         0.00
# Kurtosis:                      73.927   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Without control var

# %%
wols_lagged_control_uni(req_dfs=[all_90_15, all_90_02, all_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       weights_var='fnl_population_wt',
                       dataset_names=['all_90_15', 'all_90_02', 'all_03_15'])
# Out:
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.779
# Model:                               WLS   Adj. R-squared:                  0.779
# Method:                    Least Squares   F-statistic:                 8.606e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:00   Log-Likelihood:            -6.2507e+05
# No. Observations:                  97469   AIC:                         1.250e+06
# Df Residuals:                      97464   BIC:                         1.250e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -17.9797      0.360    -50.005      0.000     -18.684     -17.275
# dm_total_officers_rate          -3.5662      0.511     -6.977      0.000      -4.568      -2.564
# dm_jail_occupancy_count_rate    -0.1849      0.048     -3.846      0.000      -0.279      -0.091
# lag1_dm_violent_crime_rate       0.8494      0.003    282.740      0.000       0.844       0.855
# lag2_dm_violent_crime_rate      -0.0088      0.003     -3.046      0.002      -0.015      -0.003
# ==============================================================================
# Omnibus:                    52207.015   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18207642.482
# Skew:                          -1.340   Prob(JB):                         0.00
# Kurtosis:                      69.904   Cond. No.                         497.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.794
# Model:                               WLS   Adj. R-squared:                  0.794
# Method:                    Least Squares   F-statistic:                 8.482e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:00   Log-Likelihood:            -5.6048e+05
# No. Observations:                  87831   AIC:                         1.121e+06
# Df Residuals:                      87826   BIC:                         1.121e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -17.9903      0.366    -49.184      0.000     -18.707     -17.273
# dm_total_officers_rate            -2.0087      0.517     -3.884      0.000      -3.022      -0.995
# dm_prison_occupancy_count_rate    -0.4310      0.036    -11.934      0.000      -0.502      -0.360
# lag1_dm_violent_crime_rate         0.8643      0.003    273.074      0.000       0.858       0.871
# lag2_dm_violent_crime_rate        -0.0179      0.003     -5.869      0.000      -0.024      -0.012
# ==============================================================================
# Omnibus:                    51537.990   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18664850.783
# Skew:                          -1.596   Prob(JB):                         0.00
# Kurtosis:                      74.344   Cond. No.                         497.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.777
# Model:                               WLS   Adj. R-squared:                  0.777
# Method:                    Least Squares   F-statistic:                 8.763e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:00   Log-Likelihood:            -6.4530e+05
# No. Observations:                 100612   AIC:                         1.291e+06
# Df Residuals:                     100607   BIC:                         1.291e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -18.2345      0.354    -51.531      0.000     -18.928     -17.541
# dm_total_officers_rate        -4.3587      0.495     -8.808      0.000      -5.329      -3.389
# dm_drug_tot_arrests_rate       0.1123      0.014      7.947      0.000       0.085       0.140
# lag1_dm_violent_crime_rate     0.8504      0.003    286.924      0.000       0.845       0.856
# lag2_dm_violent_crime_rate    -0.0124      0.003     -4.327      0.000      -0.018      -0.007
# ==============================================================================
# Omnibus:                    56147.677   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         19454824.939
# Skew:                          -1.457   Prob(JB):                         0.00
# Kurtosis:                      71.061   Cond. No.                         486.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.781
# Model:                               WLS   Adj. R-squared:                  0.781
# Method:                    Least Squares   F-statistic:                 8.308e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:00   Log-Likelihood:            -5.9556e+05
# No. Observations:                  93297   AIC:                         1.191e+06
# Df Residuals:                      93292   BIC:                         1.191e+06
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -15.7178      0.359    -43.820      0.000     -16.421     -15.015
# dm_total_officers_rate               -15.5196      0.744    -20.854      0.000     -16.978     -14.061
# dm_disorder_arrests_tot_index_rate     0.1487      0.010     14.698      0.000       0.129       0.168
# lag1_dm_violent_crime_rate             0.8395      0.003    274.592      0.000       0.834       0.846
# lag2_dm_violent_crime_rate            -0.0115      0.003     -3.913      0.000      -0.017      -0.006
# ==============================================================================
# Omnibus:                    39414.927   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13206633.090
# Skew:                          -0.769   Prob(JB):                         0.00
# Kurtosis:                      61.266   Cond. No.                         718.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.742
# Model:                               WLS   Adj. R-squared:                  0.742
# Method:                    Least Squares   F-statistic:                 2.966e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:00   Log-Likelihood:            -2.7148e+05
# No. Observations:                  41277   AIC:                         5.430e+05
# Df Residuals:                      41272   BIC:                         5.430e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -7.8473      0.698    -11.247      0.000      -9.215      -6.480
# dm_total_officers_rate          -9.8221      1.124     -8.739      0.000     -12.025      -7.619
# dm_jail_occupancy_count_rate    -1.1445      0.091    -12.602      0.000      -1.323      -0.967
# lag1_dm_violent_crime_rate       0.8086      0.004    180.407      0.000       0.800       0.817
# lag2_dm_violent_crime_rate      -0.0306      0.004     -7.346      0.000      -0.039      -0.022
# ==============================================================================
# Omnibus:                    14164.389   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3887970.164
# Skew:                          -0.326   Prob(JB):                         0.00
# Kurtosis:                      50.541   Cond. No.                         756.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.763
# Model:                               WLS   Adj. R-squared:                  0.763
# Method:                    Least Squares   F-statistic:                 2.966e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:01   Log-Likelihood:            -2.4094e+05
# No. Observations:                  36844   AIC:                         4.819e+05
# Df Residuals:                      36839   BIC:                         4.819e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -9.6239      0.706    -13.641      0.000     -11.007      -8.241
# dm_total_officers_rate            -6.4917      1.116     -5.815      0.000      -8.680      -4.303
# dm_prison_occupancy_count_rate    -1.3913      0.065    -21.540      0.000      -1.518      -1.265
# lag1_dm_violent_crime_rate         0.8161      0.005    172.065      0.000       0.807       0.825
# lag2_dm_violent_crime_rate        -0.0338      0.004     -7.699      0.000      -0.042      -0.025
# ==============================================================================
# Omnibus:                    13407.278   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3237854.927
# Skew:                          -0.525   Prob(JB):                         0.00
# Kurtosis:                      48.913   Cond. No.                         747.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.739
# Model:                               WLS   Adj. R-squared:                  0.739
# Method:                    Least Squares   F-statistic:                 3.026e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:01   Log-Likelihood:            -2.8059e+05
# No. Observations:                  42659   AIC:                         5.612e+05
# Df Residuals:                      42654   BIC:                         5.612e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -6.6842      0.676     -9.891      0.000      -8.009      -5.360
# dm_total_officers_rate       -11.9802      1.097    -10.919      0.000     -14.131      -9.830
# dm_drug_tot_arrests_rate      -0.3390      0.025    -13.807      0.000      -0.387      -0.291
# lag1_dm_violent_crime_rate     0.8120      0.004    183.413      0.000       0.803       0.821
# lag2_dm_violent_crime_rate    -0.0315      0.004     -7.618      0.000      -0.040      -0.023
# ==============================================================================
# Omnibus:                    14929.544   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4148602.505
# Skew:                          -0.377   Prob(JB):                         0.00
# Kurtosis:                      51.306   Cond. No.                         746.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.748
# Model:                               WLS   Adj. R-squared:                  0.748
# Method:                    Least Squares   F-statistic:                 2.966e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:01   Log-Likelihood:            -2.6251e+05
# No. Observations:                  40028   AIC:                         5.250e+05
# Df Residuals:                      40023   BIC:                         5.251e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -6.1671      0.705     -8.748      0.000      -7.549      -4.785
# dm_total_officers_rate               -19.5831      1.258    -15.566      0.000     -22.049     -17.117
# dm_disorder_arrests_tot_index_rate     0.1241      0.017      7.254      0.000       0.091       0.158
# lag1_dm_violent_crime_rate             0.8100      0.005    179.597      0.000       0.801       0.819
# lag2_dm_violent_crime_rate            -0.0351      0.004     -8.401      0.000      -0.043      -0.027
# ==============================================================================
# Omnibus:                    13329.569   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4148868.192
# Skew:                          -0.119   Prob(JB):                         0.00
# Kurtosis:                      52.875   Cond. No.                         848.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.802
# Model:                               WLS   Adj. R-squared:                  0.802
# Method:                    Least Squares   F-statistic:                 4.753e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:01   Log-Likelihood:            -2.8927e+05
# No. Observations:                  46897   AIC:                         5.786e+05
# Df Residuals:                      46892   BIC:                         5.786e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -14.7986      0.463    -31.951      0.000     -15.706     -13.891
# dm_total_officers_rate          -7.6773      0.622    -12.334      0.000      -8.897      -6.457
# dm_jail_occupancy_count_rate     0.3672      0.053      6.913      0.000       0.263       0.471
# lag1_dm_violent_crime_rate       0.8689      0.005    191.790      0.000       0.860       0.878
# lag2_dm_violent_crime_rate       0.0697      0.005     14.723      0.000       0.060       0.079
# ==============================================================================
# Omnibus:                    17415.284   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8436950.301
# Skew:                          -0.322   Prob(JB):                         0.00
# Kurtosis:                      68.706   Cond. No.                         432.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.811
# Model:                               WLS   Adj. R-squared:                  0.811
# Method:                    Least Squares   F-statistic:                 4.575e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:01   Log-Likelihood:            -2.6207e+05
# No. Observations:                  42654   AIC:                         5.242e+05
# Df Residuals:                      42649   BIC:                         5.242e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -13.4047      0.492    -27.222      0.000     -14.370     -12.440
# dm_total_officers_rate            -6.4577      0.643    -10.046      0.000      -7.718      -5.198
# dm_prison_occupancy_count_rate    -0.1434      0.044     -3.259      0.001      -0.230      -0.057
# lag1_dm_violent_crime_rate         0.8825      0.005    184.825      0.000       0.873       0.892
# lag2_dm_violent_crime_rate         0.0653      0.005     13.052      0.000       0.055       0.075
# ==============================================================================
# Omnibus:                    16130.612   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9096727.926
# Skew:                          -0.316   Prob(JB):                         0.00
# Kurtosis:                      74.540   Cond. No.                         437.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.803
# Model:                               WLS   Adj. R-squared:                  0.803
# Method:                    Least Squares   F-statistic:                 4.930e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:01   Log-Likelihood:            -2.9808e+05
# No. Observations:                  48372   AIC:                         5.962e+05
# Df Residuals:                      48367   BIC:                         5.962e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -14.4911      0.443    -32.691      0.000     -15.360     -13.622
# dm_total_officers_rate        -7.1066      0.606    -11.736      0.000      -8.293      -5.920
# dm_drug_tot_arrests_rate       0.1865      0.017     10.704      0.000       0.152       0.221
# lag1_dm_violent_crime_rate     0.8674      0.004    195.265      0.000       0.859       0.876
# lag2_dm_violent_crime_rate     0.0664      0.005     14.254      0.000       0.057       0.075
# ==============================================================================
# Omnibus:                    17964.278   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8908080.754
# Skew:                          -0.312   Prob(JB):                         0.00
# Kurtosis:                      69.479   Cond. No.                         428.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.801
# Model:                               WLS   Adj. R-squared:                  0.801
# Method:                    Least Squares   F-statistic:                 4.487e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:26:01   Log-Likelihood:            -2.7444e+05
# No. Observations:                  44638   AIC:                         5.489e+05
# Df Residuals:                      44633   BIC:                         5.489e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -12.0665      0.478    -25.244      0.000     -13.003     -11.130
# dm_total_officers_rate               -14.8054      0.796    -18.611      0.000     -16.365     -13.246
# dm_disorder_arrests_tot_index_rate     0.0572      0.013      4.413      0.000       0.032       0.083
# lag1_dm_violent_crime_rate             0.8769      0.005    187.244      0.000       0.868       0.886
# lag2_dm_violent_crime_rate             0.0637      0.005     12.937      0.000       0.054       0.073
# ==============================================================================
# Omnibus:                    16203.136   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9275270.647
# Skew:                          -0.106   Prob(JB):                         0.00
# Kurtosis:                      73.618   Cond. No.                         534.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Large Agencies - 90-15, 90-02, 03-15

# %%
#### read in the required files
large_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_large_cities_core_rates_dm_ref_pop_lag.csv')
large_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_large_cities_core_rates_dm_1990_2002_ref_pop_lag.csv')
large_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_large_cities_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %% [markdown]
# #### With control var

# %%
wols_lagged_control_uni(req_dfs=[large_90_15, large_90_02, large_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['large_90_15', 'large_90_02', 'large_03_15'])
# Out:
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.887
# Model:                               WLS   Adj. R-squared:                  0.887
# Method:                    Least Squares   F-statistic:                 1.266e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:51   Log-Likelihood:                -49911.
# No. Observations:                   8094   AIC:                         9.983e+04
# Df Residuals:                       8088   BIC:                         9.988e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2942.7190    392.934      7.489      0.000    2172.467    3712.971
# dm_total_officers_rate         -17.9760      2.075     -8.661      0.000     -22.044     -13.908
# dm_jail_occupancy_count_rate    -0.1583      0.212     -0.746      0.456      -0.574       0.258
# lag1_dm_violent_crime_rate       1.0219      0.010    102.475      0.000       1.002       1.041
# lag2_dm_violent_crime_rate      -0.1619      0.010    -16.835      0.000      -0.181      -0.143
# YEAR                            -1.4813      0.196     -7.553      0.000      -1.866      -1.097
# ==============================================================================
# Omnibus:                     3164.547   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           172552.878
# Skew:                          -1.088   Prob(JB):                         0.00
# Kurtosis:                      25.515   Cond. No.                     7.27e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.893
# Model:                               WLS   Adj. R-squared:                  0.893
# Method:                    Least Squares   F-statistic:                 1.273e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:51   Log-Likelihood:                -46832.
# No. Observations:                   7632   AIC:                         9.368e+04
# Df Residuals:                       7626   BIC:                         9.372e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2733.7978    397.647      6.875      0.000    1954.300    3513.295
# dm_total_officers_rate           -18.2018      2.073     -8.782      0.000     -22.265     -14.139
# dm_prison_occupancy_count_rate    -0.0921      0.122     -0.756      0.450      -0.331       0.147
# lag1_dm_violent_crime_rate         1.0425      0.010    102.120      0.000       1.023       1.063
# lag2_dm_violent_crime_rate        -0.1787      0.010    -18.105      0.000      -0.198      -0.159
# YEAR                              -1.3768      0.198     -6.937      0.000      -1.766      -0.988
# ==============================================================================
# Omnibus:                     3082.793   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           173029.913
# Skew:                          -1.142   Prob(JB):                         0.00
# Kurtosis:                      26.214   Cond. No.                     7.40e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.883
# Model:                               WLS   Adj. R-squared:                  0.883
# Method:                    Least Squares   F-statistic:                 1.265e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:51   Log-Likelihood:                -51646.
# No. Observations:                   8360   AIC:                         1.033e+05
# Df Residuals:                       8354   BIC:                         1.033e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   2929.1964    388.195      7.546      0.000    2168.237    3690.156
# dm_total_officers_rate       -18.9155      2.076     -9.113      0.000     -22.984     -14.847
# dm_drug_tot_arrests_rate       0.0602      0.041      1.481      0.139      -0.019       0.140
# lag1_dm_violent_crime_rate     1.0230      0.010    103.659      0.000       1.004       1.042
# lag2_dm_violent_crime_rate    -0.1651      0.010    -17.315      0.000      -0.184      -0.146
# YEAR                          -1.4747      0.194     -7.611      0.000      -1.855      -1.095
# ==============================================================================
# Omnibus:                     3506.226   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           182390.789
# Skew:                          -1.240   Prob(JB):                         0.00
# Kurtosis:                      25.748   Cond. No.                     7.22e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.888
# Model:                               WLS   Adj. R-squared:                  0.888
# Method:                    Least Squares   F-statistic:                 1.165e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -45374.
# No. Observations:                   7375   AIC:                         9.076e+04
# Df Residuals:                       7369   BIC:                         9.080e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2682.6582    421.862      6.359      0.000    1855.688    3509.628
# dm_total_officers_rate               -22.3941      2.116    -10.582      0.000     -26.543     -18.246
# dm_disorder_arrests_tot_index_rate    -0.0058      0.036     -0.159      0.874      -0.077       0.065
# lag1_dm_violent_crime_rate             1.0110      0.010     97.577      0.000       0.991       1.031
# lag2_dm_violent_crime_rate            -0.1557      0.010    -15.662      0.000      -0.175      -0.136
# YEAR                                  -1.3508      0.211     -6.414      0.000      -1.764      -0.938
# ==============================================================================
# Omnibus:                     2311.311   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           116672.246
# Skew:                          -0.725   Prob(JB):                         0.00
# Kurtosis:                      22.431   Cond. No.                     7.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.861
# Model:                               WLS   Adj. R-squared:                  0.861
# Method:                    Least Squares   F-statistic:                     4579.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -23367.
# No. Observations:                   3706   AIC:                         4.675e+04
# Df Residuals:                       3700   BIC:                         4.678e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.076e+04   1397.795      7.697      0.000    8018.316    1.35e+04
# dm_total_officers_rate         -23.9152      4.148     -5.765      0.000     -32.048     -15.782
# dm_jail_occupancy_count_rate    -1.7571      0.373     -4.709      0.000      -2.489      -1.026
# lag1_dm_violent_crime_rate       0.9514      0.014     67.570      0.000       0.924       0.979
# lag2_dm_violent_crime_rate      -0.1525      0.013    -11.990      0.000      -0.177      -0.128
# YEAR                            -5.3928      0.700     -7.708      0.000      -6.765      -4.021
# ==============================================================================
# Omnibus:                      997.086   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30393.542
# Skew:                          -0.642   Prob(JB):                         0.00
# Kurtosis:                      16.971   Cond. No.                     1.56e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.872
# Model:                               WLS   Adj. R-squared:                  0.871
# Method:                    Least Squares   F-statistic:                     4693.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -21700.
# No. Observations:                   3462   AIC:                         4.341e+04
# Df Residuals:                       3456   BIC:                         4.345e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       7815.3230   1457.543      5.362      0.000    4957.590    1.07e+04
# dm_total_officers_rate           -24.5440      4.052     -6.057      0.000     -32.489     -16.599
# dm_prison_occupancy_count_rate    -1.1215      0.216     -5.203      0.000      -1.544      -0.699
# lag1_dm_violent_crime_rate         0.9663      0.015     66.544      0.000       0.938       0.995
# lag2_dm_violent_crime_rate        -0.1596      0.013    -12.080      0.000      -0.186      -0.134
# YEAR                              -3.9195      0.730     -5.372      0.000      -5.350      -2.489
# ==============================================================================
# Omnibus:                      972.397   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24072.150
# Skew:                          -0.768   Prob(JB):                         0.00
# Kurtosis:                      15.827   Cond. No.                     1.64e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.858
# Model:                               WLS   Adj. R-squared:                  0.857
# Method:                    Least Squares   F-statistic:                     4612.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -24225.
# No. Observations:                   3836   AIC:                         4.846e+04
# Df Residuals:                       3830   BIC:                         4.850e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1.241e+04   1348.615      9.204      0.000    9768.246    1.51e+04
# dm_total_officers_rate       -20.2907      4.242     -4.783      0.000     -28.608     -11.973
# dm_drug_tot_arrests_rate      -0.4324      0.067     -6.413      0.000      -0.565      -0.300
# lag1_dm_violent_crime_rate     0.9484      0.014     67.834      0.000       0.921       0.976
# lag2_dm_violent_crime_rate    -0.1510      0.013    -11.953      0.000      -0.176      -0.126
# YEAR                          -6.2198      0.675     -9.213      0.000      -7.543      -4.896
# ==============================================================================
# Omnibus:                     1095.263   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33001.536
# Skew:                          -0.732   Prob(JB):                         0.00
# Kurtosis:                      17.295   Cond. No.                     1.52e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.863
# Model:                               WLS   Adj. R-squared:                  0.863
# Method:                    Least Squares   F-statistic:                     4313.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -21562.
# No. Observations:                   3420   AIC:                         4.314e+04
# Df Residuals:                       3414   BIC:                         4.317e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.289e+04   1407.530      9.156      0.000    1.01e+04    1.56e+04
# dm_total_officers_rate               -24.3613      4.194     -5.808      0.000     -32.585     -16.138
# dm_disorder_arrests_tot_index_rate    -0.0580      0.055     -1.057      0.291      -0.166       0.050
# lag1_dm_violent_crime_rate             0.9453      0.015     64.991      0.000       0.917       0.974
# lag2_dm_violent_crime_rate            -0.1509      0.013    -11.539      0.000      -0.177      -0.125
# YEAR                                  -6.4576      0.705     -9.165      0.000      -7.839      -5.076
# ==============================================================================
# Omnibus:                      886.316   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29073.744
# Skew:                          -0.561   Prob(JB):                         0.00
# Kurtosis:                      17.240   Cond. No.                     1.52e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.890
# Method:                    Least Squares   F-statistic:                     5978.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -21674.
# No. Observations:                   3681   AIC:                         4.336e+04
# Df Residuals:                       3675   BIC:                         4.340e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1231.9245    831.020      1.482      0.138    -397.381    2861.230
# dm_total_officers_rate         -21.7257      2.003    -10.845      0.000     -25.653     -17.798
# dm_jail_occupancy_count_rate     0.2014      0.242      0.833      0.405      -0.272       0.675
# lag1_dm_violent_crime_rate       1.0345      0.016     63.607      0.000       1.003       1.066
# lag2_dm_violent_crime_rate      -0.0673      0.017     -3.952      0.000      -0.101      -0.034
# YEAR                            -0.6206      0.414     -1.501      0.134      -1.431       0.190
# ==============================================================================
# Omnibus:                     1144.045   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           153994.308
# Skew:                           0.328   Prob(JB):                         0.00
# Kurtosis:                      34.680   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.894
# Model:                               WLS   Adj. R-squared:                  0.894
# Method:                    Least Squares   F-statistic:                     5878.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -20551.
# No. Observations:                   3499   AIC:                         4.111e+04
# Df Residuals:                       3493   BIC:                         4.115e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2830.3154    866.223      3.267      0.001    1131.962    4528.669
# dm_total_officers_rate           -18.8485      2.073     -9.093      0.000     -22.913     -14.784
# dm_prison_occupancy_count_rate    -0.6102      0.160     -3.803      0.000      -0.925      -0.296
# lag1_dm_violent_crime_rate         1.0562      0.017     63.504      0.000       1.024       1.089
# lag2_dm_violent_crime_rate        -0.0816      0.017     -4.672      0.000      -0.116      -0.047
# YEAR                              -1.4146      0.431     -3.282      0.001      -2.260      -0.569
# ==============================================================================
# Omnibus:                     1180.938   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           180633.520
# Skew:                           0.468   Prob(JB):                         0.00
# Kurtosis:                      38.187   Cond. No.                     1.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.891
# Method:                    Least Squares   F-statistic:                     6220.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -22315.
# No. Observations:                   3793   AIC:                         4.464e+04
# Df Residuals:                       3787   BIC:                         4.468e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1287.8120    824.001      1.563      0.118    -327.716    2903.340
# dm_total_officers_rate       -21.3106      1.920    -11.099      0.000     -25.075     -17.546
# dm_drug_tot_arrests_rate       0.0306      0.053      0.582      0.561      -0.073       0.134
# lag1_dm_violent_crime_rate     1.0295      0.016     65.259      0.000       0.999       1.060
# lag2_dm_violent_crime_rate    -0.0611      0.017     -3.676      0.000      -0.094      -0.029
# YEAR                          -0.6481      0.410     -1.581      0.114      -1.452       0.156
# ==============================================================================
# Omnibus:                     1174.097   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           159105.125
# Skew:                           0.316   Prob(JB):                         0.00
# Kurtosis:                      34.723   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.888
# Model:                               WLS   Adj. R-squared:                  0.888
# Method:                    Least Squares   F-statistic:                     5288.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:29:52   Log-Likelihood:                -19746.
# No. Observations:                   3347   AIC:                         3.950e+04
# Df Residuals:                       3341   BIC:                         3.954e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            708.9031    913.950      0.776      0.438   -1083.055    2500.862
# dm_total_officers_rate               -23.7481      2.043    -11.622      0.000     -27.754     -19.742
# dm_disorder_arrests_tot_index_rate    -0.0179      0.046     -0.386      0.699      -0.109       0.073
# lag1_dm_violent_crime_rate             1.0485      0.017     60.552      0.000       1.015       1.082
# lag2_dm_violent_crime_rate            -0.0776      0.018     -4.239      0.000      -0.113      -0.042
# YEAR                                  -0.3598      0.455     -0.791      0.429      -1.252       0.532
# ==============================================================================
# Omnibus:                     1107.746   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149472.977
# Skew:                           0.470   Prob(JB):                         0.00
# Kurtosis:                      35.725   Cond. No.                     1.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Medium Agencies - 90-15, 90-02, 03-15

# %% [markdown]
# #### With control var

# %%
#### read in the required files
medium_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_medium_cities_core_rates_dm_ref_pop_lag.csv')
medium_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_medium_cities_core_rates_dm_1990_2002_ref_pop_lag.csv')
medium_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_medium_cities_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %%
wols_lagged_control_uni(req_dfs=[medium_90_15, medium_90_02, medium_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['medium_90_15', 'medium_90_02', 'medium_03_15'])
# Out:
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.678
# Model:                               WLS   Adj. R-squared:                  0.678
# Method:                    Least Squares   F-statistic:                     5657.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:31   Log-Likelihood:                -81188.
# No. Observations:                  13431   AIC:                         1.624e+05
# Df Residuals:                      13425   BIC:                         1.624e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3642.1808    285.492     12.758      0.000    3082.577    4201.785
# dm_total_officers_rate           2.1904      0.761      2.880      0.004       0.700       3.681
# dm_jail_occupancy_count_rate     0.0940      0.132      0.714      0.475      -0.164       0.352
# lag1_dm_violent_crime_rate       0.7534      0.008     91.905      0.000       0.737       0.769
# lag2_dm_violent_crime_rate       0.0222      0.008      2.810      0.005       0.007       0.038
# YEAR                            -1.8231      0.142    -12.796      0.000      -2.102      -1.544
# ==============================================================================
# Omnibus:                     3468.162   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           244224.541
# Skew:                           0.248   Prob(JB):                         0.00
# Kurtosis:                      23.884   Cond. No.                     6.56e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.56e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.698
# Model:                               WLS   Adj. R-squared:                  0.698
# Method:                    Least Squares   F-statistic:                     5590.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:31   Log-Likelihood:                -72502.
# No. Observations:                  12111   AIC:                         1.450e+05
# Df Residuals:                      12105   BIC:                         1.451e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3408.1183    289.394     11.777      0.000    2840.860    3975.376
# dm_total_officers_rate             3.9949      0.770      5.186      0.000       2.485       5.505
# dm_prison_occupancy_count_rate    -0.2761      0.095     -2.908      0.004      -0.462      -0.090
# lag1_dm_violent_crime_rate         0.7515      0.009     86.749      0.000       0.734       0.768
# lag2_dm_violent_crime_rate         0.0321      0.008      3.866      0.000       0.016       0.048
# YEAR                              -1.7065      0.144    -11.816      0.000      -1.990      -1.423
# ==============================================================================
# Omnibus:                     2452.773   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            88486.272
# Skew:                           0.015   Prob(JB):                         0.00
# Kurtosis:                      16.242   Cond. No.                     6.69e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.677
# Model:                               WLS   Adj. R-squared:                  0.677
# Method:                    Least Squares   F-statistic:                     5825.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -83997.
# No. Observations:                  13907   AIC:                         1.680e+05
# Df Residuals:                      13901   BIC:                         1.681e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3690.3044    272.770     13.529      0.000    3155.639    4224.969
# dm_total_officers_rate         2.5014      0.648      3.861      0.000       1.232       3.771
# dm_drug_tot_arrests_rate       0.1900      0.040      4.775      0.000       0.112       0.268
# lag1_dm_violent_crime_rate     0.7487      0.008     92.930      0.000       0.733       0.764
# lag2_dm_violent_crime_rate     0.0228      0.008      2.939      0.003       0.008       0.038
# YEAR                          -1.8472      0.136    -13.571      0.000      -2.114      -1.580
# ==============================================================================
# Omnibus:                     3646.948   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           251919.314
# Skew:                           0.299   Prob(JB):                         0.00
# Kurtosis:                      23.842   Cond. No.                     6.41e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.675
# Model:                               WLS   Adj. R-squared:                  0.675
# Method:                    Least Squares   F-statistic:                     5349.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -77458.
# No. Observations:                  12856   AIC:                         1.549e+05
# Df Residuals:                      12850   BIC:                         1.550e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3237.0357    293.393     11.033      0.000    2661.942    3812.129
# dm_total_officers_rate                -1.9176      1.726     -1.111      0.267      -5.300       1.465
# dm_disorder_arrests_tot_index_rate     0.0324      0.027      1.205      0.228      -0.020       0.085
# lag1_dm_violent_crime_rate             0.7465      0.008     89.534      0.000       0.730       0.763
# lag2_dm_violent_crime_rate             0.0266      0.008      3.323      0.001       0.011       0.042
# YEAR                                  -1.6203      0.146    -11.066      0.000      -1.907      -1.333
# ==============================================================================
# Omnibus:                     3595.282   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           280557.930
# Skew:                           0.378   Prob(JB):                         0.00
# Kurtosis:                      25.873   Cond. No.                     6.73e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.633
# Model:                               WLS   Adj. R-squared:                  0.632
# Method:                    Least Squares   F-statistic:                     2005.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -36189.
# No. Observations:                   5827   AIC:                         7.239e+04
# Df Residuals:                       5821   BIC:                         7.243e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.044e+04   1068.598      9.774      0.000    8349.244    1.25e+04
# dm_total_officers_rate           2.4691      1.754      1.408      0.159      -0.969       5.907
# dm_jail_occupancy_count_rate    -0.4987      0.254     -1.967      0.049      -0.996      -0.002
# lag1_dm_violent_crime_rate       0.7093      0.012     58.112      0.000       0.685       0.733
# lag2_dm_violent_crime_rate       0.0110      0.011      0.978      0.328      -0.011       0.033
# YEAR                            -5.2290      0.535     -9.775      0.000      -6.278      -4.180
# ==============================================================================
# Omnibus:                     2034.925   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131642.734
# Skew:                           0.828   Prob(JB):                         0.00
# Kurtosis:                      26.226   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.648
# Model:                               WLS   Adj. R-squared:                  0.647
# Method:                    Least Squares   F-statistic:                     1916.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -32047.
# No. Observations:                   5216   AIC:                         6.411e+04
# Df Residuals:                       5210   BIC:                         6.415e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       8083.1095   1102.796      7.330      0.000    5921.168    1.02e+04
# dm_total_officers_rate             5.9289      1.743      3.401      0.001       2.512       9.346
# dm_prison_occupancy_count_rate    -0.8298      0.178     -4.649      0.000      -1.180      -0.480
# lag1_dm_violent_crime_rate         0.6986      0.013     53.973      0.000       0.673       0.724
# lag2_dm_violent_crime_rate         0.0267      0.012      2.254      0.024       0.003       0.050
# YEAR                              -4.0474      0.552     -7.332      0.000      -5.130      -2.965
# ==============================================================================
# Omnibus:                     1332.588   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33136.480
# Skew:                           0.648   Prob(JB):                         0.00
# Kurtosis:                      15.280   Cond. No.                     1.43e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.633
# Model:                               WLS   Adj. R-squared:                  0.632
# Method:                    Least Squares   F-statistic:                     2078.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -37444.
# No. Observations:                   6039   AIC:                         7.490e+04
# Df Residuals:                       6033   BIC:                         7.494e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1.104e+04   1010.452     10.922      0.000    9055.359     1.3e+04
# dm_total_officers_rate         0.7880      1.489      0.529      0.597      -2.131       3.707
# dm_drug_tot_arrests_rate       0.1768      0.068      2.600      0.009       0.043       0.310
# lag1_dm_violent_crime_rate     0.7068      0.012     59.016      0.000       0.683       0.730
# lag2_dm_violent_crime_rate     0.0110      0.011      0.996      0.319      -0.011       0.033
# YEAR                          -5.5250      0.506    -10.922      0.000      -6.517      -4.533
# ==============================================================================
# Omnibus:                     2147.602   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           137712.157
# Skew:                           0.863   Prob(JB):                         0.00
# Kurtosis:                      26.331   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.636
# Model:                               WLS   Adj. R-squared:                  0.636
# Method:                    Least Squares   F-statistic:                     1976.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -35085.
# No. Observations:                   5662   AIC:                         7.018e+04
# Df Residuals:                       5656   BIC:                         7.022e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            1.01e+04   1055.914      9.569      0.000    8033.681    1.22e+04
# dm_total_officers_rate                -2.5115      2.027     -1.239      0.215      -6.486       1.463
# dm_disorder_arrests_tot_index_rate     0.0057      0.043      0.132      0.895      -0.079       0.091
# lag1_dm_violent_crime_rate             0.7054      0.012     57.361      0.000       0.681       0.730
# lag2_dm_violent_crime_rate             0.0169      0.011      1.493      0.136      -0.005       0.039
# YEAR                                  -5.0581      0.529     -9.569      0.000      -6.094      -4.022
# ==============================================================================
# Omnibus:                     2109.858   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           145441.967
# Skew:                           0.925   Prob(JB):                         0.00
# Kurtosis:                      27.760   Cond. No.                     1.35e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.712
# Model:                               WLS   Adj. R-squared:                  0.712
# Method:                    Least Squares   F-statistic:                     3149.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -37147.
# No. Observations:                   6369   AIC:                         7.431e+04
# Df Residuals:                       6363   BIC:                         7.435e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3280.1147    671.496      4.885      0.000    1963.757    4596.472
# dm_total_officers_rate           0.7693      1.087      0.708      0.479      -1.361       2.900
# dm_jail_occupancy_count_rate     0.5961      0.148      4.026      0.000       0.306       0.886
# lag1_dm_violent_crime_rate       0.8284      0.012     67.676      0.000       0.804       0.852
# lag2_dm_violent_crime_rate       0.0461      0.013      3.660      0.000       0.021       0.071
# YEAR                            -1.6395      0.334     -4.907      0.000      -2.294      -0.985
# ==============================================================================
# Omnibus:                     1643.188   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           109023.593
# Skew:                          -0.264   Prob(JB):                         0.00
# Kurtosis:                      23.262   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.733
# Model:                               WLS   Adj. R-squared:                  0.733
# Method:                    Least Squares   F-statistic:                     3173.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -33379.
# No. Observations:                   5782   AIC:                         6.677e+04
# Df Residuals:                       5776   BIC:                         6.681e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3851.8866    686.204      5.613      0.000    2506.670    5197.103
# dm_total_officers_rate             2.7958      1.096      2.551      0.011       0.647       4.945
# dm_prison_occupancy_count_rate    -0.0435      0.115     -0.377      0.706      -0.270       0.183
# lag1_dm_violent_crime_rate         0.8467      0.013     65.092      0.000       0.821       0.872
# lag2_dm_violent_crime_rate         0.0402      0.013      3.007      0.003       0.014       0.066
# YEAR                              -1.9235      0.341     -5.634      0.000      -2.593      -1.254
# ==============================================================================
# Omnibus:                     1684.876   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63203.418
# Skew:                          -0.701   Prob(JB):                         0.00
# Kurtosis:                      19.136   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.711
# Model:                               WLS   Adj. R-squared:                  0.711
# Method:                    Least Squares   F-statistic:                     3240.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -38434.
# No. Observations:                   6591   AIC:                         7.688e+04
# Df Residuals:                       6585   BIC:                         7.692e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3086.8812    663.940      4.649      0.000    1785.344    4388.419
# dm_total_officers_rate         2.2501      1.005      2.239      0.025       0.280       4.220
# dm_drug_tot_arrests_rate       0.2440      0.049      4.966      0.000       0.148       0.340
# lag1_dm_violent_crime_rate     0.8280      0.012     68.920      0.000       0.804       0.852
# lag2_dm_violent_crime_rate     0.0396      0.012      3.210      0.001       0.015       0.064
# YEAR                          -1.5432      0.330     -4.672      0.000      -2.191      -0.896
# ==============================================================================
# Omnibus:                     1668.263   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           126388.201
# Skew:                          -0.067   Prob(JB):                         0.00
# Kurtosis:                      24.452   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.701
# Model:                               WLS   Adj. R-squared:                  0.701
# Method:                    Least Squares   F-statistic:                     2832.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:31:32   Log-Likelihood:                -35114.
# No. Observations:                   6044   AIC:                         7.024e+04
# Df Residuals:                       6038   BIC:                         7.028e+04
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3178.2507    695.863      4.567      0.000    1814.111    4542.391
# dm_total_officers_rate                 0.4118      2.896      0.142      0.887      -5.264       6.088
# dm_disorder_arrests_tot_index_rate     0.0305      0.035      0.873      0.383      -0.038       0.099
# lag1_dm_violent_crime_rate             0.8253      0.013     65.672      0.000       0.801       0.850
# lag2_dm_violent_crime_rate             0.0453      0.013      3.486      0.000       0.020       0.071
# YEAR                                  -1.5875      0.346     -4.584      0.000      -2.266      -0.909
# ==============================================================================
# Omnibus:                     1600.501   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           147722.207
# Skew:                          -0.006   Prob(JB):                         0.00
# Kurtosis:                      27.220   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Small Agencies - 90-15, 90-02, 03-15

# %%
#### read in the required files
small_90_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag/final_main_small_cities_core_rates_dm_ref_pop_lag.csv')
small_90_02 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_90_02/final_main_small_cities_core_rates_dm_1990_2002_ref_pop_lag.csv')
small_03_15 = pd.read_csv('/Users/salma/Research/us_crime_data_analysis/data/final_core_dm_pop_ref_lag_03_15/final_main_small_cities_core_rates_dm_2003_2015_ref_pop_lag.csv')

# %%
wols_lagged_control_uni(req_dfs=[small_90_15, small_90_02, small_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['small_90_15', 'small_90_02', 'small_03_15'])
# Out:
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.497
# Model:                               WLS   Adj. R-squared:                  0.497
# Method:                    Least Squares   F-statistic:                 1.503e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -4.7678e+05
# No. Observations:                  75944   AIC:                         9.536e+05
# Df Residuals:                      75938   BIC:                         9.536e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3140.1025    140.525     22.346      0.000    2864.675    3415.530
# dm_total_officers_rate           6.5332      1.193      5.475      0.000       4.194       8.872
# dm_jail_occupancy_count_rate    -0.2173      0.047     -4.607      0.000      -0.310      -0.125
# lag1_dm_violent_crime_rate       0.6249      0.003    178.569      0.000       0.618       0.632
# lag2_dm_violent_crime_rate       0.0525      0.003     15.489      0.000       0.046       0.059
# YEAR                            -1.5701      0.070    -22.390      0.000      -1.708      -1.433
# ==============================================================================
# Omnibus:                    30306.590   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6239225.827
# Skew:                           0.775   Prob(JB):                         0.00
# Kurtosis:                      47.377   Cond. No.                     6.34e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.516
# Model:                               WLS   Adj. R-squared:                  0.516
# Method:                    Least Squares   F-statistic:                 1.455e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -4.2522e+05
# No. Observations:                  68088   AIC:                         8.504e+05
# Df Residuals:                      68082   BIC:                         8.505e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2675.1692    147.300     18.161      0.000    2386.461    2963.877
# dm_total_officers_rate             8.3204      1.261      6.597      0.000       5.848      10.792
# dm_prison_occupancy_count_rate    -0.6086      0.043    -14.272      0.000      -0.692      -0.525
# lag1_dm_violent_crime_rate         0.6302      0.004    170.353      0.000       0.623       0.637
# lag2_dm_violent_crime_rate         0.0563      0.004     15.734      0.000       0.049       0.063
# YEAR                              -1.3381      0.074    -18.204      0.000      -1.482      -1.194
# ==============================================================================
# Omnibus:                    25855.887   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6656860.005
# Skew:                           0.603   Prob(JB):                         0.00
# Kurtosis:                      51.425   Cond. No.                     6.50e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.5e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.498
# Model:                               WLS   Adj. R-squared:                  0.498
# Method:                    Least Squares   F-statistic:                 1.553e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -4.9139e+05
# No. Observations:                  78345   AIC:                         9.828e+05
# Df Residuals:                      78339   BIC:                         9.828e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   3498.5836    133.026     26.300      0.000    3237.854    3759.314
# dm_total_officers_rate         5.3957      1.180      4.572      0.000       3.083       7.709
# dm_drug_tot_arrests_rate       0.2009      0.019     10.658      0.000       0.164       0.238
# lag1_dm_violent_crime_rate     0.6238      0.003    181.015      0.000       0.617       0.631
# lag2_dm_violent_crime_rate     0.0516      0.003     15.468      0.000       0.045       0.058
# YEAR                          -1.7491      0.066    -26.351      0.000      -1.879      -1.619
# ==============================================================================
# Omnibus:                    32375.347   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6779737.328
# Skew:                           0.845   Prob(JB):                         0.00
# Kurtosis:                      48.542   Cond. No.                     6.13e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.506
# Model:                               WLS   Adj. R-squared:                  0.506
# Method:                    Least Squares   F-statistic:                 1.496e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -4.5664e+05
# No. Observations:                  73066   AIC:                         9.133e+05
# Df Residuals:                      73060   BIC:                         9.134e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2517.9119    140.941     17.865      0.000    2241.668    2794.156
# dm_total_officers_rate                 3.5055      1.186      2.955      0.003       1.180       5.831
# dm_disorder_arrests_tot_index_rate     0.1721      0.012     14.008      0.000       0.148       0.196
# lag1_dm_violent_crime_rate             0.6318      0.004    177.063      0.000       0.625       0.639
# lag2_dm_violent_crime_rate             0.0488      0.003     14.172      0.000       0.042       0.056
# YEAR                                  -1.2590      0.070    -17.900      0.000      -1.397      -1.121
# ==============================================================================
# Omnibus:                    31463.799   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6970245.465
# Skew:                           0.919   Prob(JB):                         0.00
# Kurtosis:                      50.814   Cond. No.                     6.41e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.455
# Model:                               WLS   Adj. R-squared:                  0.454
# Method:                    Least Squares   F-statistic:                     5289.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -2.0497e+05
# No. Observations:                  31744   AIC:                         4.099e+05
# Df Residuals:                      31738   BIC:                         4.100e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     9132.7709    545.960     16.728      0.000    8062.668    1.02e+04
# dm_total_officers_rate           5.3020      2.337      2.269      0.023       0.721       9.883
# dm_jail_occupancy_count_rate    -0.5661      0.091     -6.200      0.000      -0.745      -0.387
# lag1_dm_violent_crime_rate       0.5826      0.005    108.125      0.000       0.572       0.593
# lag2_dm_violent_crime_rate       0.0402      0.005      7.935      0.000       0.030       0.050
# YEAR                            -4.5710      0.273    -16.724      0.000      -5.107      -4.035
# ==============================================================================
# Omnibus:                    15244.378   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2625250.758
# Skew:                           1.231   Prob(JB):                         0.00
# Kurtosis:                      47.483   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.474
# Model:                               WLS   Adj. R-squared:                  0.474
# Method:                    Least Squares   F-statistic:                     5076.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -1.8100e+05
# No. Observations:                  28166   AIC:                         3.620e+05
# Df Residuals:                      28160   BIC:                         3.621e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       7737.3626    579.776     13.345      0.000    6600.975    8873.751
# dm_total_officers_rate             4.6091      2.391      1.928      0.054      -0.077       9.295
# dm_prison_occupancy_count_rate    -0.9175      0.081    -11.288      0.000      -1.077      -0.758
# lag1_dm_violent_crime_rate         0.5907      0.006    103.158      0.000       0.579       0.602
# lag2_dm_violent_crime_rate         0.0386      0.005      7.183      0.000       0.028       0.049
# YEAR                              -3.8734      0.290    -13.346      0.000      -4.442      -3.305
# ==============================================================================
# Omnibus:                    12598.834   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2850982.382
# Skew:                           0.995   Prob(JB):                         0.00
# Kurtosis:                      52.248   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.453
# Model:                               WLS   Adj. R-squared:                  0.453
# Method:                    Least Squares   F-statistic:                     5427.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -2.1150e+05
# No. Observations:                  32784   AIC:                         4.230e+05
# Df Residuals:                      32778   BIC:                         4.231e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   9952.6315    528.277     18.840      0.000    8917.188     1.1e+04
# dm_total_officers_rate         2.8369      2.310      1.228      0.219      -1.691       7.365
# dm_drug_tot_arrests_rate       0.1735      0.034      5.056      0.000       0.106       0.241
# lag1_dm_violent_crime_rate     0.5845      0.005    109.905      0.000       0.574       0.595
# lag2_dm_violent_crime_rate     0.0381      0.005      7.617      0.000       0.028       0.048
# YEAR                          -4.9805      0.264    -18.831      0.000      -5.499      -4.462
# ==============================================================================
# Omnibus:                    16901.083   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2940061.693
# Skew:                           1.407   Prob(JB):                         0.00
# Kurtosis:                      49.308   Cond. No.                     1.31e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.470
# Model:                               WLS   Adj. R-squared:                  0.470
# Method:                    Least Squares   F-statistic:                     5485.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -1.9910e+05
# No. Observations:                  30946   AIC:                         3.982e+05
# Df Residuals:                      30940   BIC:                         3.983e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           8517.2504    536.651     15.871      0.000    7465.392    9569.109
# dm_total_officers_rate                 0.7210      2.315      0.311      0.755      -3.816       5.258
# dm_disorder_arrests_tot_index_rate     0.2093      0.020     10.212      0.000       0.169       0.250
# lag1_dm_violent_crime_rate             0.5989      0.005    110.381      0.000       0.588       0.610
# lag2_dm_violent_crime_rate             0.0330      0.005      6.499      0.000       0.023       0.043
# YEAR                                  -4.2630      0.269    -15.867      0.000      -4.790      -3.736
# ==============================================================================
# Omnibus:                    15654.946   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2896061.144
# Skew:                           1.342   Prob(JB):                         0.00
# Kurtosis:                      50.316   Cond. No.                     1.32e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.569
# Model:                               WLS   Adj. R-squared:                  0.569
# Method:                    Least Squares   F-statistic:                     9733.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:48   Log-Likelihood:            -2.2365e+05
# No. Observations:                  36847   AIC:                         4.473e+05
# Df Residuals:                      36841   BIC:                         4.474e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2647.3716    335.872      7.882      0.000    1989.052    3305.691
# dm_total_officers_rate           7.7026      1.301      5.920      0.000       5.153      10.253
# dm_jail_occupancy_count_rate     0.0181      0.051      0.352      0.725      -0.083       0.119
# lag1_dm_violent_crime_rate       0.7008      0.005    136.458      0.000       0.691       0.711
# lag2_dm_violent_crime_rate       0.0982      0.005     18.622      0.000       0.088       0.109
# YEAR                            -1.3226      0.167     -7.915      0.000      -1.650      -0.995
# ==============================================================================
# Omnibus:                    12101.937   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1623049.708
# Skew:                           0.503   Prob(JB):                         0.00
# Kurtosis:                      35.498   Cond. No.                     1.31e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.581
# Model:                               WLS   Adj. R-squared:                  0.581
# Method:                    Least Squares   F-statistic:                     9260.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:49   Log-Likelihood:            -2.0164e+05
# No. Observations:                  33373   AIC:                         4.033e+05
# Df Residuals:                      33367   BIC:                         4.033e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3062.9033    351.468      8.715      0.000    2374.014    3751.793
# dm_total_officers_rate             9.3032      1.403      6.629      0.000       6.553      12.054
# dm_prison_occupancy_count_rate    -0.3326      0.048     -6.869      0.000      -0.428      -0.238
# lag1_dm_violent_crime_rate         0.6976      0.005    129.056      0.000       0.687       0.708
# lag2_dm_violent_crime_rate         0.1110      0.006     20.030      0.000       0.100       0.122
# YEAR                              -1.5287      0.175     -8.743      0.000      -1.871      -1.186
# ==============================================================================
# Omnibus:                    11055.628   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1500576.314
# Skew:                           0.516   Prob(JB):                         0.00
# Kurtosis:                      35.834   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.571
# Model:                               WLS   Adj. R-squared:                  0.571
# Method:                    Least Squares   F-statistic:                 1.010e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:49   Log-Likelihood:            -2.3033e+05
# No. Observations:                  37988   AIC:                         4.607e+05
# Df Residuals:                      37982   BIC:                         4.607e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   2398.2120    329.674      7.274      0.000    1752.042    3044.382
# dm_total_officers_rate         7.4885      1.286      5.822      0.000       4.968      10.009
# dm_drug_tot_arrests_rate       0.1909      0.023      8.450      0.000       0.147       0.235
# lag1_dm_violent_crime_rate     0.6998      0.005    138.294      0.000       0.690       0.710
# lag2_dm_violent_crime_rate     0.0973      0.005     18.726      0.000       0.087       0.107
# YEAR                          -1.1989      0.164     -7.310      0.000      -1.520      -0.877
# ==============================================================================
# Omnibus:                    12216.005   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1720488.804
# Skew:                           0.440   Prob(JB):                         0.00
# Kurtosis:                      35.957   Cond. No.                     1.31e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.564
# Model:                               WLS   Adj. R-squared:                  0.564
# Method:                    Least Squares   F-statistic:                     9133.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           13:32:49   Log-Likelihood:            -2.1268e+05
# No. Observations:                  35247   AIC:                         4.254e+05
# Df Residuals:                      35241   BIC:                         4.254e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1761.8063    339.292      5.193      0.000    1096.784    2426.829
# dm_total_officers_rate                 5.8374      1.289      4.528      0.000       3.311       8.364
# dm_disorder_arrests_tot_index_rate     0.0946      0.015      6.159      0.000       0.064       0.125
# lag1_dm_violent_crime_rate             0.6997      0.005    132.080      0.000       0.689       0.710
# lag2_dm_violent_crime_rate             0.0943      0.005     17.346      0.000       0.084       0.105
# YEAR                                  -0.8810      0.169     -5.218      0.000      -1.212      -0.550
# ==============================================================================
# Omnibus:                    12461.854   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1855184.108
# Skew:                           0.618   Prob(JB):                         0.00
# Kurtosis:                      38.520   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 'dm_total_officers_rate' and others two at a time

# %%
def wols_lagged_control_multi_3(req_dfs, dep_var, ind_vars_lists, weights_var, control_var=False, dataset_names=False):
    df_count=0
    for df in req_dfs:
        for var_list in ind_vars_lists:
            if control_var:
                model = sm.WLS.from_formula(f'{dep_var} ~ {var_list[0]} + {var_list[1]} + {var_list[2]}+ lag1_{dep_var} + lag2_{dep_var} + {control_var}', 
                                            data=df, 
                                            weights=df[f'{weights_var}'])
            else:
                model = sm.WLS.from_formula(f'{dep_var} ~ {var_list[0]} + {var_list[1]} + {var_list[2]} + lag1_{dep_var} + lag2_{dep_var}', 
                                            data=df, 
                                            weights=df[f'{weights_var}'])
                
            results = model.fit()
            if dataset_names:
                print(dataset_names[df_count])
            print(results.summary(), '\n', '\n')
        df_count += 1

# %%
dm_dep_var_rates = 'dm_violent_crime_rate'
dm_ind_var_lists = [['dm_total_officers_rate', 'dm_jail_occupancy_count_rate', 'dm_drug_tot_arrests_rate'], 
                    ['dm_total_officers_rate', 'dm_prison_occupancy_count_rate', 'dm_drug_tot_arrests_rate'],
                    ['dm_total_officers_rate', 'dm_jail_occupancy_count_rate', 'dm_disorder_arrests_tot_index_rate'], 
                    ['dm_total_officers_rate', 'dm_prison_occupancy_count_rate', 'dm_disorder_arrests_tot_index_rate'],
                    ['dm_total_officers_rate', 'dm_drug_tot_arrests_rate', 'dm_disorder_arrests_tot_index_rate']]

# %% [markdown]
# ### All Agencies - 90-15, 90-02, 03-15

# %% [markdown]
# #### With control var

# %%
wols_lagged_control_multi_3(req_dfs=[all_90_15, all_90_02, all_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['all_90_15', 'all_90_02', 'all_03_15'])
# Out:
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.781
# Model:                               WLS   Adj. R-squared:                  0.781
# Method:                    Least Squares   F-statistic:                 5.800e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:43   Log-Likelihood:            -6.2465e+05
# No. Observations:                  97469   AIC:                         1.249e+06
# Df Residuals:                      97462   BIC:                         1.249e+06
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3319.6954    119.234     27.842      0.000    3085.999    3553.392
# dm_total_officers_rate          -3.8663      0.509     -7.589      0.000      -4.865      -2.868
# dm_jail_occupancy_count_rate     0.0780      0.049      1.583      0.113      -0.019       0.174
# dm_drug_tot_arrests_rate         0.1028      0.014      7.186      0.000       0.075       0.131
# lag1_dm_violent_crime_rate       0.8371      0.003    277.014      0.000       0.831       0.843
# lag2_dm_violent_crime_rate      -0.0205      0.003     -7.014      0.000      -0.026      -0.015
# YEAR                            -1.6657      0.060    -27.993      0.000      -1.782      -1.549
# ==============================================================================
# Omnibus:                    52226.710   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17534992.305
# Skew:                          -1.350   Prob(JB):                         0.00
# Kurtosis:                      68.654   Cond. No.                     6.75e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.75e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.796
# Model:                               WLS   Adj. R-squared:                  0.796
# Method:                    Least Squares   F-statistic:                 5.704e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -5.6018e+05
# No. Observations:                  87831   AIC:                         1.120e+06
# Df Residuals:                      87824   BIC:                         1.120e+06
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2946.9614    123.542     23.854      0.000    2704.820    3189.103
# dm_total_officers_rate            -2.5683      0.516     -4.978      0.000      -3.580      -1.557
# dm_prison_occupancy_count_rate    -0.2313      0.038     -6.115      0.000      -0.305      -0.157
# dm_drug_tot_arrests_rate           0.0770      0.015      5.282      0.000       0.048       0.106
# lag1_dm_violent_crime_rate         0.8540      0.003    268.352      0.000       0.848       0.860
# lag2_dm_violent_crime_rate        -0.0286      0.003     -9.290      0.000      -0.035      -0.023
# YEAR                              -1.4798      0.062    -24.000      0.000      -1.601      -1.359
# ==============================================================================
# Omnibus:                    51513.974   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17740254.820
# Skew:                          -1.607   Prob(JB):                         0.00
# Kurtosis:                      72.550   Cond. No.                     6.89e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.89e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.783
# Model:                               WLS   Adj. R-squared:                  0.783
# Method:                    Least Squares   F-statistic:                 5.432e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -5.7755e+05
# No. Observations:                  90404   AIC:                         1.155e+06
# Df Residuals:                      90397   BIC:                         1.155e+06
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2688.9690    127.946     21.016      0.000    2438.195    2939.743
# dm_total_officers_rate               -14.2133      0.759    -18.719      0.000     -15.702     -12.725
# dm_jail_occupancy_count_rate          -0.0558      0.051     -1.098      0.272      -0.155       0.044
# dm_disorder_arrests_tot_index_rate     0.0672      0.011      6.164      0.000       0.046       0.089
# lag1_dm_violent_crime_rate             0.8322      0.003    266.973      0.000       0.826       0.838
# lag2_dm_violent_crime_rate            -0.0177      0.003     -5.903      0.000      -0.024      -0.012
# YEAR                                  -1.3501      0.064    -21.141      0.000      -1.475      -1.225
# ==============================================================================
# Omnibus:                    39726.244   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13110231.217
# Skew:                          -0.862   Prob(JB):                         0.00
# Kurtosis:                      61.970   Cond. No.                     7.09e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.798
# Model:                               WLS   Adj. R-squared:                  0.798
# Method:                    Least Squares   F-statistic:                 5.337e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -5.1632e+05
# No. Observations:                  81199   AIC:                         1.033e+06
# Df Residuals:                      81192   BIC:                         1.033e+06
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2238.0203    131.195     17.059      0.000    1980.878    2495.162
# dm_total_officers_rate               -12.8074      0.776    -16.497      0.000     -14.329     -11.286
# dm_prison_occupancy_count_rate        -0.4636      0.039    -11.841      0.000      -0.540      -0.387
# dm_disorder_arrests_tot_index_rate     0.0594      0.011      5.302      0.000       0.037       0.081
# lag1_dm_violent_crime_rate             0.8467      0.003    257.512      0.000       0.840       0.853
# lag2_dm_violent_crime_rate            -0.0247      0.003     -7.802      0.000      -0.031      -0.018
# YEAR                                  -1.1252      0.065    -17.182      0.000      -1.254      -0.997
# ==============================================================================
# Omnibus:                    39830.890   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12254241.248
# Skew:                          -1.141   Prob(JB):                         0.00
# Kurtosis:                      63.140   Cond. No.                     7.16e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.16e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.782
# Model:                               WLS   Adj. R-squared:                  0.782
# Method:                    Least Squares   F-statistic:                 5.579e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -5.9529e+05
# No. Observations:                  93297   AIC:                         1.191e+06
# Df Residuals:                      93290   BIC:                         1.191e+06
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2601.1633    122.707     21.198      0.000    2360.658    2841.668
# dm_total_officers_rate               -13.8778      0.748    -18.564      0.000     -15.343     -12.413
# dm_drug_tot_arrests_rate              -0.1039      0.015     -6.878      0.000      -0.134      -0.074
# dm_disorder_arrests_tot_index_rate     0.0824      0.011      7.557      0.000       0.061       0.104
# lag1_dm_violent_crime_rate             0.8312      0.003    270.704      0.000       0.825       0.837
# lag2_dm_violent_crime_rate            -0.0162      0.003     -5.469      0.000      -0.022      -0.010
# YEAR                                  -1.3060      0.061    -21.324      0.000      -1.426      -1.186
# ==============================================================================
# Omnibus:                    40418.272   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13269756.813
# Skew:                          -0.831   Prob(JB):                         0.00
# Kurtosis:                      61.402   Cond. No.                     6.96e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.96e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.748
# Model:                               WLS   Adj. R-squared:                  0.748
# Method:                    Least Squares   F-statistic:                 2.038e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.7102e+05
# No. Observations:                  41277   AIC:                         5.420e+05
# Df Residuals:                      41270   BIC:                         5.421e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.185e+04    444.977     26.624      0.000     1.1e+04    1.27e+04
# dm_total_officers_rate          -6.8829      1.116     -6.167      0.000      -9.070      -4.695
# dm_jail_occupancy_count_rate    -0.5416      0.092     -5.885      0.000      -0.722      -0.361
# dm_drug_tot_arrests_rate        -0.3203      0.025    -12.851      0.000      -0.369      -0.271
# lag1_dm_violent_crime_rate       0.7820      0.005    173.071      0.000       0.773       0.791
# lag2_dm_violent_crime_rate      -0.0267      0.004     -6.429      0.000      -0.035      -0.019
# YEAR                            -5.9345      0.223    -26.642      0.000      -6.371      -5.498
# ==============================================================================
# Omnibus:                    13383.725   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3524469.820
# Skew:                          -0.121   Prob(JB):                         0.00
# Kurtosis:                      48.268   Cond. No.                     1.43e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.767
# Model:                               WLS   Adj. R-squared:                  0.767
# Method:                    Least Squares   F-statistic:                 2.025e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.4061e+05
# No. Observations:                  36844   AIC:                         4.812e+05
# Df Residuals:                      36837   BIC:                         4.813e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       9468.0053    469.558     20.164      0.000    8547.659    1.04e+04
# dm_total_officers_rate            -5.2358      1.108     -4.725      0.000      -7.408      -3.064
# dm_prison_occupancy_count_rate    -0.8099      0.068    -11.829      0.000      -0.944      -0.676
# dm_drug_tot_arrests_rate          -0.3777      0.025    -15.077      0.000      -0.427      -0.329
# lag1_dm_violent_crime_rate         0.7953      0.005    166.687      0.000       0.786       0.805
# lag2_dm_violent_crime_rate        -0.0302      0.004     -6.882      0.000      -0.039      -0.022
# YEAR                              -4.7441      0.235    -20.184      0.000      -5.205      -4.283
# ==============================================================================
# Omnibus:                    12597.060   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2886329.820
# Skew:                          -0.393   Prob(JB):                         0.00
# Kurtosis:                      46.353   Cond. No.                     1.49e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.753
# Model:                               WLS   Adj. R-squared:                  0.753
# Method:                    Least Squares   F-statistic:                 1.971e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.5402e+05
# No. Observations:                  38743   AIC:                         5.081e+05
# Df Residuals:                      38736   BIC:                         5.081e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.182e+04    458.048     25.803      0.000    1.09e+04    1.27e+04
# dm_total_officers_rate               -12.6849      1.288     -9.851      0.000     -15.209     -10.161
# dm_jail_occupancy_count_rate          -0.7138      0.094     -7.564      0.000      -0.899      -0.529
# dm_disorder_arrests_tot_index_rate     0.0303      0.018      1.730      0.084      -0.004       0.065
# lag1_dm_violent_crime_rate             0.7849      0.005    169.906      0.000       0.776       0.794
# lag2_dm_violent_crime_rate            -0.0313      0.004     -7.420      0.000      -0.040      -0.023
# YEAR                                  -5.9203      0.229    -25.820      0.000      -6.370      -5.471
# ==============================================================================
# Omnibus:                    12837.084   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3898488.788
# Skew:                          -0.109   Prob(JB):                         0.00
# Kurtosis:                      52.142   Cond. No.                     1.43e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.772
# Model:                               WLS   Adj. R-squared:                  0.772
# Method:                    Least Squares   F-statistic:                 1.944e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.2483e+05
# No. Observations:                  34470   AIC:                         4.497e+05
# Df Residuals:                      34463   BIC:                         4.497e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           9415.1153    486.190     19.365      0.000    8462.166    1.04e+04
# dm_total_officers_rate               -11.4646      1.284     -8.927      0.000     -13.982      -8.947
# dm_prison_occupancy_count_rate        -0.9835      0.071    -13.934      0.000      -1.122      -0.845
# dm_disorder_arrests_tot_index_rate     0.0113      0.018      0.633      0.527      -0.024       0.046
# lag1_dm_violent_crime_rate             0.7987      0.005    163.393      0.000       0.789       0.808
# lag2_dm_violent_crime_rate            -0.0372      0.004     -8.321      0.000      -0.046      -0.028
# YEAR                                  -4.7176      0.243    -19.384      0.000      -5.195      -4.241
# ==============================================================================
# Omnibus:                    12038.430   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3250299.071
# Skew:                          -0.382   Prob(JB):                         0.00
# Kurtosis:                      50.565   Cond. No.                     1.50e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.755
# Model:                               WLS   Adj. R-squared:                  0.755
# Method:                    Least Squares   F-statistic:                 2.053e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.6194e+05
# No. Observations:                  40028   AIC:                         5.239e+05
# Df Residuals:                      40021   BIC:                         5.240e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.112e+04    441.701     25.179      0.000    1.03e+04     1.2e+04
# dm_total_officers_rate               -12.8287      1.257    -10.208      0.000     -15.292     -10.365
# dm_drug_tot_arrests_rate              -0.4757      0.025    -18.679      0.000      -0.526      -0.426
# dm_disorder_arrests_tot_index_rate     0.0870      0.017      5.008      0.000       0.053       0.121
# lag1_dm_violent_crime_rate             0.7800      0.005    171.796      0.000       0.771       0.789
# lag2_dm_violent_crime_rate            -0.0239      0.004     -5.739      0.000      -0.032      -0.016
# YEAR                                  -5.5704      0.221    -25.191      0.000      -6.004      -5.137
# ==============================================================================
# Omnibus:                    13134.057   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3666802.710
# Skew:                           0.136   Prob(JB):                         0.00
# Kurtosis:                      49.888   Cond. No.                     1.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.803
# Model:                               WLS   Adj. R-squared:                  0.803
# Method:                    Least Squares   F-statistic:                 3.180e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.8921e+05
# No. Observations:                  46897   AIC:                         5.784e+05
# Df Residuals:                      46890   BIC:                         5.785e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1703.6132    267.615      6.366      0.000    1179.085    2228.141
# dm_total_officers_rate          -8.0117      0.622    -12.875      0.000      -9.231      -6.792
# dm_jail_occupancy_count_rate     0.3234      0.053      6.081      0.000       0.219       0.428
# dm_drug_tot_arrests_rate         0.1554      0.018      8.682      0.000       0.120       0.190
# lag1_dm_violent_crime_rate       0.8637      0.005    189.966      0.000       0.855       0.873
# lag2_dm_violent_crime_rate       0.0654      0.005     13.779      0.000       0.056       0.075
# YEAR                            -0.8553      0.133     -6.423      0.000      -1.116      -0.594
# ==============================================================================
# Omnibus:                    17725.734   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8623773.979
# Skew:                          -0.376   Prob(JB):                         0.00
# Kurtosis:                      69.428   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.812
# Model:                               WLS   Adj. R-squared:                  0.812
# Method:                    Least Squares   F-statistic:                 3.063e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.6200e+05
# No. Observations:                  42654   AIC:                         5.240e+05
# Df Residuals:                      42647   BIC:                         5.241e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2446.0157    280.022      8.735      0.000    1897.167    2994.865
# dm_total_officers_rate            -6.4163      0.642     -9.996      0.000      -7.674      -5.158
# dm_prison_occupancy_count_rate    -0.2479      0.045     -5.543      0.000      -0.336      -0.160
# dm_drug_tot_arrests_rate           0.1372      0.018      7.470      0.000       0.101       0.173
# lag1_dm_violent_crime_rate         0.8767      0.005    183.093      0.000       0.867       0.886
# lag2_dm_violent_crime_rate         0.0614      0.005     12.256      0.000       0.052       0.071
# YEAR                              -1.2238      0.139     -8.784      0.000      -1.497      -0.951
# ==============================================================================
# Omnibus:                    16482.476   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9321804.683
# Skew:                          -0.385   Prob(JB):                         0.00
# Kurtosis:                      75.419   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.802
# Model:                               WLS   Adj. R-squared:                  0.802
# Method:                    Least Squares   F-statistic:                 2.916e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.6647e+05
# No. Observations:                  43292   AIC:                         5.330e+05
# Df Residuals:                      43285   BIC:                         5.330e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1335.6387    283.184      4.717      0.000     780.593    1890.684
# dm_total_officers_rate               -15.6335      0.811    -19.266      0.000     -17.224     -14.043
# dm_jail_occupancy_count_rate           0.3249      0.056      5.850      0.000       0.216       0.434
# dm_disorder_arrests_tot_index_rate     0.0391      0.014      2.864      0.004       0.012       0.066
# lag1_dm_violent_crime_rate             0.8744      0.005    183.527      0.000       0.865       0.884
# lag2_dm_violent_crime_rate             0.0626      0.005     12.529      0.000       0.053       0.072
# YEAR                                  -0.6712      0.141     -4.763      0.000      -0.947      -0.395
# ==============================================================================
# Omnibus:                    15793.660   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8837952.025
# Skew:                          -0.164   Prob(JB):                         0.00
# Kurtosis:                      72.996   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.812
# Model:                               WLS   Adj. R-squared:                  0.812
# Method:                    Least Squares   F-statistic:                 2.822e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.4079e+05
# No. Observations:                  39264   AIC:                         4.816e+05
# Df Residuals:                      39257   BIC:                         4.816e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1967.1795    297.519      6.612      0.000    1384.035    2550.324
# dm_total_officers_rate               -15.0038      0.844    -17.782      0.000     -16.658     -13.350
# dm_prison_occupancy_count_rate        -0.1912      0.047     -4.032      0.000      -0.284      -0.098
# dm_disorder_arrests_tot_index_rate     0.0366      0.014      2.556      0.011       0.009       0.065
# lag1_dm_violent_crime_rate             0.8845      0.005    175.952      0.000       0.875       0.894
# lag2_dm_violent_crime_rate             0.0620      0.005     11.732      0.000       0.052       0.072
# YEAR                                  -0.9847      0.148     -6.651      0.000      -1.275      -0.695
# ==============================================================================
# Omnibus:                    14775.341   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9739085.149
# Skew:                          -0.216   Prob(JB):                         0.00
# Kurtosis:                      80.154   Cond. No.                     1.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.801
# Model:                               WLS   Adj. R-squared:                  0.801
# Method:                    Least Squares   F-statistic:                 3.000e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:44   Log-Likelihood:            -2.7438e+05
# No. Observations:                  44638   AIC:                         5.488e+05
# Df Residuals:                      44631   BIC:                         5.488e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1175.6843    278.354      4.224      0.000     630.106    1721.262
# dm_total_officers_rate               -15.4696      0.798    -19.396      0.000     -17.033     -13.906
# dm_drug_tot_arrests_rate               0.1617      0.019      8.675      0.000       0.125       0.198
# dm_disorder_arrests_tot_index_rate     0.0161      0.014      1.179      0.239      -0.011       0.043
# lag1_dm_violent_crime_rate             0.8732      0.005    186.033      0.000       0.864       0.882
# lag2_dm_violent_crime_rate             0.0609      0.005     12.357      0.000       0.051       0.071
# YEAR                                  -0.5916      0.139     -4.271      0.000      -0.863      -0.320
# ==============================================================================
# Omnibus:                    16316.468   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9433545.360
# Skew:                          -0.149   Prob(JB):                         0.00
# Kurtosis:                      74.218   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Without control var

# %%
wols_lagged_control_multi_3(req_dfs=[all_90_15, all_90_02, all_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       weights_var='fnl_population_wt',
                       dataset_names=['all_90_15', 'all_90_02', 'all_03_15'])
# Out:
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.779
# Model:                               WLS   Adj. R-squared:                  0.779
# Method:                    Least Squares   F-statistic:                 6.889e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:57   Log-Likelihood:            -6.2504e+05
# No. Observations:                  97469   AIC:                         1.250e+06
# Df Residuals:                      97463   BIC:                         1.250e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -18.0052      0.359    -50.085      0.000     -18.710     -17.301
# dm_total_officers_rate          -3.7095      0.511     -7.253      0.000      -4.712      -2.707
# dm_jail_occupancy_count_rate    -0.2164      0.048     -4.480      0.000      -0.311      -0.122
# dm_drug_tot_arrests_rate         0.0974      0.014      6.779      0.000       0.069       0.126
# lag1_dm_violent_crime_rate       0.8489      0.003    282.531      0.000       0.843       0.855
# lag2_dm_violent_crime_rate      -0.0102      0.003     -3.505      0.000      -0.016      -0.004
# ==============================================================================
# Omnibus:                    51443.092   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17644879.352
# Skew:                          -1.304   Prob(JB):                         0.00
# Kurtosis:                      68.863   Cond. No.                         498.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.794
# Model:                               WLS   Adj. R-squared:                  0.794
# Method:                    Least Squares   F-statistic:                 6.788e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:57   Log-Likelihood:            -5.6046e+05
# No. Observations:                  87831   AIC:                         1.121e+06
# Df Residuals:                      87825   BIC:                         1.121e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -17.9897      0.366    -49.191      0.000     -18.706     -17.273
# dm_total_officers_rate            -2.0288      0.517     -3.923      0.000      -3.042      -1.015
# dm_prison_occupancy_count_rate    -0.4668      0.037    -12.738      0.000      -0.539      -0.395
# dm_drug_tot_arrests_rate           0.0837      0.015      5.724      0.000       0.055       0.112
# lag1_dm_violent_crime_rate         0.8638      0.003    272.868      0.000       0.858       0.870
# lag2_dm_violent_crime_rate        -0.0191      0.003     -6.232      0.000      -0.025      -0.013
# ==============================================================================
# Omnibus:                    50811.909   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18097596.410
# Skew:                          -1.556   Prob(JB):                         0.00
# Kurtosis:                      73.253   Cond. No.                         497.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.782
# Model:                               WLS   Adj. R-squared:                  0.782
# Method:                    Least Squares   F-statistic:                 6.478e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:57   Log-Likelihood:            -5.7777e+05
# No. Observations:                  90404   AIC:                         1.156e+06
# Df Residuals:                      90398   BIC:                         1.156e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -15.8939      0.367    -43.299      0.000     -16.613     -15.174
# dm_total_officers_rate               -14.7747      0.761    -19.422      0.000     -16.266     -13.284
# dm_jail_occupancy_count_rate          -0.2837      0.050     -5.695      0.000      -0.381      -0.186
# dm_disorder_arrests_tot_index_rate     0.1413      0.010     13.670      0.000       0.121       0.162
# lag1_dm_violent_crime_rate             0.8398      0.003    270.586      0.000       0.834       0.846
# lag2_dm_violent_crime_rate            -0.0108      0.003     -3.617      0.000      -0.017      -0.005
# ==============================================================================
# Omnibus:                    38540.867   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12818551.280
# Skew:                          -0.791   Prob(JB):                         0.00
# Kurtosis:                      61.314   Cond. No.                         723.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.797
# Model:                               WLS   Adj. R-squared:                  0.797
# Method:                    Least Squares   F-statistic:                 6.376e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:57   Log-Likelihood:            -5.1647e+05
# No. Observations:                  81199   AIC:                         1.033e+06
# Df Residuals:                      81193   BIC:                         1.033e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -16.1854      0.374    -43.264      0.000     -16.919     -15.452
# dm_total_officers_rate               -12.9816      0.778    -16.693      0.000     -14.506     -11.457
# dm_prison_occupancy_count_rate        -0.6163      0.038    -16.133      0.000      -0.691      -0.541
# dm_disorder_arrests_tot_index_rate     0.1161      0.011     10.830      0.000       0.095       0.137
# lag1_dm_violent_crime_rate             0.8527      0.003    260.320      0.000       0.846       0.859
# lag2_dm_violent_crime_rate            -0.0184      0.003     -5.844      0.000      -0.025      -0.012
# ==============================================================================
# Omnibus:                    38596.246   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11941220.049
# Skew:                          -1.063   Prob(JB):                         0.00
# Kurtosis:                      62.371   Cond. No.                         730.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.781
# Model:                               WLS   Adj. R-squared:                  0.781
# Method:                    Least Squares   F-statistic:                 6.653e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:57   Log-Likelihood:            -5.9552e+05
# No. Observations:                  93297   AIC:                         1.191e+06
# Df Residuals:                      93291   BIC:                         1.191e+06
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -15.3796      0.361    -42.655      0.000     -16.086     -14.673
# dm_total_officers_rate               -14.8174      0.748    -19.807      0.000     -16.284     -13.351
# dm_drug_tot_arrests_rate              -0.1340      0.015     -8.887      0.000      -0.164      -0.104
# dm_disorder_arrests_tot_index_rate     0.1634      0.010     15.949      0.000       0.143       0.183
# lag1_dm_violent_crime_rate             0.8388      0.003    274.353      0.000       0.833       0.845
# lag2_dm_violent_crime_rate            -0.0093      0.003     -3.173      0.002      -0.015      -0.004
# ==============================================================================
# Omnibus:                    39011.406   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12929187.572
# Skew:                          -0.748   Prob(JB):                         0.00
# Kurtosis:                      60.652   Cond. No.                         722.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.743
# Model:                               WLS   Adj. R-squared:                  0.743
# Method:                    Least Squares   F-statistic:                 2.390e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.7137e+05
# No. Observations:                  41277   AIC:                         5.427e+05
# Df Residuals:                      41271   BIC:                         5.428e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -7.7374      0.696    -11.119      0.000      -9.101      -6.373
# dm_total_officers_rate          -8.6071      1.124     -7.660      0.000     -10.810      -6.405
# dm_jail_occupancy_count_rate    -1.0522      0.091    -11.591      0.000      -1.230      -0.874
# dm_drug_tot_arrests_rate        -0.3786      0.025    -15.118      0.000      -0.428      -0.330
# lag1_dm_violent_crime_rate       0.8041      0.004    179.504      0.000       0.795       0.813
# lag2_dm_violent_crime_rate      -0.0231      0.004     -5.523      0.000      -0.031      -0.015
# ==============================================================================
# Omnibus:                    13642.864   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3600829.200
# Skew:                          -0.218   Prob(JB):                         0.00
# Kurtosis:                      48.754   Cond. No.                         758.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.765
# Model:                               WLS   Adj. R-squared:                  0.765
# Method:                    Least Squares   F-statistic:                 2.395e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.4081e+05
# No. Observations:                  36844   AIC:                         4.816e+05
# Df Residuals:                      36838   BIC:                         4.817e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -9.3595      0.703    -13.311      0.000     -10.738      -7.981
# dm_total_officers_rate            -5.4772      1.114     -4.916      0.000      -7.661      -3.293
# dm_prison_occupancy_count_rate    -1.2810      0.065    -19.794      0.000      -1.408      -1.154
# dm_drug_tot_arrests_rate          -0.4104      0.025    -16.327      0.000      -0.460      -0.361
# lag1_dm_violent_crime_rate         0.8105      0.005    171.067      0.000       0.801       0.820
# lag2_dm_violent_crime_rate        -0.0254      0.004     -5.770      0.000      -0.034      -0.017
# ==============================================================================
# Omnibus:                    12815.484   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2907190.595
# Skew:                          -0.440   Prob(JB):                         0.00
# Kurtosis:                      46.508   Cond. No.                         748.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.749
# Model:                               WLS   Adj. R-squared:                  0.749
# Method:                    Least Squares   F-statistic:                 2.312e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.5435e+05
# No. Observations:                  38743   AIC:                         5.087e+05
# Df Residuals:                      38737   BIC:                         5.088e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -7.9698      0.732    -10.885      0.000      -9.405      -6.535
# dm_total_officers_rate               -16.2966      1.291    -12.624      0.000     -18.827     -13.766
# dm_jail_occupancy_count_rate          -1.1990      0.093    -12.855      0.000      -1.382      -1.016
# dm_disorder_arrests_tot_index_rate     0.1052      0.017      6.038      0.000       0.071       0.139
# lag1_dm_violent_crime_rate             0.8068      0.005    176.171      0.000       0.798       0.816
# lag2_dm_violent_crime_rate            -0.0301      0.004     -7.060      0.000      -0.038      -0.022
# ==============================================================================
# Omnibus:                    13025.751   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3966945.241
# Skew:                          -0.192   Prob(JB):                         0.00
# Kurtosis:                      52.571   Cond. No.                         857.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.769
# Model:                               WLS   Adj. R-squared:                  0.769
# Method:                    Least Squares   F-statistic:                 2.300e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.2502e+05
# No. Observations:                  34470   AIC:                         4.500e+05
# Df Residuals:                      34464   BIC:                         4.501e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -9.2391      0.734    -12.583      0.000     -10.678      -7.800
# dm_total_officers_rate               -13.0982      1.288    -10.166      0.000     -15.624     -10.573
# dm_prison_occupancy_count_rate        -1.4618      0.066    -21.987      0.000      -1.592      -1.332
# dm_disorder_arrests_tot_index_rate     0.0509      0.018      2.865      0.004       0.016       0.086
# lag1_dm_violent_crime_rate             0.8136      0.005    167.666      0.000       0.804       0.823
# lag2_dm_violent_crime_rate            -0.0339      0.004     -7.533      0.000      -0.043      -0.025
# ==============================================================================
# Omnibus:                    12194.937   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3265787.762
# Skew:                          -0.420   Prob(JB):                         0.00
# Kurtosis:                      50.677   Cond. No.                         851.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.751
# Model:                               WLS   Adj. R-squared:                  0.751
# Method:                    Least Squares   F-statistic:                 2.413e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.6226e+05
# No. Observations:                  40028   AIC:                         5.245e+05
# Df Residuals:                      40022   BIC:                         5.246e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -5.6535      0.701     -8.065      0.000      -7.027      -4.280
# dm_total_officers_rate               -17.0673      1.255    -13.597      0.000     -19.528     -14.607
# dm_drug_tot_arrests_rate              -0.5706      0.025    -22.477      0.000      -0.620      -0.521
# dm_disorder_arrests_tot_index_rate     0.1742      0.017     10.157      0.000       0.141       0.208
# lag1_dm_violent_crime_rate             0.8004      0.005    177.787      0.000       0.792       0.809
# lag2_dm_violent_crime_rate            -0.0222      0.004     -5.295      0.000      -0.030      -0.014
# ==============================================================================
# Omnibus:                    13132.392   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3733906.552
# Skew:                           0.115   Prob(JB):                         0.00
# Kurtosis:                      50.315   Cond. No.                         851.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.803
# Model:                               WLS   Adj. R-squared:                  0.803
# Method:                    Least Squares   F-statistic:                 3.812e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.8923e+05
# No. Observations:                  46897   AIC:                         5.785e+05
# Df Residuals:                      46891   BIC:                         5.785e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -15.3817      0.467    -32.963      0.000     -16.296     -14.467
# dm_total_officers_rate          -7.9450      0.622    -12.764      0.000      -9.165      -6.725
# dm_jail_occupancy_count_rate     0.3300      0.053      6.204      0.000       0.226       0.434
# dm_drug_tot_arrests_rate         0.1711      0.018      9.647      0.000       0.136       0.206
# lag1_dm_violent_crime_rate       0.8656      0.005    190.686      0.000       0.857       0.875
# lag2_dm_violent_crime_rate       0.0662      0.005     13.950      0.000       0.057       0.076
# ==============================================================================
# Omnibus:                    17435.529   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8547475.313
# Skew:                          -0.320   Prob(JB):                         0.00
# Kurtosis:                      69.135   Cond. No.                         433.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.811
# Model:                               WLS   Adj. R-squared:                  0.811
# Method:                    Least Squares   F-statistic:                 3.668e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.6203e+05
# No. Observations:                  42654   AIC:                         5.241e+05
# Df Residuals:                      42648   BIC:                         5.241e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -13.8026      0.494    -27.934      0.000     -14.771     -12.834
# dm_total_officers_rate            -6.5315      0.642    -10.169      0.000      -7.790      -5.273
# dm_prison_occupancy_count_rate    -0.1970      0.044     -4.437      0.000      -0.284      -0.110
# dm_drug_tot_arrests_rate           0.1586      0.018      8.706      0.000       0.123       0.194
# lag1_dm_violent_crime_rate         0.8795      0.005    183.900      0.000       0.870       0.889
# lag2_dm_violent_crime_rate         0.0621      0.005     12.388      0.000       0.052       0.072
# ==============================================================================
# Omnibus:                    16128.888   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9213294.244
# Skew:                          -0.310   Prob(JB):                         0.00
# Kurtosis:                      74.997   Cond. No.                         437.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.802
# Model:                               WLS   Adj. R-squared:                  0.802
# Method:                    Least Squares   F-statistic:                 3.497e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.6648e+05
# No. Observations:                  43292   AIC:                         5.330e+05
# Df Residuals:                      43286   BIC:                         5.330e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -13.0320      0.503    -25.924      0.000     -14.017     -12.047
# dm_total_officers_rate               -15.5563      0.811    -19.170      0.000     -17.147     -13.966
# dm_jail_occupancy_count_rate           0.3285      0.056      5.913      0.000       0.220       0.437
# dm_disorder_arrests_tot_index_rate     0.0565      0.013      4.288      0.000       0.031       0.082
# lag1_dm_violent_crime_rate             0.8756      0.005    184.019      0.000       0.866       0.885
# lag2_dm_violent_crime_rate             0.0632      0.005     12.643      0.000       0.053       0.073
# ==============================================================================
# Omnibus:                    15685.187   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8767797.231
# Skew:                          -0.116   Prob(JB):                         0.00
# Kurtosis:                      72.718   Cond. No.                         538.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.812
# Model:                               WLS   Adj. R-squared:                  0.812
# Method:                    Least Squares   F-statistic:                 3.381e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.4081e+05
# No. Observations:                  39264   AIC:                         4.816e+05
# Df Residuals:                      39258   BIC:                         4.817e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -11.7459      0.531    -22.127      0.000     -12.786     -10.705
# dm_total_officers_rate               -15.1421      0.844    -17.941      0.000     -16.796     -13.488
# dm_prison_occupancy_count_rate        -0.1357      0.047     -2.905      0.004      -0.227      -0.044
# dm_disorder_arrests_tot_index_rate     0.0621      0.014      4.499      0.000       0.035       0.089
# lag1_dm_violent_crime_rate             0.8861      0.005    176.405      0.000       0.876       0.896
# lag2_dm_violent_crime_rate             0.0624      0.005     11.810      0.000       0.052       0.073
# ==============================================================================
# Omnibus:                    14600.317   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9605685.866
# Skew:                          -0.150   Prob(JB):                         0.00
# Kurtosis:                      79.625   Cond. No.                         549.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# all_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.801
# Model:                               WLS   Adj. R-squared:                  0.801
# Method:                    Least Squares   F-statistic:                 3.598e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:00:58   Log-Likelihood:            -2.7439e+05
# No. Observations:                  44638   AIC:                         5.488e+05
# Df Residuals:                      44632   BIC:                         5.489e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -13.2045      0.494    -26.756      0.000     -14.172     -12.237
# dm_total_officers_rate               -15.4201      0.798    -19.333      0.000     -16.983     -13.857
# dm_drug_tot_arrests_rate               0.1696      0.019      9.142      0.000       0.133       0.206
# dm_disorder_arrests_tot_index_rate     0.0303      0.013      2.281      0.023       0.004       0.056
# lag1_dm_violent_crime_rate             0.8742      0.005    186.446      0.000       0.865       0.883
# lag2_dm_violent_crime_rate             0.0612      0.005     12.428      0.000       0.052       0.071
# ==============================================================================
# Omnibus:                    16223.764   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9365772.643
# Skew:                          -0.107   Prob(JB):                         0.00
# Kurtosis:                      73.962   Cond. No.                         536.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Large Agencies - 90-15, 90-02, 03-15

# %%
wols_lagged_control_multi_3(req_dfs=[large_90_15, large_90_02, large_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['large_90_15', 'large_90_02', 'large_03_15'])
# Out:
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.887
# Model:                               WLS   Adj. R-squared:                  0.887
# Method:                    Least Squares   F-statistic:                 1.055e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -49910.
# No. Observations:                   8094   AIC:                         9.983e+04
# Df Residuals:                       8087   BIC:                         9.988e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2919.8100    394.127      7.408      0.000    2147.219    3692.401
# dm_total_officers_rate         -18.1933      2.096     -8.682      0.000     -22.301     -14.085
# dm_jail_occupancy_count_rate    -0.1737      0.213     -0.815      0.415      -0.591       0.244
# dm_drug_tot_arrests_rate         0.0309      0.041      0.751      0.453      -0.050       0.111
# lag1_dm_violent_crime_rate       1.0220      0.010    102.475      0.000       1.002       1.042
# lag2_dm_violent_crime_rate      -0.1625      0.010    -16.839      0.000      -0.181      -0.144
# YEAR                            -1.4699      0.197     -7.472      0.000      -1.855      -1.084
# ==============================================================================
# Omnibus:                     3145.372   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           170452.871
# Skew:                          -1.078   Prob(JB):                         0.00
# Kurtosis:                      25.378   Cond. No.                     7.30e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.3e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.893
# Model:                               WLS   Adj. R-squared:                  0.893
# Method:                    Least Squares   F-statistic:                 1.061e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -46832.
# No. Observations:                   7632   AIC:                         9.368e+04
# Df Residuals:                       7625   BIC:                         9.373e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2714.8810    401.140      6.768      0.000    1928.536    3501.226
# dm_total_officers_rate           -18.2670      2.081     -8.779      0.000     -22.346     -14.188
# dm_prison_occupancy_count_rate    -0.1038      0.126     -0.823      0.411      -0.351       0.143
# dm_drug_tot_arrests_rate           0.0151      0.042      0.359      0.719      -0.067       0.097
# lag1_dm_violent_crime_rate         1.0426      0.010    102.113      0.000       1.023       1.063
# lag2_dm_violent_crime_rate        -0.1790      0.010    -18.089      0.000      -0.198      -0.160
# YEAR                              -1.3674      0.200     -6.829      0.000      -1.760      -0.975
# ==============================================================================
# Omnibus:                     3072.966   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           172098.569
# Skew:                          -1.136   Prob(JB):                         0.00
# Kurtosis:                      26.152   Cond. No.                     7.46e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.46e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.889
# Model:                               WLS   Adj. R-squared:                  0.889
# Method:                    Least Squares   F-statistic:                     9508.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -43848.
# No. Observations:                   7124   AIC:                         8.771e+04
# Df Residuals:                       7117   BIC:                         8.776e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2527.8366    435.709      5.802      0.000    1673.717    3381.956
# dm_total_officers_rate               -20.8845      2.181     -9.574      0.000     -25.161     -16.608
# dm_jail_occupancy_count_rate          -0.6892      0.234     -2.944      0.003      -1.148      -0.230
# dm_disorder_arrests_tot_index_rate    -0.0116      0.037     -0.316      0.752      -0.083       0.060
# lag1_dm_violent_crime_rate             1.0118      0.011     96.232      0.000       0.991       1.032
# lag2_dm_violent_crime_rate            -0.1540      0.010    -15.191      0.000      -0.174      -0.134
# YEAR                                  -1.2736      0.217     -5.856      0.000      -1.700      -0.847
# ==============================================================================
# Omnibus:                     2287.212   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           117269.671
# Skew:                          -0.759   Prob(JB):                         0.00
# Kurtosis:                      22.818   Cond. No.                     7.69e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.894
# Model:                               WLS   Adj. R-squared:                  0.893
# Method:                    Least Squares   F-statistic:                     9442.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -41442.
# No. Observations:                   6758   AIC:                         8.290e+04
# Df Residuals:                       6751   BIC:                         8.295e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2214.1331    437.654      5.059      0.000    1356.193    3072.073
# dm_total_officers_rate               -19.7765      2.187     -9.044      0.000     -24.063     -15.490
# dm_prison_occupancy_count_rate        -0.5482      0.132     -4.164      0.000      -0.806      -0.290
# dm_disorder_arrests_tot_index_rate    -0.0094      0.037     -0.252      0.801      -0.082       0.064
# lag1_dm_violent_crime_rate             1.0245      0.011     95.109      0.000       1.003       1.046
# lag2_dm_violent_crime_rate            -0.1646      0.010    -15.810      0.000      -0.185      -0.144
# YEAR                                  -1.1169      0.218     -5.112      0.000      -1.545      -0.689
# ==============================================================================
# Omnibus:                     2274.417   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           109953.086
# Skew:                          -0.854   Prob(JB):                         0.00
# Kurtosis:                      22.687   Cond. No.                     7.73e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.888
# Model:                               WLS   Adj. R-squared:                  0.888
# Method:                    Least Squares   F-statistic:                     9752.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -45360.
# No. Observations:                   7375   AIC:                         9.073e+04
# Df Residuals:                       7368   BIC:                         9.078e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2701.9387    421.059      6.417      0.000    1876.544    3527.334
# dm_total_officers_rate               -20.6892      2.135     -9.689      0.000     -24.875     -16.503
# dm_drug_tot_arrests_rate              -0.2494      0.046     -5.447      0.000      -0.339      -0.160
# dm_disorder_arrests_tot_index_rate     0.0314      0.037      0.854      0.393      -0.041       0.104
# lag1_dm_violent_crime_rate             1.0062      0.010     96.974      0.000       0.986       1.027
# lag2_dm_violent_crime_rate            -0.1485      0.010    -14.835      0.000      -0.168      -0.129
# YEAR                                  -1.3601      0.210     -6.471      0.000      -1.772      -0.948
# ==============================================================================
# Omnibus:                     2267.419   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           113468.289
# Skew:                          -0.697   Prob(JB):                         0.00
# Kurtosis:                      22.165   Cond. No.                     7.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.863
# Model:                               WLS   Adj. R-squared:                  0.863
# Method:                    Least Squares   F-statistic:                     3885.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -23338.
# No. Observations:                   3706   AIC:                         4.669e+04
# Df Residuals:                       3699   BIC:                         4.673e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.049e+04   1387.565      7.558      0.000    7767.328    1.32e+04
# dm_total_officers_rate         -18.3234      4.181     -4.382      0.000     -26.521     -10.126
# dm_jail_occupancy_count_rate    -1.6607      0.371     -4.482      0.000      -2.387      -0.934
# dm_drug_tot_arrests_rate        -0.5219      0.068     -7.630      0.000      -0.656      -0.388
# lag1_dm_violent_crime_rate       0.9395      0.014     66.823      0.000       0.912       0.967
# lag2_dm_violent_crime_rate      -0.1372      0.013    -10.741      0.000      -0.162      -0.112
# YEAR                            -5.2563      0.695     -7.568      0.000      -6.618      -3.895
# ==============================================================================
# Omnibus:                      954.250   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29870.632
# Skew:                          -0.571   Prob(JB):                         0.00
# Kurtosis:                      16.861   Cond. No.                     1.56e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.874
# Model:                               WLS   Adj. R-squared:                  0.874
# Method:                    Least Squares   F-statistic:                     4000.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -21665.
# No. Observations:                   3462   AIC:                         4.334e+04
# Df Residuals:                       3455   BIC:                         4.339e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       7926.0306   1443.346      5.491      0.000    5096.134    1.08e+04
# dm_total_officers_rate           -19.0892      4.065     -4.695      0.000     -27.060     -11.118
# dm_prison_occupancy_count_rate    -0.9358      0.215     -4.361      0.000      -1.357      -0.515
# dm_drug_tot_arrests_rate          -0.5677      0.068     -8.344      0.000      -0.701      -0.434
# lag1_dm_violent_crime_rate         0.9518      0.014     65.713      0.000       0.923       0.980
# lag2_dm_violent_crime_rate        -0.1435      0.013    -10.845      0.000      -0.169      -0.118
# YEAR                              -3.9739      0.722     -5.501      0.000      -5.390      -2.557
# ==============================================================================
# Omnibus:                      951.829   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22780.320
# Skew:                          -0.749   Prob(JB):                         0.00
# Kurtosis:                      15.477   Cond. No.                     1.64e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.866
# Model:                               WLS   Adj. R-squared:                  0.865
# Method:                    Least Squares   F-statistic:                     3535.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -20810.
# No. Observations:                   3301   AIC:                         4.163e+04
# Df Residuals:                       3294   BIC:                         4.168e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.125e+04   1467.958      7.666      0.000    8374.731    1.41e+04
# dm_total_officers_rate               -22.4612      4.218     -5.325      0.000     -30.732     -14.191
# dm_jail_occupancy_count_rate          -2.0778      0.402     -5.166      0.000      -2.866      -1.289
# dm_disorder_arrests_tot_index_rate    -0.0746      0.055     -1.349      0.177      -0.183       0.034
# lag1_dm_violent_crime_rate             0.9424      0.015     63.921      0.000       0.914       0.971
# lag2_dm_violent_crime_rate            -0.1413      0.013    -10.546      0.000      -0.168      -0.115
# YEAR                                  -5.6401      0.735     -7.676      0.000      -7.081      -4.199
# ==============================================================================
# Omnibus:                      918.626   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29384.575
# Skew:                          -0.671   Prob(JB):                         0.00
# Kurtosis:                      17.555   Cond. No.                     1.56e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.875
# Model:                               WLS   Adj. R-squared:                  0.874
# Method:                    Least Squares   F-statistic:                     3596.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -19424.
# No. Observations:                   3098   AIC:                         3.886e+04
# Df Residuals:                       3091   BIC:                         3.890e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           8500.0698   1532.856      5.545      0.000    5494.550    1.15e+04
# dm_total_officers_rate               -23.0841      4.132     -5.587      0.000     -31.186     -14.982
# dm_prison_occupancy_count_rate        -1.1793      0.225     -5.238      0.000      -1.621      -0.738
# dm_disorder_arrests_tot_index_rate    -0.0888      0.055     -1.617      0.106      -0.197       0.019
# lag1_dm_violent_crime_rate             0.9571      0.015     63.077      0.000       0.927       0.987
# lag2_dm_violent_crime_rate            -0.1516      0.014    -10.921      0.000      -0.179      -0.124
# YEAR                                  -4.2619      0.767     -5.555      0.000      -5.766      -2.757
# ==============================================================================
# Omnibus:                      909.631   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23304.722
# Skew:                          -0.816   Prob(JB):                         0.00
# Kurtosis:                      16.337   Cond. No.                     1.64e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.867
# Model:                               WLS   Adj. R-squared:                  0.867
# Method:                    Least Squares   F-statistic:                     3714.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -21513.
# No. Observations:                   3420   AIC:                         4.304e+04
# Df Residuals:                       3413   BIC:                         4.308e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.191e+04   1391.292      8.562      0.000    9184.667    1.46e+04
# dm_total_officers_rate               -17.2229      4.198     -4.103      0.000     -25.453      -8.993
# dm_drug_tot_arrests_rate              -0.7183      0.072     -9.932      0.000      -0.860      -0.576
# dm_disorder_arrests_tot_index_rate     0.0085      0.055      0.156      0.876      -0.098       0.115
# lag1_dm_violent_crime_rate             0.9240      0.015     63.719      0.000       0.896       0.952
# lag2_dm_violent_crime_rate            -0.1266      0.013     -9.645      0.000      -0.152      -0.101
# YEAR                                  -5.9677      0.696     -8.569      0.000      -7.333      -4.602
# ==============================================================================
# Omnibus:                      800.612   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28042.648
# Skew:                          -0.381   Prob(JB):                         0.00
# Kurtosis:                      17.008   Cond. No.                     1.53e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.53e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.891
# Model:                               WLS   Adj. R-squared:                  0.890
# Method:                    Least Squares   F-statistic:                     4980.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -21674.
# No. Observations:                   3681   AIC:                         4.336e+04
# Df Residuals:                       3674   BIC:                         4.341e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1177.0809    846.792      1.390      0.165    -483.148    2837.310
# dm_total_officers_rate         -21.7815      2.010    -10.834      0.000     -25.723     -17.840
# dm_jail_occupancy_count_rate     0.1988      0.242      0.822      0.411      -0.275       0.673
# dm_drug_tot_arrests_rate         0.0181      0.054      0.338      0.735      -0.087       0.123
# lag1_dm_violent_crime_rate       1.0343      0.016     63.557      0.000       1.002       1.066
# lag2_dm_violent_crime_rate      -0.0679      0.017     -3.966      0.000      -0.101      -0.034
# YEAR                            -0.5933      0.421     -1.408      0.159      -1.419       0.233
# ==============================================================================
# Omnibus:                     1144.513   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           154168.530
# Skew:                           0.329   Prob(JB):                         0.00
# Kurtosis:                      34.698   Cond. No.                     1.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.894
# Model:                               WLS   Adj. R-squared:                  0.894
# Method:                    Least Squares   F-statistic:                     4898.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -20551.
# No. Observations:                   3499   AIC:                         4.112e+04
# Df Residuals:                       3492   BIC:                         4.116e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2715.3821    878.402      3.091      0.002     993.149    4437.615
# dm_total_officers_rate           -18.8767      2.073     -9.105      0.000     -22.942     -14.812
# dm_prison_occupancy_count_rate    -0.6345      0.163     -3.883      0.000      -0.955      -0.314
# dm_drug_tot_arrests_rate           0.0436      0.055      0.790      0.430      -0.065       0.152
# lag1_dm_violent_crime_rate         1.0559      0.017     63.463      0.000       1.023       1.089
# lag2_dm_violent_crime_rate        -0.0829      0.018     -4.724      0.000      -0.117      -0.048
# YEAR                              -1.3574      0.437     -3.106      0.002      -2.214      -0.500
# ==============================================================================
# Omnibus:                     1183.132   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           181432.611
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                      38.264   Cond. No.                     1.43e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.888
# Model:                               WLS   Adj. R-squared:                  0.888
# Method:                    Least Squares   F-statistic:                     4269.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -19115.
# No. Observations:                   3237   AIC:                         3.824e+04
# Df Residuals:                       3230   BIC:                         3.829e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            593.9807    936.906      0.634      0.526   -1243.010    2430.971
# dm_total_officers_rate               -24.1257      2.162    -11.158      0.000     -28.365     -19.886
# dm_jail_occupancy_count_rate           0.1454      0.270      0.539      0.590      -0.384       0.675
# dm_disorder_arrests_tot_index_rate    -0.0209      0.047     -0.443      0.658      -0.113       0.071
# lag1_dm_violent_crime_rate             1.0497      0.018     59.648      0.000       1.015       1.084
# lag2_dm_violent_crime_rate            -0.0805      0.019     -4.328      0.000      -0.117      -0.044
# YEAR                                  -0.3029      0.466     -0.650      0.516      -1.217       0.611
# ==============================================================================
# Omnibus:                     1077.865   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           143968.177
# Skew:                           0.485   Prob(JB):                         0.00
# Kurtosis:                      35.657   Cond. No.                     1.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.889
# Model:                               WLS   Adj. R-squared:                  0.889
# Method:                    Least Squares   F-statistic:                     4138.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -18252.
# No. Observations:                   3093   AIC:                         3.652e+04
# Df Residuals:                       3086   BIC:                         3.656e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2282.8983    996.741      2.290      0.022     328.555    4237.241
# dm_total_officers_rate               -20.7010      2.267     -9.131      0.000     -25.146     -16.256
# dm_prison_occupancy_count_rate        -0.6076      0.178     -3.413      0.001      -0.957      -0.259
# dm_disorder_arrests_tot_index_rate    -0.0179      0.050     -0.358      0.720      -0.116       0.080
# lag1_dm_violent_crime_rate             1.0551      0.018     58.822      0.000       1.020       1.090
# lag2_dm_violent_crime_rate            -0.0796      0.019     -4.183      0.000      -0.117      -0.042
# YEAR                                  -1.1421      0.496     -2.303      0.021      -2.115      -0.170
# ==============================================================================
# Omnibus:                     1069.604   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           159512.906
# Skew:                           0.524   Prob(JB):                         0.00
# Kurtosis:                      38.166   Cond. No.                     1.49e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# large_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.888
# Model:                               WLS   Adj. R-squared:                  0.888
# Method:                    Least Squares   F-statistic:                     4405.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:05   Log-Likelihood:                -19746.
# No. Observations:                   3347   AIC:                         3.951e+04
# Df Residuals:                       3340   BIC:                         3.955e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            634.4578    925.099      0.686      0.493   -1179.361    2448.276
# dm_total_officers_rate               -23.8439      2.052    -11.621      0.000     -27.867     -19.821
# dm_drug_tot_arrests_rate               0.0310      0.059      0.522      0.602      -0.085       0.147
# dm_disorder_arrests_tot_index_rate    -0.0229      0.047     -0.485      0.628      -0.116       0.070
# lag1_dm_violent_crime_rate             1.0482      0.017     60.486      0.000       1.014       1.082
# lag2_dm_violent_crime_rate            -0.0783      0.018     -4.265      0.000      -0.114      -0.042
# YEAR                                  -0.3229      0.460     -0.701      0.483      -1.226       0.580
# ==============================================================================
# Omnibus:                     1108.993   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149776.749
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                      35.758   Cond. No.                     1.43e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Medium Agencies - 90-15, 90-02, 03-15

# %%
wols_lagged_control_multi_3(req_dfs=[medium_90_15, medium_90_02, medium_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['medium_90_15', 'medium_90_02', 'medium_03_15'])
# Out:
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.679
# Model:                               WLS   Adj. R-squared:                  0.678
# Method:                    Least Squares   F-statistic:                     4724.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -81178.
# No. Observations:                  13431   AIC:                         1.624e+05
# Df Residuals:                      13424   BIC:                         1.624e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3754.0932    286.349     13.110      0.000    3192.810    4315.377
# dm_total_officers_rate           2.3723      0.761      3.117      0.002       0.881       3.864
# dm_jail_occupancy_count_rate     0.0483      0.132      0.366      0.714      -0.210       0.307
# dm_drug_tot_arrests_rate         0.1848      0.041      4.536      0.000       0.105       0.265
# lag1_dm_violent_crime_rate       0.7520      0.008     91.739      0.000       0.736       0.768
# lag2_dm_violent_crime_rate       0.0203      0.008      2.573      0.010       0.005       0.036
# YEAR                            -1.8790      0.143    -13.149      0.000      -2.159      -1.599
# ==============================================================================
# Omnibus:                     3478.035   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           243447.699
# Skew:                           0.260   Prob(JB):                         0.00
# Kurtosis:                      23.851   Cond. No.                     6.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.698
# Model:                               WLS   Adj. R-squared:                  0.698
# Method:                    Least Squares   F-statistic:                     4663.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -72498.
# No. Observations:                  12111   AIC:                         1.450e+05
# Df Residuals:                      12104   BIC:                         1.451e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3481.5468    290.342     11.991      0.000    2912.430    4050.663
# dm_total_officers_rate             4.0956      0.771      5.313      0.000       2.585       5.607
# dm_prison_occupancy_count_rate    -0.2891      0.095     -3.043      0.002      -0.475      -0.103
# dm_drug_tot_arrests_rate           0.1206      0.040      2.987      0.003       0.041       0.200
# lag1_dm_violent_crime_rate         0.7506      0.009     86.623      0.000       0.734       0.768
# lag2_dm_violent_crime_rate         0.0309      0.008      3.714      0.000       0.015       0.047
# YEAR                              -1.7432      0.145    -12.030      0.000      -2.027      -1.459
# ==============================================================================
# Omnibus:                     2453.888   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            88577.660
# Skew:                           0.022   Prob(JB):                         0.00
# Kurtosis:                      16.249   Cond. No.                     6.72e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.679
# Model:                               WLS   Adj. R-squared:                  0.679
# Method:                    Least Squares   F-statistic:                     4369.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -74871.
# No. Observations:                  12418   AIC:                         1.498e+05
# Df Residuals:                      12411   BIC:                         1.498e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3437.2979    307.008     11.196      0.000    2835.514    4039.082
# dm_total_officers_rate                -2.7584      1.789     -1.542      0.123      -6.265       0.748
# dm_jail_occupancy_count_rate           0.3118      0.142      2.198      0.028       0.034       0.590
# dm_disorder_arrests_tot_index_rate     0.0364      0.027      1.326      0.185      -0.017       0.090
# lag1_dm_violent_crime_rate             0.7503      0.008     88.443      0.000       0.734       0.767
# lag2_dm_violent_crime_rate             0.0242      0.008      2.976      0.003       0.008       0.040
# YEAR                                  -1.7203      0.153    -11.227      0.000      -2.021      -1.420
# ==============================================================================
# Omnibus:                     3385.863   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           265110.933
# Skew:                           0.320   Prob(JB):                         0.00
# Kurtosis:                      25.627   Cond. No.                     6.89e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.89e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.698
# Model:                               WLS   Adj. R-squared:                  0.698
# Method:                    Least Squares   F-statistic:                     4308.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -66713.
# No. Observations:                  11171   AIC:                         1.334e+05
# Df Residuals:                      11164   BIC:                         1.335e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3100.0191    308.780     10.040      0.000    2494.755    3705.283
# dm_total_officers_rate                 0.5029      1.803      0.279      0.780      -3.032       4.038
# dm_prison_occupancy_count_rate        -0.2547      0.102     -2.507      0.012      -0.454      -0.056
# dm_disorder_arrests_tot_index_rate     0.0421      0.028      1.524      0.128      -0.012       0.096
# lag1_dm_violent_crime_rate             0.7433      0.009     82.855      0.000       0.726       0.761
# lag2_dm_violent_crime_rate             0.0395      0.009      4.604      0.000       0.023       0.056
# YEAR                                  -1.5523      0.154    -10.073      0.000      -1.854      -1.250
# ==============================================================================
# Omnibus:                     2337.422   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93128.162
# Skew:                           0.004   Prob(JB):                         0.00
# Kurtosis:                      17.145   Cond. No.                     6.96e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.96e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.676
# Model:                               WLS   Adj. R-squared:                  0.676
# Method:                    Least Squares   F-statistic:                     4462.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -77453.
# No. Observations:                  12856   AIC:                         1.549e+05
# Df Residuals:                      12849   BIC:                         1.550e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3392.9293    297.276     11.413      0.000    2810.224    3975.635
# dm_total_officers_rate                -1.9596      1.725     -1.136      0.256      -5.341       1.422
# dm_drug_tot_arrests_rate               0.1336      0.042      3.212      0.001       0.052       0.215
# dm_disorder_arrests_tot_index_rate     0.0158      0.027      0.576      0.565      -0.038       0.070
# lag1_dm_violent_crime_rate             0.7458      0.008     89.439      0.000       0.729       0.762
# lag2_dm_violent_crime_rate             0.0252      0.008      3.147      0.002       0.010       0.041
# YEAR                                  -1.6982      0.148    -11.446      0.000      -1.989      -1.407
# ==============================================================================
# Omnibus:                     3590.097   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           278978.643
# Skew:                           0.377   Prob(JB):                         0.00
# Kurtosis:                      25.809   Cond. No.                     6.82e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.633
# Model:                               WLS   Adj. R-squared:                  0.633
# Method:                    Least Squares   F-statistic:                     1674.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -36185.
# No. Observations:                   5827   AIC:                         7.238e+04
# Df Residuals:                       5820   BIC:                         7.243e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      1.07e+04   1072.586      9.980      0.000    8602.060    1.28e+04
# dm_total_officers_rate           2.7585      1.756      1.571      0.116      -0.685       6.202
# dm_jail_occupancy_count_rate    -0.5339      0.254     -2.104      0.035      -1.031      -0.036
# dm_drug_tot_arrests_rate         0.1857      0.070      2.644      0.008       0.048       0.323
# lag1_dm_violent_crime_rate       0.7083      0.012     58.027      0.000       0.684       0.732
# lag2_dm_violent_crime_rate       0.0086      0.011      0.763      0.446      -0.014       0.031
# YEAR                            -5.3592      0.537     -9.981      0.000      -6.412      -4.307
# ==============================================================================
# Omnibus:                     2046.567   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131155.383
# Skew:                           0.840   Prob(JB):                         0.00
# Kurtosis:                      26.181   Cond. No.                     1.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.648
# Model:                               WLS   Adj. R-squared:                  0.647
# Method:                    Least Squares   F-statistic:                     1597.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -32046.
# No. Observations:                   5216   AIC:                         6.411e+04
# Df Residuals:                       5209   BIC:                         6.415e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       8269.1743   1108.590      7.459      0.000    6095.872    1.04e+04
# dm_total_officers_rate             6.0092      1.744      3.447      0.001       2.591       9.427
# dm_prison_occupancy_count_rate    -0.8248      0.178     -4.621      0.000      -1.175      -0.475
# dm_drug_tot_arrests_rate           0.1116      0.069      1.620      0.105      -0.023       0.247
# lag1_dm_violent_crime_rate         0.6980      0.013     53.909      0.000       0.673       0.723
# lag2_dm_violent_crime_rate         0.0253      0.012      2.131      0.033       0.002       0.049
# YEAR                              -4.1404      0.555     -7.461      0.000      -5.228      -3.053
# ==============================================================================
# Omnibus:                     1338.932   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33110.440
# Skew:                           0.656   Prob(JB):                         0.00
# Kurtosis:                      15.273   Cond. No.                     1.44e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.636
# Model:                               WLS   Adj. R-squared:                  0.636
# Method:                    Least Squares   F-statistic:                     1591.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -33903.
# No. Observations:                   5462   AIC:                         6.782e+04
# Df Residuals:                       5455   BIC:                         6.787e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           9913.1151   1115.026      8.890      0.000    7727.219    1.21e+04
# dm_total_officers_rate                -1.0092      2.236     -0.451      0.652      -5.392       3.374
# dm_jail_occupancy_count_rate          -0.4142      0.262     -1.582      0.114      -0.928       0.099
# dm_disorder_arrests_tot_index_rate     0.0038      0.044      0.085      0.932      -0.083       0.091
# lag1_dm_violent_crime_rate             0.7067      0.013     56.336      0.000       0.682       0.731
# lag2_dm_violent_crime_rate             0.0150      0.012      1.296      0.195      -0.008       0.038
# YEAR                                  -4.9628      0.558     -8.891      0.000      -6.057      -3.869
# ==============================================================================
# Omnibus:                     2009.865   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           137469.613
# Skew:                           0.903   Prob(JB):                         0.00
# Kurtosis:                      27.511   Cond. No.                     1.39e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.652
# Model:                               WLS   Adj. R-squared:                  0.651
# Method:                    Least Squares   F-statistic:                     1520.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -29973.
# No. Observations:                   4882   AIC:                         5.996e+04
# Df Residuals:                       4875   BIC:                         6.001e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           7397.4495   1161.143      6.371      0.000    5121.086    9673.813
# dm_total_officers_rate                 3.2055      2.186      1.466      0.143      -1.080       7.491
# dm_prison_occupancy_count_rate        -0.9223      0.187     -4.926      0.000      -1.289      -0.555
# dm_disorder_arrests_tot_index_rate     0.0070      0.044      0.158      0.874      -0.080       0.093
# lag1_dm_violent_crime_rate             0.6898      0.013     51.928      0.000       0.664       0.716
# lag2_dm_violent_crime_rate             0.0349      0.012      2.872      0.004       0.011       0.059
# YEAR                                  -3.7040      0.581     -6.372      0.000      -4.844      -2.565
# ==============================================================================
# Omnibus:                     1282.203   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33983.403
# Skew:                           0.662   Prob(JB):                         0.00
# Kurtosis:                      15.857   Cond. No.                     1.46e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.636
# Model:                               WLS   Adj. R-squared:                  0.636
# Method:                    Least Squares   F-statistic:                     1648.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -35084.
# No. Observations:                   5662   AIC:                         7.018e+04
# Df Residuals:                       5655   BIC:                         7.023e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1.045e+04   1075.640      9.712      0.000    8337.532    1.26e+04
# dm_total_officers_rate                -2.0526      2.046     -1.003      0.316      -6.063       1.958
# dm_drug_tot_arrests_rate               0.1216      0.073      1.664      0.096      -0.022       0.265
# dm_disorder_arrests_tot_index_rate    -0.0095      0.044     -0.215      0.830      -0.096       0.077
# lag1_dm_violent_crime_rate             0.7048      0.012     57.289      0.000       0.681       0.729
# lag2_dm_violent_crime_rate             0.0152      0.011      1.337      0.181      -0.007       0.038
# YEAR                                  -5.2295      0.538     -9.712      0.000      -6.285      -4.174
# ==============================================================================
# Omnibus:                     2116.714   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           145046.840
# Skew:                           0.933   Prob(JB):                         0.00
# Kurtosis:                      27.725   Cond. No.                     1.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.713
# Model:                               WLS   Adj. R-squared:                  0.713
# Method:                    Least Squares   F-statistic:                     2636.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -37137.
# No. Observations:                   6369   AIC:                         7.429e+04
# Df Residuals:                       6362   BIC:                         7.433e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2898.8579    675.411      4.292      0.000    1574.825    4222.891
# dm_total_officers_rate           0.7758      1.085      0.715      0.475      -1.351       2.903
# dm_jail_occupancy_count_rate     0.5559      0.148      3.754      0.000       0.266       0.846
# dm_drug_tot_arrests_rate         0.2317      0.050      4.648      0.000       0.134       0.329
# lag1_dm_violent_crime_rate       0.8257      0.012     67.492      0.000       0.802       0.850
# lag2_dm_violent_crime_rate       0.0444      0.013      3.529      0.000       0.020       0.069
# YEAR                            -1.4502      0.336     -4.315      0.000      -2.109      -0.791
# ==============================================================================
# Omnibus:                     1637.077   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           108090.238
# Skew:                          -0.258   Prob(JB):                         0.00
# Kurtosis:                      23.175   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.734
# Model:                               WLS   Adj. R-squared:                  0.733
# Method:                    Least Squares   F-statistic:                     2649.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -33375.
# No. Observations:                   5782   AIC:                         6.676e+04
# Df Residuals:                       5775   BIC:                         6.681e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       3573.1624    692.205      5.162      0.000    2216.182    4930.143
# dm_total_officers_rate             2.7951      1.095      2.552      0.011       0.648       4.942
# dm_prison_occupancy_count_rate    -0.0524      0.115     -0.454      0.650      -0.278       0.174
# dm_drug_tot_arrests_rate           0.1468      0.050      2.954      0.003       0.049       0.244
# lag1_dm_violent_crime_rate         0.8455      0.013     65.012      0.000       0.820       0.871
# lag2_dm_violent_crime_rate         0.0385      0.013      2.874      0.004       0.012       0.065
# YEAR                              -1.7850      0.344     -5.183      0.000      -2.460      -1.110
# ==============================================================================
# Omnibus:                     1684.786   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63061.637
# Skew:                          -0.702   Prob(JB):                         0.00
# Kurtosis:                      19.118   Cond. No.                     1.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.706
# Model:                               WLS   Adj. R-squared:                  0.706
# Method:                    Least Squares   F-statistic:                     2336.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -33941.
# No. Observations:                   5844   AIC:                         6.790e+04
# Df Residuals:                       5837   BIC:                         6.794e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2782.4601    707.650      3.932      0.000    1395.204    4169.716
# dm_total_officers_rate                -0.6918      2.913     -0.237      0.812      -6.403       5.019
# dm_jail_occupancy_count_rate           0.8839      0.162      5.455      0.000       0.566       1.202
# dm_disorder_arrests_tot_index_rate     0.0419      0.035      1.183      0.237      -0.028       0.111
# lag1_dm_violent_crime_rate             0.8216      0.013     64.193      0.000       0.797       0.847
# lag2_dm_violent_crime_rate             0.0509      0.013      3.841      0.000       0.025       0.077
# YEAR                                  -1.3914      0.352     -3.951      0.000      -2.082      -0.701
# ==============================================================================
# Omnibus:                     1551.303   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           115054.562
# Skew:                          -0.266   Prob(JB):                         0.00
# Kurtosis:                      24.731   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.726
# Model:                               WLS   Adj. R-squared:                  0.726
# Method:                    Least Squares   F-statistic:                     2332.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -30438.
# No. Observations:                   5291   AIC:                         6.089e+04
# Df Residuals:                       5284   BIC:                         6.094e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           3152.6632    726.010      4.342      0.000    1729.385    4575.942
# dm_total_officers_rate                 1.8421      3.067      0.601      0.548      -4.171       7.855
# dm_prison_occupancy_count_rate         0.1316      0.124      1.059      0.290      -0.112       0.375
# dm_disorder_arrests_tot_index_rate     0.0311      0.036      0.870      0.384      -0.039       0.101
# lag1_dm_violent_crime_rate             0.8338      0.014     61.226      0.000       0.807       0.861
# lag2_dm_violent_crime_rate             0.0539      0.014      3.821      0.000       0.026       0.082
# YEAR                                  -1.5752      0.361     -4.361      0.000      -2.283      -0.867
# ==============================================================================
# Omnibus:                     1615.829   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            71595.543
# Skew:                          -0.719   Prob(JB):                         0.00
# Kurtosis:                      20.964   Cond. No.                     1.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# medium_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.702
# Model:                               WLS   Adj. R-squared:                  0.702
# Method:                    Least Squares   F-statistic:                     2370.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:11   Log-Likelihood:                -35105.
# No. Observations:                   6044   AIC:                         7.022e+04
# Df Residuals:                       6037   BIC:                         7.027e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2910.0932    697.966      4.169      0.000    1541.830    4278.357
# dm_total_officers_rate                -1.3400      2.923     -0.458      0.647      -7.069       4.389
# dm_drug_tot_arrests_rate               0.2113      0.051      4.130      0.000       0.111       0.312
# dm_disorder_arrests_tot_index_rate     0.0079      0.035      0.223      0.824      -0.061       0.077
# lag1_dm_violent_crime_rate             0.8231      0.013     65.518      0.000       0.798       0.848
# lag2_dm_violent_crime_rate             0.0446      0.013      3.433      0.001       0.019       0.070
# YEAR                                  -1.4546      0.347     -4.188      0.000      -2.135      -0.774
# ==============================================================================
# Omnibus:                     1595.135   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144838.084
# Skew:                          -0.025   Prob(JB):                         0.00
# Kurtosis:                      26.982   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Small Agencies - 90-15, 90-02, 03-15

# %%
wols_lagged_control_multi_3(req_dfs=[small_90_15, small_90_02, small_03_15],
                       dep_var=dm_dep_var_rates,
                       ind_vars_lists=dm_ind_var_lists,
                       control_var='YEAR',
                       weights_var='fnl_population_wt',
                       dataset_names=['small_90_15', 'small_90_02', 'small_03_15'])
# Out:
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.498
# Model:                               WLS   Adj. R-squared:                  0.498
# Method:                    Least Squares   F-statistic:                 1.257e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:28   Log-Likelihood:            -4.7672e+05
# No. Observations:                  75944   AIC:                         9.534e+05
# Df Residuals:                      75937   BIC:                         9.535e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3305.9299    141.206     23.412      0.000    3029.167    3582.693
# dm_total_officers_rate           5.6971      1.195      4.769      0.000       3.356       8.039
# dm_jail_occupancy_count_rate    -0.2589      0.047     -5.475      0.000      -0.352      -0.166
# dm_drug_tot_arrests_rate         0.2120      0.019     11.091      0.000       0.175       0.249
# lag1_dm_violent_crime_rate       0.6236      0.003    178.215      0.000       0.617       0.630
# lag2_dm_violent_crime_rate       0.0513      0.003     15.133      0.000       0.045       0.058
# YEAR                            -1.6529      0.070    -23.458      0.000      -1.791      -1.515
# ==============================================================================
# Omnibus:                    30609.136   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6249688.049
# Skew:                           0.798   Prob(JB):                         0.00
# Kurtosis:                      47.413   Cond. No.                     6.37e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.517
# Model:                               WLS   Adj. R-squared:                  0.517
# Method:                    Least Squares   F-statistic:                 1.216e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:28   Log-Likelihood:            -4.2516e+05
# No. Observations:                  68088   AIC:                         8.503e+05
# Df Residuals:                      68081   BIC:                         8.504e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2834.4717    147.934     19.160      0.000    2544.521    3124.422
# dm_total_officers_rate             7.4201      1.263      5.875      0.000       4.945       9.896
# dm_prison_occupancy_count_rate    -0.6466      0.043    -15.123      0.000      -0.730      -0.563
# dm_drug_tot_arrests_rate           0.2073      0.019     10.667      0.000       0.169       0.245
# lag1_dm_violent_crime_rate         0.6287      0.004    169.967      0.000       0.621       0.636
# lag2_dm_violent_crime_rate         0.0551      0.004     15.384      0.000       0.048       0.062
# YEAR                              -1.4176      0.074    -19.203      0.000      -1.562      -1.273
# ==============================================================================
# Omnibus:                    26134.683   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6663576.062
# Skew:                           0.630   Prob(JB):                         0.00
# Kurtosis:                      51.448   Cond. No.                     6.53e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.53e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.506
# Model:                               WLS   Adj. R-squared:                  0.506
# Method:                    Least Squares   F-statistic:                 1.211e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:28   Log-Likelihood:            -4.4360e+05
# No. Observations:                  70862   AIC:                         8.872e+05
# Df Residuals:                      70855   BIC:                         8.873e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2365.4898    149.710     15.800      0.000    2072.058    2658.922
# dm_total_officers_rate                 4.0017      1.206      3.318      0.001       1.638       6.365
# dm_jail_occupancy_count_rate          -0.2167      0.048     -4.515      0.000      -0.311      -0.123
# dm_disorder_arrests_tot_index_rate     0.1745      0.013     13.920      0.000       0.150       0.199
# lag1_dm_violent_crime_rate             0.6304      0.004    173.993      0.000       0.623       0.637
# lag2_dm_violent_crime_rate             0.0502      0.003     14.348      0.000       0.043       0.057
# YEAR                                  -1.1829      0.075    -15.833      0.000      -1.329      -1.036
# ==============================================================================
# Omnibus:                    30240.487   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6547945.683
# Skew:                           0.905   Prob(JB):                         0.00
# Kurtosis:                      50.058   Cond. No.                     6.64e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.64e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.526
# Model:                               WLS   Adj. R-squared:                  0.526
# Method:                    Least Squares   F-statistic:                 1.172e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:28   Log-Likelihood:            -3.9381e+05
# No. Observations:                  63270   AIC:                         7.876e+05
# Df Residuals:                      63263   BIC:                         7.877e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2060.7124    154.667     13.324      0.000    1757.565    2363.860
# dm_total_officers_rate                 5.2657      1.271      4.143      0.000       2.775       7.757
# dm_prison_occupancy_count_rate        -0.5292      0.044    -11.944      0.000      -0.616      -0.442
# dm_disorder_arrests_tot_index_rate     0.1552      0.013     12.087      0.000       0.130       0.180
# lag1_dm_violent_crime_rate             0.6374      0.004    165.939      0.000       0.630       0.645
# lag2_dm_violent_crime_rate             0.0544      0.004     14.692      0.000       0.047       0.062
# YEAR                                  -1.0309      0.077    -13.355      0.000      -1.182      -0.880
# ==============================================================================
# Omnibus:                    26055.436   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7214341.490
# Skew:                           0.762   Prob(JB):                         0.00
# Kurtosis:                      55.290   Cond. No.                     6.71e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# small_90_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.506
# Model:                               WLS   Adj. R-squared:                  0.506
# Method:                    Least Squares   F-statistic:                 1.248e+04
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:28   Log-Likelihood:            -4.5663e+05
# No. Observations:                  73066   AIC:                         9.133e+05
# Df Residuals:                      73059   BIC:                         9.133e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2668.4459    143.450     18.602      0.000    2387.284    2949.608
# dm_total_officers_rate                 3.0190      1.189      2.539      0.011       0.688       5.350
# dm_drug_tot_arrests_rate               0.1083      0.019      5.603      0.000       0.070       0.146
# dm_disorder_arrests_tot_index_rate     0.1597      0.012     12.797      0.000       0.135       0.184
# lag1_dm_violent_crime_rate             0.6313      0.004    176.936      0.000       0.624       0.638
# lag2_dm_violent_crime_rate             0.0482      0.003     13.993      0.000       0.041       0.055
# YEAR                                  -1.3342      0.072    -18.637      0.000      -1.475      -1.194
# ==============================================================================
# Omnibus:                    31552.892   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6987459.627
# Skew:                           0.926   Prob(JB):                         0.00
# Kurtosis:                      50.872   Cond. No.                     6.52e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.455
# Model:                               WLS   Adj. R-squared:                  0.455
# Method:                    Least Squares   F-statistic:                     4417.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:28   Log-Likelihood:            -2.0495e+05
# No. Observations:                  31744   AIC:                         4.099e+05
# Df Residuals:                      31737   BIC:                         4.100e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     9521.8932    550.116     17.309      0.000    8443.645    1.06e+04
# dm_total_officers_rate           4.5237      2.340      1.933      0.053      -0.063       9.110
# dm_jail_occupancy_count_rate    -0.5990      0.091     -6.550      0.000      -0.778      -0.420
# dm_drug_tot_arrests_rate         0.1946      0.035      5.594      0.000       0.126       0.263
# lag1_dm_violent_crime_rate       0.5818      0.005    108.008      0.000       0.571       0.592
# lag2_dm_violent_crime_rate       0.0385      0.005      7.594      0.000       0.029       0.048
# YEAR                            -4.7656      0.275    -17.304      0.000      -5.305      -4.226
# ==============================================================================
# Omnibus:                    15396.803   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2627507.773
# Skew:                           1.257   Prob(JB):                         0.00
# Kurtosis:                      47.499   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.475
# Model:                               WLS   Adj. R-squared:                  0.475
# Method:                    Least Squares   F-statistic:                     4240.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -1.8098e+05
# No. Observations:                  28166   AIC:                         3.620e+05
# Df Residuals:                      28159   BIC:                         3.620e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       8066.3293    582.298     13.853      0.000    6924.997    9207.661
# dm_total_officers_rate             3.7013      2.395      1.546      0.122      -0.992       8.395
# dm_prison_occupancy_count_rate    -0.9580      0.082    -11.748      0.000      -1.118      -0.798
# dm_drug_tot_arrests_rate           0.2013      0.035      5.719      0.000       0.132       0.270
# lag1_dm_violent_crime_rate         0.5898      0.006    103.035      0.000       0.579       0.601
# lag2_dm_violent_crime_rate         0.0367      0.005      6.803      0.000       0.026       0.047
# YEAR                              -4.0379      0.291    -13.852      0.000      -4.609      -3.467
# ==============================================================================
# Omnibus:                    12757.675   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2851628.784
# Skew:                           1.027   Prob(JB):                         0.00
# Kurtosis:                      52.251   Cond. No.                     1.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.471
# Model:                               WLS   Adj. R-squared:                  0.471
# Method:                    Least Squares   F-statistic:                     4447.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -1.9317e+05
# No. Observations:                  29980   AIC:                         3.864e+05
# Df Residuals:                      29973   BIC:                         3.864e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           8026.3529    559.934     14.334      0.000    6928.858    9123.848
# dm_total_officers_rate                 2.3397      2.356      0.993      0.321      -2.278       6.958
# dm_jail_occupancy_count_rate          -0.5723      0.092     -6.196      0.000      -0.753      -0.391
# dm_disorder_arrests_tot_index_rate     0.2121      0.021     10.145      0.000       0.171       0.253
# lag1_dm_violent_crime_rate             0.5956      0.006    108.076      0.000       0.585       0.606
# lag2_dm_violent_crime_rate             0.0352      0.005      6.829      0.000       0.025       0.045
# YEAR                                  -4.0180      0.280    -14.334      0.000      -4.567      -3.469
# ==============================================================================
# Omnibus:                    14756.675   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2676524.465
# Skew:                           1.278   Prob(JB):                         0.00
# Kurtosis:                      49.218   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.492
# Model:                               WLS   Adj. R-squared:                  0.491
# Method:                    Least Squares   F-statistic:                     4267.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -1.6985e+05
# No. Observations:                  26490   AIC:                         3.397e+05
# Df Residuals:                      26483   BIC:                         3.398e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           6774.6193    594.315     11.399      0.000    5609.729    7939.509
# dm_total_officers_rate                 1.5595      2.415      0.646      0.518      -3.175       6.294
# dm_prison_occupancy_count_rate        -0.8563      0.084    -10.234      0.000      -1.020      -0.692
# dm_disorder_arrests_tot_index_rate     0.1911      0.021      8.911      0.000       0.149       0.233
# lag1_dm_violent_crime_rate             0.6050      0.006    102.905      0.000       0.593       0.617
# lag2_dm_violent_crime_rate             0.0339      0.005      6.159      0.000       0.023       0.045
# YEAR                                  -3.3920      0.298    -11.401      0.000      -3.975      -2.809
# ==============================================================================
# Omnibus:                    12544.596   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3013900.418
# Skew:                           1.112   Prob(JB):                         0.00
# Kurtosis:                      55.208   Cond. No.                     1.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# small_90_02
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.470
# Model:                               WLS   Adj. R-squared:                  0.470
# Method:                    Least Squares   F-statistic:                     4571.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -1.9909e+05
# No. Observations:                  30946   AIC:                         3.982e+05
# Df Residuals:                      30939   BIC:                         3.983e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           8672.4240    546.908     15.857      0.000    7600.462    9744.386
# dm_total_officers_rate                 0.4906      2.320      0.211      0.833      -4.057       5.038
# dm_drug_tot_arrests_rate               0.0521      0.035      1.471      0.141      -0.017       0.122
# dm_disorder_arrests_tot_index_rate     0.2040      0.021      9.797      0.000       0.163       0.245
# lag1_dm_violent_crime_rate             0.5987      0.005    110.328      0.000       0.588       0.609
# lag2_dm_violent_crime_rate             0.0326      0.005      6.402      0.000       0.023       0.043
# YEAR                                  -4.3406      0.274    -15.853      0.000      -4.877      -3.804
# ==============================================================================
# Omnibus:                    15688.611   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2898728.897
# Skew:                           1.347   Prob(JB):                         0.00
# Kurtosis:                      50.337   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.570
# Model:                               WLS   Adj. R-squared:                  0.570
# Method:                    Least Squares   F-statistic:                     8137.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -2.2362e+05
# No. Observations:                  36847   AIC:                         4.473e+05
# Df Residuals:                      36840   BIC:                         4.473e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2446.7158    336.417      7.273      0.000    1787.328    3106.104
# dm_total_officers_rate           7.0983      1.302      5.453      0.000       4.547       9.650
# dm_jail_occupancy_count_rate    -0.0148      0.052     -0.286      0.775      -0.116       0.086
# dm_drug_tot_arrests_rate         0.1914      0.023      8.355      0.000       0.146       0.236
# lag1_dm_violent_crime_rate       0.6987      0.005    136.016      0.000       0.689       0.709
# lag2_dm_violent_crime_rate       0.0973      0.005     18.453      0.000       0.087       0.108
# YEAR                            -1.2231      0.167     -7.308      0.000      -1.551      -0.895
# ==============================================================================
# Omnibus:                    12137.125   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1621570.264
# Skew:                           0.510   Prob(JB):                         0.00
# Kurtosis:                      35.483   Cond. No.                     1.31e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.582
# Model:                               WLS   Adj. R-squared:                  0.582
# Method:                    Least Squares   F-statistic:                     7742.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -2.0161e+05
# No. Observations:                  33373   AIC:                         4.032e+05
# Df Residuals:                      33366   BIC:                         4.033e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       2870.0969    351.960      8.155      0.000    2180.243    3559.951
# dm_total_officers_rate             8.6251      1.405      6.141      0.000       5.872      11.378
# dm_prison_occupancy_count_rate    -0.3524      0.048     -7.275      0.000      -0.447      -0.257
# dm_drug_tot_arrests_rate           0.1882      0.023      8.008      0.000       0.142       0.234
# lag1_dm_violent_crime_rate         0.6954      0.005    128.591      0.000       0.685       0.706
# lag2_dm_violent_crime_rate         0.1102      0.006     19.891      0.000       0.099       0.121
# YEAR                              -1.4332      0.175     -8.185      0.000      -1.776      -1.090
# ==============================================================================
# Omnibus:                    11075.358   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1496243.752
# Skew:                           0.521   Prob(JB):                         0.00
# Kurtosis:                      35.786   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.565
# Model:                               WLS   Adj. R-squared:                  0.565
# Method:                    Least Squares   F-statistic:                     7396.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -2.0681e+05
# No. Observations:                  34211   AIC:                         4.136e+05
# Df Residuals:                      34204   BIC:                         4.137e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1798.5998    347.984      5.169      0.000    1116.540    2480.659
# dm_total_officers_rate                 5.7353      1.310      4.379      0.000       3.168       8.303
# dm_jail_occupancy_count_rate           0.0254      0.052      0.486      0.627      -0.077       0.128
# dm_disorder_arrests_tot_index_rate     0.0953      0.016      6.080      0.000       0.065       0.126
# lag1_dm_violent_crime_rate             0.6998      0.005    130.145      0.000       0.689       0.710
# lag2_dm_violent_crime_rate             0.0941      0.006     17.056      0.000       0.083       0.105
# YEAR                                  -0.8994      0.173     -5.194      0.000      -1.239      -0.560
# ==============================================================================
# Omnibus:                    12042.797   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1743728.327
# Skew:                           0.618   Prob(JB):                         0.00
# Kurtosis:                      37.954   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.577
# Model:                               WLS   Adj. R-squared:                  0.577
# Method:                    Least Squares   F-statistic:                     7020.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -1.8566e+05
# No. Observations:                  30880   AIC:                         3.713e+05
# Df Residuals:                      30873   BIC:                         3.714e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           2106.0958    362.758      5.806      0.000    1395.075    2817.117
# dm_total_officers_rate                 6.5507      1.402      4.674      0.000       3.804       9.298
# dm_prison_occupancy_count_rate        -0.2134      0.051     -4.212      0.000      -0.313      -0.114
# dm_disorder_arrests_tot_index_rate     0.0879      0.016      5.434      0.000       0.056       0.120
# lag1_dm_violent_crime_rate             0.6984      0.006    122.803      0.000       0.687       0.710
# lag2_dm_violent_crime_rate             0.1078      0.006     18.474      0.000       0.096       0.119
# YEAR                                  -1.0521      0.180     -5.829      0.000      -1.406      -0.698
# ==============================================================================
# Omnibus:                    10948.056   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1619032.937
# Skew:                           0.625   Prob(JB):                         0.00
# Kurtosis:                      38.451   Cond. No.                     1.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# small_03_15
#                               WLS Regression Results
# =================================================================================
# Dep. Variable:     dm_violent_crime_rate   R-squared:                       0.565
# Model:                               WLS   Adj. R-squared:                  0.565
# Method:                    Least Squares   F-statistic:                     7628.
# Date:                   Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                           15:01:29   Log-Likelihood:            -2.1266e+05
# No. Observations:                  35247   AIC:                         4.253e+05
# Df Residuals:                      35240   BIC:                         4.254e+05
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                           1678.5914    339.297      4.947      0.000    1013.558    2343.624
# dm_total_officers_rate                 5.2907      1.291      4.098      0.000       2.760       7.821
# dm_drug_tot_arrests_rate               0.1559      0.023      6.782      0.000       0.111       0.201
# dm_disorder_arrests_tot_index_rate     0.0751      0.016      4.813      0.000       0.045       0.106
# lag1_dm_violent_crime_rate             0.6985      0.005    131.848      0.000       0.688       0.709
# lag2_dm_violent_crime_rate             0.0939      0.005     17.284      0.000       0.083       0.105
# YEAR                                  -0.8401      0.169     -4.976      0.000      -1.171      -0.509
# ==============================================================================
# Omnibus:                    12409.822   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1849056.267
# Skew:                           0.610   Prob(JB):                         0.00
# Kurtosis:                      38.462   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
